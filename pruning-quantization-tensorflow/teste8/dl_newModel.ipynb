# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# 2.7.0
# 1
# /device:GPU:0

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255
#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout (Dropout)           (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_1 (Dropout)         (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_2 (Dropout)         (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_3 (Dropout)         (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 250
alpha = 0.5
n_bits = 3

learning_rate = 0.015
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_8.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0 and alpha > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0 and alpha > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_8.csv')
# Out:
# Created Tensor of velocity
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Epoch 1/250 	 Loss = 1.717 	 Train Acc = 40.008% 	 Sparsity = 44.790% 	 Test Loss = 1.547 	Test Acc = 44.200%
# New test accuracy is 44.200%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/250 	 Loss = 1.397 	 Train Acc = 49.008% 	 Sparsity = 55.225% 	 Test Loss = 1.435 	Test Acc = 47.090%
# New test accuracy is 47.090%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/250 	 Loss = 1.306 	 Train Acc = 52.826% 	 Sparsity = 55.591% 	 Test Loss = 1.174 	Test Acc = 57.680%
# New test accuracy is 57.680%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/250 	 Loss = 1.237 	 Train Acc = 55.472% 	 Sparsity = 55.877% 	 Test Loss = 1.187 	Test Acc = 57.020%
# Epoch 5/250 	 Loss = 1.193 	 Train Acc = 57.258% 	 Sparsity = 55.974% 	 Test Loss = 1.083 	Test Acc = 60.970%
# New test accuracy is 60.970%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/250 	 Loss = 1.172 	 Train Acc = 58.278% 	 Sparsity = 56.016% 	 Test Loss = 1.097 	Test Acc = 60.610%
# Epoch 7/250 	 Loss = 1.158 	 Train Acc = 58.882% 	 Sparsity = 56.029% 	 Test Loss = 1.250 	Test Acc = 57.250%
# Epoch 8/250 	 Loss = 1.158 	 Train Acc = 59.166% 	 Sparsity = 56.039% 	 Test Loss = 1.083 	Test Acc = 61.400%
# New test accuracy is 61.400%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/250 	 Loss = 1.143 	 Train Acc = 59.736% 	 Sparsity = 56.047% 	 Test Loss = 1.004 	Test Acc = 64.250%
# New test accuracy is 64.250%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 10/250 	 Loss = 1.140 	 Train Acc = 59.678% 	 Sparsity = 56.050% 	 Test Loss = 0.986 	Test Acc = 64.700%
# New test accuracy is 64.700%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 11/250 	 Loss = 1.136 	 Train Acc = 59.588% 	 Sparsity = 56.053% 	 Test Loss = 1.502 	Test Acc = 49.710%
# Epoch 12/250 	 Loss = 1.136 	 Train Acc = 59.902% 	 Sparsity = 56.054% 	 Test Loss = 1.150 	Test Acc = 59.480%
# Epoch 13/250 	 Loss = 1.133 	 Train Acc = 60.036% 	 Sparsity = 56.056% 	 Test Loss = 0.994 	Test Acc = 64.390%
# Epoch 14/250 	 Loss = 1.130 	 Train Acc = 60.322% 	 Sparsity = 56.058% 	 Test Loss = 0.989 	Test Acc = 64.310%
# Epoch 15/250 	 Loss = 1.126 	 Train Acc = 60.602% 	 Sparsity = 56.059% 	 Test Loss = 0.972 	Test Acc = 65.020%
# New test accuracy is 65.020%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 16/250 	 Loss = 1.127 	 Train Acc = 60.204% 	 Sparsity = 56.060% 	 Test Loss = 0.972 	Test Acc = 65.090%
# New test accuracy is 65.090%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 17/250 	 Loss = 1.127 	 Train Acc = 60.248% 	 Sparsity = 56.061% 	 Test Loss = 1.003 	Test Acc = 64.050%
# Epoch 18/250 	 Loss = 1.125 	 Train Acc = 60.310% 	 Sparsity = 56.064% 	 Test Loss = 0.979 	Test Acc = 64.830%
# Epoch 19/250 	 Loss = 1.131 	 Train Acc = 60.134% 	 Sparsity = 56.065% 	 Test Loss = 0.982 	Test Acc = 64.930%
# Epoch 20/250 	 Loss = 1.128 	 Train Acc = 60.320% 	 Sparsity = 56.065% 	 Test Loss = 0.969 	Test Acc = 64.970%
# Epoch 21/250 	 Loss = 1.123 	 Train Acc = 60.410% 	 Sparsity = 56.066% 	 Test Loss = 0.990 	Test Acc = 64.350%
# Epoch 22/250 	 Loss = 1.126 	 Train Acc = 60.380% 	 Sparsity = 56.066% 	 Test Loss = 1.036 	Test Acc = 62.720%
# Epoch 23/250 	 Loss = 1.129 	 Train Acc = 60.124% 	 Sparsity = 56.068% 	 Test Loss = 0.950 	Test Acc = 65.750%
# New test accuracy is 65.750%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 24/250 	 Loss = 1.127 	 Train Acc = 60.464% 	 Sparsity = 56.068% 	 Test Loss = 0.965 	Test Acc = 65.350%
# Epoch 25/250 	 Loss = 1.123 	 Train Acc = 60.438% 	 Sparsity = 56.068% 	 Test Loss = 0.962 	Test Acc = 65.280%
# Epoch 26/250 	 Loss = 1.124 	 Train Acc = 60.334% 	 Sparsity = 56.068% 	 Test Loss = 0.966 	Test Acc = 65.610%
# Epoch 27/250 	 Loss = 1.123 	 Train Acc = 60.282% 	 Sparsity = 56.069% 	 Test Loss = 0.981 	Test Acc = 64.950%
# Epoch 28/250 	 Loss = 1.128 	 Train Acc = 60.450% 	 Sparsity = 56.069% 	 Test Loss = 0.995 	Test Acc = 63.960%
# Epoch 29/250 	 Loss = 1.125 	 Train Acc = 60.290% 	 Sparsity = 56.070% 	 Test Loss = 0.968 	Test Acc = 65.200%
# Epoch 30/250 	 Loss = 1.125 	 Train Acc = 60.448% 	 Sparsity = 56.070% 	 Test Loss = 0.964 	Test Acc = 65.420%
# Epoch 31/250 	 Loss = 1.121 	 Train Acc = 60.306% 	 Sparsity = 56.071% 	 Test Loss = 0.962 	Test Acc = 65.330%
# Epoch 32/250 	 Loss = 1.124 	 Train Acc = 60.292% 	 Sparsity = 56.071% 	 Test Loss = 0.979 	Test Acc = 64.780%
# Epoch 33/250 	 Loss = 1.126 	 Train Acc = 60.098% 	 Sparsity = 56.072% 	 Test Loss = 0.949 	Test Acc = 65.720%
# Epoch 34/250 	 Loss = 1.123 	 Train Acc = 60.332% 	 Sparsity = 56.075% 	 Test Loss = 0.975 	Test Acc = 65.010%
# Epoch 35/250 	 Loss = 1.126 	 Train Acc = 60.438% 	 Sparsity = 56.076% 	 Test Loss = 0.978 	Test Acc = 64.860%
# Epoch 36/250 	 Loss = 1.120 	 Train Acc = 60.270% 	 Sparsity = 56.077% 	 Test Loss = 0.949 	Test Acc = 65.880%
# New test accuracy is 65.880%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 37/250 	 Loss = 1.128 	 Train Acc = 60.106% 	 Sparsity = 56.077% 	 Test Loss = 0.961 	Test Acc = 65.390%
# Epoch 38/250 	 Loss = 1.132 	 Train Acc = 60.108% 	 Sparsity = 56.077% 	 Test Loss = 0.965 	Test Acc = 65.340%
# Epoch 39/250 	 Loss = 1.125 	 Train Acc = 60.222% 	 Sparsity = 56.077% 	 Test Loss = 0.956 	Test Acc = 65.650%
# Epoch 40/250 	 Loss = 1.130 	 Train Acc = 60.326% 	 Sparsity = 56.077% 	 Test Loss = 0.964 	Test Acc = 65.310%
# Epoch 41/250 	 Loss = 1.127 	 Train Acc = 60.282% 	 Sparsity = 56.077% 	 Test Loss = 0.980 	Test Acc = 64.950%
# Epoch 42/250 	 Loss = 1.121 	 Train Acc = 60.438% 	 Sparsity = 56.077% 	 Test Loss = 1.015 	Test Acc = 63.820%
# Epoch 43/250 	 Loss = 1.123 	 Train Acc = 60.450% 	 Sparsity = 56.077% 	 Test Loss = 0.988 	Test Acc = 64.710%
# Epoch 44/250 	 Loss = 1.128 	 Train Acc = 60.070% 	 Sparsity = 56.078% 	 Test Loss = 0.979 	Test Acc = 65.150%
# Epoch 45/250 	 Loss = 1.125 	 Train Acc = 60.230% 	 Sparsity = 56.078% 	 Test Loss = 0.952 	Test Acc = 65.960%
# New test accuracy is 65.960%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 46/250 	 Loss = 1.130 	 Train Acc = 60.096% 	 Sparsity = 56.078% 	 Test Loss = 0.953 	Test Acc = 65.550%
# Epoch 47/250 	 Loss = 1.128 	 Train Acc = 60.238% 	 Sparsity = 56.078% 	 Test Loss = 0.965 	Test Acc = 65.350%
# Epoch 48/250 	 Loss = 1.125 	 Train Acc = 60.454% 	 Sparsity = 56.078% 	 Test Loss = 0.977 	Test Acc = 64.700%
# Epoch 49/250 	 Loss = 1.128 	 Train Acc = 60.292% 	 Sparsity = 56.078% 	 Test Loss = 0.949 	Test Acc = 66.030%
# New test accuracy is 66.030%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 50/250 	 Loss = 1.124 	 Train Acc = 60.292% 	 Sparsity = 56.078% 	 Test Loss = 0.973 	Test Acc = 65.340%
# Epoch 51/250 	 Loss = 1.124 	 Train Acc = 60.384% 	 Sparsity = 56.078% 	 Test Loss = 0.969 	Test Acc = 65.010%
# Epoch 52/250 	 Loss = 1.125 	 Train Acc = 60.302% 	 Sparsity = 56.078% 	 Test Loss = 0.968 	Test Acc = 65.390%
# Epoch 53/250 	 Loss = 1.127 	 Train Acc = 60.306% 	 Sparsity = 56.079% 	 Test Loss = 0.991 	Test Acc = 64.430%
# Epoch 54/250 	 Loss = 1.123 	 Train Acc = 60.126% 	 Sparsity = 56.079% 	 Test Loss = 0.960 	Test Acc = 65.640%
# Epoch 55/250 	 Loss = 1.123 	 Train Acc = 60.554% 	 Sparsity = 56.079% 	 Test Loss = 0.969 	Test Acc = 65.450%
# Epoch 56/250 	 Loss = 1.129 	 Train Acc = 60.276% 	 Sparsity = 56.079% 	 Test Loss = 0.958 	Test Acc = 66.170%
# New test accuracy is 66.170%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 57/250 	 Loss = 1.128 	 Train Acc = 60.112% 	 Sparsity = 56.079% 	 Test Loss = 0.940 	Test Acc = 66.330%
# New test accuracy is 66.330%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 58/250 	 Loss = 1.122 	 Train Acc = 60.242% 	 Sparsity = 56.079% 	 Test Loss = 0.957 	Test Acc = 65.740%
# Epoch 59/250 	 Loss = 1.118 	 Train Acc = 60.590% 	 Sparsity = 56.079% 	 Test Loss = 0.961 	Test Acc = 65.490%
# Epoch 60/250 	 Loss = 1.125 	 Train Acc = 60.226% 	 Sparsity = 56.081% 	 Test Loss = 0.963 	Test Acc = 65.590%
# Epoch 61/250 	 Loss = 1.128 	 Train Acc = 60.036% 	 Sparsity = 56.082% 	 Test Loss = 0.973 	Test Acc = 65.200%
# Epoch 62/250 	 Loss = 1.126 	 Train Acc = 60.290% 	 Sparsity = 56.082% 	 Test Loss = 0.977 	Test Acc = 65.000%
# Epoch 63/250 	 Loss = 1.118 	 Train Acc = 60.412% 	 Sparsity = 56.082% 	 Test Loss = 0.964 	Test Acc = 65.460%
# Epoch 64/250 	 Loss = 1.126 	 Train Acc = 60.192% 	 Sparsity = 56.082% 	 Test Loss = 0.952 	Test Acc = 65.750%
# Epoch 65/250 	 Loss = 1.127 	 Train Acc = 60.204% 	 Sparsity = 56.083% 	 Test Loss = 0.969 	Test Acc = 65.290%
# Epoch 66/250 	 Loss = 1.124 	 Train Acc = 60.656% 	 Sparsity = 56.083% 	 Test Loss = 0.940 	Test Acc = 66.140%
# Epoch 67/250 	 Loss = 1.125 	 Train Acc = 60.116% 	 Sparsity = 56.083% 	 Test Loss = 0.962 	Test Acc = 65.660%
# Epoch 68/250 	 Loss = 1.128 	 Train Acc = 60.494% 	 Sparsity = 56.083% 	 Test Loss = 0.946 	Test Acc = 66.170%
# Epoch 69/250 	 Loss = 1.117 	 Train Acc = 60.630% 	 Sparsity = 56.083% 	 Test Loss = 0.952 	Test Acc = 65.960%
# Epoch 70/250 	 Loss = 1.121 	 Train Acc = 60.356% 	 Sparsity = 56.083% 	 Test Loss = 0.970 	Test Acc = 65.080%
# Epoch 71/250 	 Loss = 1.127 	 Train Acc = 60.032% 	 Sparsity = 56.083% 	 Test Loss = 0.954 	Test Acc = 65.760%
# Epoch 72/250 	 Loss = 1.126 	 Train Acc = 60.388% 	 Sparsity = 56.083% 	 Test Loss = 0.952 	Test Acc = 66.260%
# Epoch 73/250 	 Loss = 1.122 	 Train Acc = 60.322% 	 Sparsity = 56.083% 	 Test Loss = 0.968 	Test Acc = 65.440%
# Epoch 74/250 	 Loss = 1.124 	 Train Acc = 60.464% 	 Sparsity = 56.083% 	 Test Loss = 0.935 	Test Acc = 66.350%
# New test accuracy is 66.350%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 75/250 	 Loss = 1.119 	 Train Acc = 60.280% 	 Sparsity = 56.083% 	 Test Loss = 0.970 	Test Acc = 65.250%
# Epoch 76/250 	 Loss = 1.126 	 Train Acc = 60.274% 	 Sparsity = 56.083% 	 Test Loss = 0.962 	Test Acc = 65.530%
# Epoch 77/250 	 Loss = 1.130 	 Train Acc = 60.192% 	 Sparsity = 56.083% 	 Test Loss = 0.995 	Test Acc = 64.510%
# Epoch 78/250 	 Loss = 1.125 	 Train Acc = 60.338% 	 Sparsity = 56.083% 	 Test Loss = 0.964 	Test Acc = 65.380%
# Epoch 79/250 	 Loss = 1.122 	 Train Acc = 60.222% 	 Sparsity = 56.084% 	 Test Loss = 0.960 	Test Acc = 65.920%
# Epoch 80/250 	 Loss = 1.122 	 Train Acc = 60.306% 	 Sparsity = 56.084% 	 Test Loss = 0.967 	Test Acc = 65.240%
# Epoch 81/250 	 Loss = 1.121 	 Train Acc = 60.414% 	 Sparsity = 56.084% 	 Test Loss = 0.965 	Test Acc = 65.490%
# Epoch 82/250 	 Loss = 1.123 	 Train Acc = 60.254% 	 Sparsity = 56.084% 	 Test Loss = 0.967 	Test Acc = 65.270%
# Epoch 83/250 	 Loss = 1.117 	 Train Acc = 60.510% 	 Sparsity = 56.084% 	 Test Loss = 0.957 	Test Acc = 65.900%
# Epoch 84/250 	 Loss = 1.121 	 Train Acc = 60.560% 	 Sparsity = 56.084% 	 Test Loss = 1.011 	Test Acc = 63.680%
# Epoch 85/250 	 Loss = 1.116 	 Train Acc = 60.648% 	 Sparsity = 56.084% 	 Test Loss = 0.981 	Test Acc = 64.690%
# Epoch 86/250 	 Loss = 1.124 	 Train Acc = 60.206% 	 Sparsity = 56.084% 	 Test Loss = 1.024 	Test Acc = 63.310%
# Epoch 87/250 	 Loss = 1.121 	 Train Acc = 60.344% 	 Sparsity = 56.084% 	 Test Loss = 1.122 	Test Acc = 59.770%
# Epoch 88/250 	 Loss = 1.119 	 Train Acc = 60.406% 	 Sparsity = 56.084% 	 Test Loss = 1.091 	Test Acc = 61.480%
# Epoch 89/250 	 Loss = 1.129 	 Train Acc = 60.108% 	 Sparsity = 56.084% 	 Test Loss = 1.147 	Test Acc = 59.190%
# Epoch 90/250 	 Loss = 1.126 	 Train Acc = 60.342% 	 Sparsity = 56.085% 	 Test Loss = 1.240 	Test Acc = 56.650%
# Epoch 91/250 	 Loss = 1.123 	 Train Acc = 60.294% 	 Sparsity = 56.085% 	 Test Loss = 1.305 	Test Acc = 54.550%
# Epoch 92/250 	 Loss = 1.127 	 Train Acc = 60.168% 	 Sparsity = 56.085% 	 Test Loss = 1.414 	Test Acc = 52.940%
# Epoch 93/250 	 Loss = 1.121 	 Train Acc = 60.368% 	 Sparsity = 56.085% 	 Test Loss = 1.528 	Test Acc = 50.530%
# Epoch 94/250 	 Loss = 1.123 	 Train Acc = 60.448% 	 Sparsity = 56.085% 	 Test Loss = 1.666 	Test Acc = 49.280%
# Epoch 95/250 	 Loss = 1.119 	 Train Acc = 60.410% 	 Sparsity = 56.085% 	 Test Loss = 1.798 	Test Acc = 46.600%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9948/260292417.py in <module>
#      54             #Cópia do modelo
#      55             if n_bits > 0 and alpha > 0:
# ---> 56                 model_copy = keras.models.clone_model(model)
#      57                 model_copy.set_weights(model.get_weights())
#      58
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\models.py in clone_model(model, input_tensors, clone_function)
#     452     if isinstance(model, Sequential):
#     453       return _clone_sequential_model(
# --> 454           model, input_tensors=input_tensors, layer_fn=clone_function)
#     455     else:
#     456       return _clone_functional_model(
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\models.py in _clone_sequential_model(model, input_tensors, layer_fn)
#     334
#     335   if input_tensors is None:
# --> 336     cloned_model = Sequential(layers=layers, name=model.name)
#     337   elif len(generic_utils.to_list(input_tensors)) != 1:
#     338     raise ValueError(
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\sequential.py in __init__(self, layers, name)
#     108     # Skip the init in FunctionalModel since model doesn't have input/output yet
#     109     super(functional.Functional, self).__init__(  # pylint: disable=bad-super-call
# --> 110         name=name, autocast=False)
#     111     base_layer.keras_api_gauge.get_cell('Sequential').set(True)
#     112     self.supports_masking = True
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py in __init__(self, *args, **kwargs)
#     279     self._steps_per_execution = None
#     280
# --> 281     self._init_batch_counters()
#     282     self._base_model_initialized = True
#     283
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py in _init_batch_counters(self)
#     287     # `evaluate`, and `predict`.
#     288     agg = tf.VariableAggregation.ONLY_FIRST_REPLICA
# --> 289     self._train_counter = tf.Variable(0, dtype='int64', aggregation=agg)
#     290     self._test_counter = tf.Variable(0, dtype='int64', aggregation=agg)
#     291     self._predict_counter = tf.Variable(
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     268       return cls._variable_v1_call(*args, **kwargs)
#     269     elif cls is Variable:
# --> 270       return cls._variable_v2_call(*args, **kwargs)
#     271     else:
#     272       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\variables.py in _variable_v2_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape)
#     261         synchronization=synchronization,
#     262         aggregation=aggregation,
# --> 263         shape=shape)
#     264
#     265   @traceback_utils.filter_traceback
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\variables.py in <lambda>(**kws)
#     242                         shape=None):
#     243     """Call on Variable class. Useful to force the signature."""
# --> 244     previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#     245     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     246       previous_getter = _make_getter(getter, previous_getter)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\variable_scope.py in default_variable_creator_v2(next_creator, **kwargs)
#    2673       synchronization=synchronization,
#    2674       aggregation=aggregation,
# -> 2675       shape=shape)
#    2676
#    2677
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     270       return cls._variable_v2_call(*args, **kwargs)
#     271     else:
# --> 272       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     273
#     274
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1639           aggregation=aggregation,
#    1640           shape=shape,
# -> 1641           distribute_strategy=distribute_strategy)
#    1642
#    1643   def _init_from_args(self,
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1795               shared_name=shared_name,
#    1796               name=name,
# -> 1797               graph_mode=self._in_graph_mode)
#    1798         # pylint: disable=protected-access
#    1799         if (self._in_graph_mode and initial_value is not None and
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in eager_safe_variable_handle(initial_value, shape, shared_name, name, graph_mode)
#     237   dtype = initial_value.dtype.base_dtype
#     238   return _variable_handle_from_shape_and_dtype(shape, dtype, shared_name, name,
# --> 239                                                graph_mode, initial_value)
#     240
#     241
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _variable_handle_from_shape_and_dtype(shape, dtype, shared_name, name, graph_mode, initial_value)
#     165       shared_name=shared_name,
#     166       name=name,
# --> 167       container=container)
#     168   if initial_value is None:
#     169     initial_value = handle
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py in var_handle_op(dtype, shape, container, shared_name, allowed_devices, name)
#    1172         _ctx, "VarHandleOp", name, "container", container, "shared_name",
#    1173         shared_name, "dtype", dtype, "shape", shape, "allowed_devices",
# -> 1174         allowed_devices)
#    1175       return _result
#    1176     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
l = len(model.trainable_weights)
for i in range(l):
  a = tf.reshape(model.trainable_weights[i],[-1])
  b = a.numpy()
  #print(a)
  #plt.ylim(0,300)
  plt.title(str(i))
  plt.hist(b,200)
  plt.show()

# %%
import pandas as pd

data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_8.csv')

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
model = keras.models.load_model('test_8.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
for layer in model.layers:
    if layer.name == 'conv2':
        a = tf.reshape(layer.weights[0],[-1])
        b = a.numpy()
        plt.hist(b,200)
        plt.show()

        plt.hist(b,200)
        plt.ylim((0,150))
        plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
with tf.device('/device:CPU:0'):
    test_accuracy = tf.keras.metrics.Accuracy()
    logits = model(x_test, training=False)
    prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
    test_accuracy(prediction, y_test)
    print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 66.350%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# 2.7.0
# 1
# /device:GPU:0

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255
#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout (Dropout)           (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_1 (Dropout)         (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_2 (Dropout)         (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_3 (Dropout)         (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 250
alpha = 0.75
n_bits = 16

learning_rate = 0.015
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_9.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_9.csv')
# Out:
# Created Tensor of velocity
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Epoch 1/250 	 Loss = 1.635 	 Train Acc = 42.310% 	 Sparsity = 56.904% 	 Test Loss = 1.294 	Test Acc = 53.300%
# New test accuracy is 53.300%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/250 	 Loss = 1.258 	 Train Acc = 54.776% 	 Sparsity = 58.649% 	 Test Loss = 1.162 	Test Acc = 58.730%
# New test accuracy is 58.730%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/250 	 Loss = 1.113 	 Train Acc = 60.230% 	 Sparsity = 59.772% 	 Test Loss = 0.955 	Test Acc = 65.730%
# New test accuracy is 65.730%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/250 	 Loss = 1.020 	 Train Acc = 64.120% 	 Sparsity = 60.618% 	 Test Loss = 0.839 	Test Acc = 69.970%
# New test accuracy is 69.970%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 5/250 	 Loss = 0.951 	 Train Acc = 66.420% 	 Sparsity = 61.266% 	 Test Loss = 0.825 	Test Acc = 71.150%
# New test accuracy is 71.150%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/250 	 Loss = 0.907 	 Train Acc = 68.344% 	 Sparsity = 61.778% 	 Test Loss = 0.806 	Test Acc = 72.120%
# New test accuracy is 72.120%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/250 	 Loss = 0.867 	 Train Acc = 69.734% 	 Sparsity = 62.201% 	 Test Loss = 0.737 	Test Acc = 74.130%
# New test accuracy is 74.130%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/250 	 Loss = 0.841 	 Train Acc = 70.768% 	 Sparsity = 62.565% 	 Test Loss = 0.742 	Test Acc = 74.190%
# New test accuracy is 74.190%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/250 	 Loss = 0.818 	 Train Acc = 71.352% 	 Sparsity = 62.886% 	 Test Loss = 0.715 	Test Acc = 75.170%
# New test accuracy is 75.170%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 10/250 	 Loss = 0.801 	 Train Acc = 71.910% 	 Sparsity = 63.166% 	 Test Loss = 0.775 	Test Acc = 72.860%
# Epoch 11/250 	 Loss = 0.782 	 Train Acc = 72.860% 	 Sparsity = 63.424% 	 Test Loss = 0.685 	Test Acc = 76.380%
# New test accuracy is 76.380%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 12/250 	 Loss = 0.770 	 Train Acc = 73.286% 	 Sparsity = 63.652% 	 Test Loss = 0.683 	Test Acc = 76.250%
# Epoch 13/250 	 Loss = 0.757 	 Train Acc = 73.582% 	 Sparsity = 63.861% 	 Test Loss = 0.679 	Test Acc = 76.570%
# New test accuracy is 76.570%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 14/250 	 Loss = 0.746 	 Train Acc = 74.052% 	 Sparsity = 64.050% 	 Test Loss = 0.665 	Test Acc = 77.120%
# New test accuracy is 77.120%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 15/250 	 Loss = 0.733 	 Train Acc = 74.514% 	 Sparsity = 64.218% 	 Test Loss = 0.664 	Test Acc = 77.130%
# New test accuracy is 77.130%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 16/250 	 Loss = 0.730 	 Train Acc = 74.570% 	 Sparsity = 64.374% 	 Test Loss = 0.659 	Test Acc = 77.100%
# Epoch 17/250 	 Loss = 0.722 	 Train Acc = 75.058% 	 Sparsity = 64.511% 	 Test Loss = 0.696 	Test Acc = 75.960%
# Epoch 18/250 	 Loss = 0.718 	 Train Acc = 75.072% 	 Sparsity = 64.638% 	 Test Loss = 0.635 	Test Acc = 78.190%
# New test accuracy is 78.190%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 19/250 	 Loss = 0.708 	 Train Acc = 75.284% 	 Sparsity = 64.777% 	 Test Loss = 0.642 	Test Acc = 78.080%
# Epoch 20/250 	 Loss = 0.708 	 Train Acc = 75.284% 	 Sparsity = 64.887% 	 Test Loss = 0.636 	Test Acc = 77.810%
# Epoch 21/250 	 Loss = 0.697 	 Train Acc = 75.780% 	 Sparsity = 64.995% 	 Test Loss = 0.660 	Test Acc = 77.380%
# Epoch 22/250 	 Loss = 0.695 	 Train Acc = 75.840% 	 Sparsity = 65.087% 	 Test Loss = 0.628 	Test Acc = 78.370%
# New test accuracy is 78.370%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 23/250 	 Loss = 0.693 	 Train Acc = 76.080% 	 Sparsity = 65.187% 	 Test Loss = 0.636 	Test Acc = 77.820%
# Epoch 24/250 	 Loss = 0.689 	 Train Acc = 76.108% 	 Sparsity = 65.284% 	 Test Loss = 0.643 	Test Acc = 77.700%
# Epoch 25/250 	 Loss = 0.686 	 Train Acc = 76.204% 	 Sparsity = 65.364% 	 Test Loss = 0.660 	Test Acc = 76.880%
# Epoch 26/250 	 Loss = 0.682 	 Train Acc = 76.298% 	 Sparsity = 65.436% 	 Test Loss = 0.649 	Test Acc = 77.700%
# Epoch 27/250 	 Loss = 0.681 	 Train Acc = 76.522% 	 Sparsity = 65.515% 	 Test Loss = 0.641 	Test Acc = 77.600%
# Epoch 28/250 	 Loss = 0.671 	 Train Acc = 76.450% 	 Sparsity = 65.601% 	 Test Loss = 0.651 	Test Acc = 77.750%
# Epoch 29/250 	 Loss = 0.680 	 Train Acc = 76.462% 	 Sparsity = 65.658% 	 Test Loss = 0.659 	Test Acc = 77.310%
# Epoch 30/250 	 Loss = 0.678 	 Train Acc = 76.420% 	 Sparsity = 65.724% 	 Test Loss = 0.609 	Test Acc = 79.240%
# New test accuracy is 79.240%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 31/250 	 Loss = 0.674 	 Train Acc = 76.392% 	 Sparsity = 65.774% 	 Test Loss = 0.653 	Test Acc = 77.540%
# Epoch 32/250 	 Loss = 0.672 	 Train Acc = 76.716% 	 Sparsity = 65.831% 	 Test Loss = 0.615 	Test Acc = 78.950%
# Epoch 33/250 	 Loss = 0.670 	 Train Acc = 76.866% 	 Sparsity = 65.899% 	 Test Loss = 0.651 	Test Acc = 77.960%
# Epoch 34/250 	 Loss = 0.670 	 Train Acc = 76.738% 	 Sparsity = 65.965% 	 Test Loss = 0.623 	Test Acc = 78.420%
# Epoch 35/250 	 Loss = 0.656 	 Train Acc = 76.916% 	 Sparsity = 66.009% 	 Test Loss = 0.589 	Test Acc = 79.560%
# New test accuracy is 79.560%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 36/250 	 Loss = 0.664 	 Train Acc = 76.844% 	 Sparsity = 66.060% 	 Test Loss = 0.636 	Test Acc = 77.830%
# Epoch 37/250 	 Loss = 0.662 	 Train Acc = 77.050% 	 Sparsity = 66.126% 	 Test Loss = 0.611 	Test Acc = 78.720%
# Epoch 38/250 	 Loss = 0.663 	 Train Acc = 77.086% 	 Sparsity = 66.164% 	 Test Loss = 0.633 	Test Acc = 78.330%
# Epoch 39/250 	 Loss = 0.661 	 Train Acc = 76.936% 	 Sparsity = 66.208% 	 Test Loss = 0.635 	Test Acc = 77.850%
# Epoch 40/250 	 Loss = 0.657 	 Train Acc = 77.074% 	 Sparsity = 66.251% 	 Test Loss = 0.647 	Test Acc = 77.520%
# Epoch 41/250 	 Loss = 0.659 	 Train Acc = 77.282% 	 Sparsity = 66.286% 	 Test Loss = 0.624 	Test Acc = 78.410%
# Epoch 42/250 	 Loss = 0.651 	 Train Acc = 77.328% 	 Sparsity = 66.329% 	 Test Loss = 0.604 	Test Acc = 79.070%
# Epoch 43/250 	 Loss = 0.652 	 Train Acc = 77.202% 	 Sparsity = 66.371% 	 Test Loss = 0.666 	Test Acc = 76.920%
# Epoch 44/250 	 Loss = 0.652 	 Train Acc = 77.368% 	 Sparsity = 66.419% 	 Test Loss = 0.607 	Test Acc = 78.960%
# Epoch 45/250 	 Loss = 0.647 	 Train Acc = 77.680% 	 Sparsity = 66.451% 	 Test Loss = 0.620 	Test Acc = 78.600%
# Epoch 46/250 	 Loss = 0.650 	 Train Acc = 77.512% 	 Sparsity = 66.504% 	 Test Loss = 0.601 	Test Acc = 78.910%
# Epoch 47/250 	 Loss = 0.647 	 Train Acc = 77.604% 	 Sparsity = 66.539% 	 Test Loss = 0.604 	Test Acc = 78.620%
# Epoch 48/250 	 Loss = 0.652 	 Train Acc = 77.400% 	 Sparsity = 66.568% 	 Test Loss = 0.610 	Test Acc = 78.820%
# Epoch 49/250 	 Loss = 0.647 	 Train Acc = 77.600% 	 Sparsity = 66.592% 	 Test Loss = 0.602 	Test Acc = 79.200%
# Epoch 50/250 	 Loss = 0.642 	 Train Acc = 77.674% 	 Sparsity = 66.644% 	 Test Loss = 0.628 	Test Acc = 78.390%
# Epoch 51/250 	 Loss = 0.640 	 Train Acc = 77.666% 	 Sparsity = 66.671% 	 Test Loss = 0.613 	Test Acc = 78.800%
# Epoch 52/250 	 Loss = 0.642 	 Train Acc = 77.478% 	 Sparsity = 66.714% 	 Test Loss = 0.615 	Test Acc = 78.720%
# Epoch 53/250 	 Loss = 0.649 	 Train Acc = 77.270% 	 Sparsity = 66.734% 	 Test Loss = 0.614 	Test Acc = 78.590%
# Epoch 54/250 	 Loss = 0.646 	 Train Acc = 77.332% 	 Sparsity = 66.750% 	 Test Loss = 0.597 	Test Acc = 79.050%
# Epoch 55/250 	 Loss = 0.643 	 Train Acc = 77.734% 	 Sparsity = 66.808% 	 Test Loss = 0.655 	Test Acc = 77.800%
# Epoch 56/250 	 Loss = 0.645 	 Train Acc = 77.476% 	 Sparsity = 66.859% 	 Test Loss = 0.609 	Test Acc = 79.140%
# Epoch 57/250 	 Loss = 0.642 	 Train Acc = 77.572% 	 Sparsity = 66.879% 	 Test Loss = 0.602 	Test Acc = 79.090%
# Epoch 58/250 	 Loss = 0.642 	 Train Acc = 77.584% 	 Sparsity = 66.898% 	 Test Loss = 0.633 	Test Acc = 78.090%
# Epoch 59/250 	 Loss = 0.642 	 Train Acc = 77.836% 	 Sparsity = 66.926% 	 Test Loss = 0.634 	Test Acc = 77.890%
# Epoch 60/250 	 Loss = 0.639 	 Train Acc = 77.674% 	 Sparsity = 66.953% 	 Test Loss = 0.604 	Test Acc = 79.140%
# Epoch 61/250 	 Loss = 0.643 	 Train Acc = 77.494% 	 Sparsity = 66.971% 	 Test Loss = 0.613 	Test Acc = 78.760%
# Epoch 62/250 	 Loss = 0.639 	 Train Acc = 77.812% 	 Sparsity = 66.987% 	 Test Loss = 0.611 	Test Acc = 78.760%
# Epoch 63/250 	 Loss = 0.641 	 Train Acc = 77.534% 	 Sparsity = 67.004% 	 Test Loss = 0.624 	Test Acc = 78.180%
# Epoch 64/250 	 Loss = 0.642 	 Train Acc = 77.762% 	 Sparsity = 67.049% 	 Test Loss = 0.622 	Test Acc = 78.560%
# Epoch 65/250 	 Loss = 0.639 	 Train Acc = 77.772% 	 Sparsity = 67.062% 	 Test Loss = 0.603 	Test Acc = 79.240%
# Epoch 66/250 	 Loss = 0.636 	 Train Acc = 77.700% 	 Sparsity = 67.103% 	 Test Loss = 0.603 	Test Acc = 79.180%
# Epoch 67/250 	 Loss = 0.633 	 Train Acc = 77.946% 	 Sparsity = 67.134% 	 Test Loss = 0.621 	Test Acc = 78.560%
# Epoch 68/250 	 Loss = 0.635 	 Train Acc = 77.990% 	 Sparsity = 67.149% 	 Test Loss = 0.582 	Test Acc = 80.020%
# New test accuracy is 80.020%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 69/250 	 Loss = 0.640 	 Train Acc = 77.758% 	 Sparsity = 67.170% 	 Test Loss = 0.620 	Test Acc = 78.690%
# Epoch 70/250 	 Loss = 0.638 	 Train Acc = 77.968% 	 Sparsity = 67.200% 	 Test Loss = 0.611 	Test Acc = 78.980%
# Epoch 71/250 	 Loss = 0.635 	 Train Acc = 77.864% 	 Sparsity = 67.225% 	 Test Loss = 0.603 	Test Acc = 78.930%
# Epoch 72/250 	 Loss = 0.637 	 Train Acc = 77.828% 	 Sparsity = 67.257% 	 Test Loss = 0.625 	Test Acc = 78.380%
# Epoch 73/250 	 Loss = 0.631 	 Train Acc = 77.938% 	 Sparsity = 67.291% 	 Test Loss = 0.601 	Test Acc = 79.060%
# Epoch 74/250 	 Loss = 0.634 	 Train Acc = 77.998% 	 Sparsity = 67.299% 	 Test Loss = 0.596 	Test Acc = 79.270%
# Epoch 75/250 	 Loss = 0.640 	 Train Acc = 77.558% 	 Sparsity = 67.354% 	 Test Loss = 0.596 	Test Acc = 79.430%
# Epoch 76/250 	 Loss = 0.634 	 Train Acc = 77.994% 	 Sparsity = 67.377% 	 Test Loss = 0.617 	Test Acc = 78.560%
# Epoch 77/250 	 Loss = 0.633 	 Train Acc = 77.920% 	 Sparsity = 67.390% 	 Test Loss = 0.605 	Test Acc = 79.340%
# Epoch 78/250 	 Loss = 0.631 	 Train Acc = 78.008% 	 Sparsity = 67.404% 	 Test Loss = 0.611 	Test Acc = 79.090%
# Epoch 79/250 	 Loss = 0.637 	 Train Acc = 77.834% 	 Sparsity = 67.417% 	 Test Loss = 0.608 	Test Acc = 78.940%
# Epoch 80/250 	 Loss = 0.634 	 Train Acc = 77.764% 	 Sparsity = 67.434% 	 Test Loss = 0.588 	Test Acc = 79.440%
# Epoch 81/250 	 Loss = 0.634 	 Train Acc = 77.988% 	 Sparsity = 67.452% 	 Test Loss = 0.635 	Test Acc = 78.620%
# Epoch 82/250 	 Loss = 0.631 	 Train Acc = 77.992% 	 Sparsity = 67.475% 	 Test Loss = 0.591 	Test Acc = 79.540%
# Epoch 83/250 	 Loss = 0.628 	 Train Acc = 78.384% 	 Sparsity = 67.503% 	 Test Loss = 0.622 	Test Acc = 78.650%
# Epoch 84/250 	 Loss = 0.633 	 Train Acc = 77.888% 	 Sparsity = 67.515% 	 Test Loss = 0.636 	Test Acc = 78.030%
# Epoch 85/250 	 Loss = 0.635 	 Train Acc = 77.870% 	 Sparsity = 67.522% 	 Test Loss = 0.594 	Test Acc = 79.450%
# Epoch 86/250 	 Loss = 0.637 	 Train Acc = 77.840% 	 Sparsity = 67.535% 	 Test Loss = 0.605 	Test Acc = 78.860%
# Epoch 87/250 	 Loss = 0.627 	 Train Acc = 78.090% 	 Sparsity = 67.568% 	 Test Loss = 0.605 	Test Acc = 79.030%
# Epoch 88/250 	 Loss = 0.636 	 Train Acc = 77.958% 	 Sparsity = 67.586% 	 Test Loss = 0.596 	Test Acc = 79.150%
# Epoch 89/250 	 Loss = 0.632 	 Train Acc = 78.076% 	 Sparsity = 67.618% 	 Test Loss = 0.627 	Test Acc = 78.750%
# Epoch 90/250 	 Loss = 0.627 	 Train Acc = 78.088% 	 Sparsity = 67.625% 	 Test Loss = 0.596 	Test Acc = 79.660%
# Epoch 91/250 	 Loss = 0.628 	 Train Acc = 78.102% 	 Sparsity = 67.638% 	 Test Loss = 0.586 	Test Acc = 79.680%
# Epoch 92/250 	 Loss = 0.630 	 Train Acc = 77.974% 	 Sparsity = 67.664% 	 Test Loss = 0.630 	Test Acc = 78.550%
# Epoch 93/250 	 Loss = 0.631 	 Train Acc = 77.970% 	 Sparsity = 67.670% 	 Test Loss = 0.600 	Test Acc = 79.340%
# Epoch 94/250 	 Loss = 0.634 	 Train Acc = 77.772% 	 Sparsity = 67.681% 	 Test Loss = 0.613 	Test Acc = 78.840%
# Epoch 95/250 	 Loss = 0.627 	 Train Acc = 78.102% 	 Sparsity = 67.688% 	 Test Loss = 0.593 	Test Acc = 79.420%
# Epoch 96/250 	 Loss = 0.630 	 Train Acc = 77.938% 	 Sparsity = 67.731% 	 Test Loss = 0.629 	Test Acc = 78.400%
# Epoch 97/250 	 Loss = 0.626 	 Train Acc = 78.188% 	 Sparsity = 67.746% 	 Test Loss = 0.601 	Test Acc = 79.120%
# Epoch 98/250 	 Loss = 0.637 	 Train Acc = 77.740% 	 Sparsity = 67.761% 	 Test Loss = 0.596 	Test Acc = 79.500%
# Epoch 99/250 	 Loss = 0.632 	 Train Acc = 77.976% 	 Sparsity = 67.771% 	 Test Loss = 0.624 	Test Acc = 78.380%
# Epoch 100/250 	 Loss = 0.626 	 Train Acc = 78.102% 	 Sparsity = 67.783% 	 Test Loss = 0.599 	Test Acc = 79.070%
# Epoch 101/250 	 Loss = 0.632 	 Train Acc = 78.122% 	 Sparsity = 67.830% 	 Test Loss = 0.583 	Test Acc = 79.710%
# Epoch 102/250 	 Loss = 0.631 	 Train Acc = 77.824% 	 Sparsity = 67.845% 	 Test Loss = 0.572 	Test Acc = 79.960%
# Epoch 103/250 	 Loss = 0.622 	 Train Acc = 78.154% 	 Sparsity = 67.881% 	 Test Loss = 0.593 	Test Acc = 79.640%
# Epoch 104/250 	 Loss = 0.632 	 Train Acc = 78.188% 	 Sparsity = 67.929% 	 Test Loss = 0.583 	Test Acc = 80.150%
# New test accuracy is 80.150%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 105/250 	 Loss = 0.629 	 Train Acc = 78.122% 	 Sparsity = 67.934% 	 Test Loss = 0.593 	Test Acc = 79.500%
# Epoch 106/250 	 Loss = 0.628 	 Train Acc = 78.376% 	 Sparsity = 67.938% 	 Test Loss = 0.603 	Test Acc = 79.420%
# Epoch 107/250 	 Loss = 0.626 	 Train Acc = 78.292% 	 Sparsity = 67.943% 	 Test Loss = 0.588 	Test Acc = 79.790%
# Epoch 108/250 	 Loss = 0.628 	 Train Acc = 78.256% 	 Sparsity = 67.949% 	 Test Loss = 0.590 	Test Acc = 79.490%
# Epoch 109/250 	 Loss = 0.625 	 Train Acc = 78.150% 	 Sparsity = 67.954% 	 Test Loss = 0.613 	Test Acc = 78.780%
# Epoch 110/250 	 Loss = 0.627 	 Train Acc = 78.150% 	 Sparsity = 67.992% 	 Test Loss = 0.610 	Test Acc = 79.220%
# Epoch 111/250 	 Loss = 0.631 	 Train Acc = 78.014% 	 Sparsity = 67.997% 	 Test Loss = 0.609 	Test Acc = 79.140%
# Epoch 112/250 	 Loss = 0.632 	 Train Acc = 77.938% 	 Sparsity = 68.013% 	 Test Loss = 0.598 	Test Acc = 79.360%
# Epoch 113/250 	 Loss = 0.627 	 Train Acc = 78.120% 	 Sparsity = 68.027% 	 Test Loss = 0.607 	Test Acc = 78.980%
# Epoch 114/250 	 Loss = 0.621 	 Train Acc = 78.502% 	 Sparsity = 68.031% 	 Test Loss = 0.584 	Test Acc = 79.870%
# Epoch 115/250 	 Loss = 0.629 	 Train Acc = 78.080% 	 Sparsity = 68.051% 	 Test Loss = 0.594 	Test Acc = 79.510%
# Epoch 116/250 	 Loss = 0.621 	 Train Acc = 78.280% 	 Sparsity = 68.137% 	 Test Loss = 0.596 	Test Acc = 79.410%
# Epoch 117/250 	 Loss = 0.629 	 Train Acc = 78.080% 	 Sparsity = 68.147% 	 Test Loss = 0.590 	Test Acc = 79.640%
# Epoch 118/250 	 Loss = 0.617 	 Train Acc = 78.594% 	 Sparsity = 68.152% 	 Test Loss = 0.583 	Test Acc = 80.270%
# New test accuracy is 80.270%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 119/250 	 Loss = 0.623 	 Train Acc = 78.260% 	 Sparsity = 68.168% 	 Test Loss = 0.600 	Test Acc = 79.230%
# Epoch 120/250 	 Loss = 0.628 	 Train Acc = 78.022% 	 Sparsity = 68.172% 	 Test Loss = 0.606 	Test Acc = 79.190%
# Epoch 121/250 	 Loss = 0.623 	 Train Acc = 78.264% 	 Sparsity = 68.176% 	 Test Loss = 0.579 	Test Acc = 79.900%
# Epoch 122/250 	 Loss = 0.625 	 Train Acc = 78.354% 	 Sparsity = 68.187% 	 Test Loss = 0.593 	Test Acc = 79.670%
# Epoch 123/250 	 Loss = 0.626 	 Train Acc = 78.100% 	 Sparsity = 68.191% 	 Test Loss = 0.610 	Test Acc = 78.940%
# Epoch 124/250 	 Loss = 0.625 	 Train Acc = 78.298% 	 Sparsity = 68.201% 	 Test Loss = 0.605 	Test Acc = 79.320%
# Epoch 125/250 	 Loss = 0.623 	 Train Acc = 78.384% 	 Sparsity = 68.204% 	 Test Loss = 0.588 	Test Acc = 79.490%
# Epoch 126/250 	 Loss = 0.627 	 Train Acc = 78.144% 	 Sparsity = 68.208% 	 Test Loss = 0.593 	Test Acc = 79.640%
# Epoch 127/250 	 Loss = 0.626 	 Train Acc = 78.086% 	 Sparsity = 68.212% 	 Test Loss = 0.601 	Test Acc = 79.370%
# Epoch 128/250 	 Loss = 0.627 	 Train Acc = 78.270% 	 Sparsity = 68.215% 	 Test Loss = 0.623 	Test Acc = 78.670%
# Epoch 129/250 	 Loss = 0.626 	 Train Acc = 78.256% 	 Sparsity = 68.219% 	 Test Loss = 0.636 	Test Acc = 77.740%
# Epoch 130/250 	 Loss = 0.626 	 Train Acc = 78.228% 	 Sparsity = 68.223% 	 Test Loss = 0.612 	Test Acc = 78.990%
# Epoch 131/250 	 Loss = 0.623 	 Train Acc = 78.224% 	 Sparsity = 68.258% 	 Test Loss = 0.587 	Test Acc = 79.780%
# Epoch 132/250 	 Loss = 0.623 	 Train Acc = 78.476% 	 Sparsity = 68.262% 	 Test Loss = 0.589 	Test Acc = 79.610%
# Epoch 133/250 	 Loss = 0.621 	 Train Acc = 78.490% 	 Sparsity = 68.277% 	 Test Loss = 0.596 	Test Acc = 79.250%
# Epoch 134/250 	 Loss = 0.623 	 Train Acc = 78.320% 	 Sparsity = 68.280% 	 Test Loss = 0.620 	Test Acc = 78.360%
# Epoch 135/250 	 Loss = 0.628 	 Train Acc = 77.972% 	 Sparsity = 68.295% 	 Test Loss = 0.602 	Test Acc = 79.240%
# Epoch 136/250 	 Loss = 0.626 	 Train Acc = 78.102% 	 Sparsity = 68.298% 	 Test Loss = 0.595 	Test Acc = 79.570%
# Epoch 137/250 	 Loss = 0.620 	 Train Acc = 78.566% 	 Sparsity = 68.301% 	 Test Loss = 0.592 	Test Acc = 79.790%
# Epoch 138/250 	 Loss = 0.624 	 Train Acc = 78.320% 	 Sparsity = 68.322% 	 Test Loss = 0.591 	Test Acc = 79.330%
# Epoch 139/250 	 Loss = 0.624 	 Train Acc = 78.342% 	 Sparsity = 68.325% 	 Test Loss = 0.606 	Test Acc = 79.430%
# Epoch 140/250 	 Loss = 0.625 	 Train Acc = 78.320% 	 Sparsity = 68.414% 	 Test Loss = 0.600 	Test Acc = 79.520%
# Epoch 141/250 	 Loss = 0.626 	 Train Acc = 78.258% 	 Sparsity = 68.417% 	 Test Loss = 0.583 	Test Acc = 79.900%
# Epoch 142/250 	 Loss = 0.625 	 Train Acc = 78.178% 	 Sparsity = 68.534% 	 Test Loss = 0.583 	Test Acc = 80.050%
# Epoch 143/250 	 Loss = 0.625 	 Train Acc = 78.202% 	 Sparsity = 68.537% 	 Test Loss = 0.616 	Test Acc = 78.940%
# Epoch 144/250 	 Loss = 0.620 	 Train Acc = 78.112% 	 Sparsity = 68.540% 	 Test Loss = 0.595 	Test Acc = 79.690%
# Epoch 145/250 	 Loss = 0.627 	 Train Acc = 78.292% 	 Sparsity = 68.543% 	 Test Loss = 0.598 	Test Acc = 79.670%
# Epoch 146/250 	 Loss = 0.628 	 Train Acc = 78.212% 	 Sparsity = 68.547% 	 Test Loss = 0.603 	Test Acc = 79.310%
# Epoch 147/250 	 Loss = 0.621 	 Train Acc = 78.346% 	 Sparsity = 68.594% 	 Test Loss = 0.625 	Test Acc = 78.780%
# Epoch 148/250 	 Loss = 0.621 	 Train Acc = 78.292% 	 Sparsity = 68.597% 	 Test Loss = 0.593 	Test Acc = 79.420%
# Epoch 149/250 	 Loss = 0.623 	 Train Acc = 78.256% 	 Sparsity = 68.605% 	 Test Loss = 0.583 	Test Acc = 79.860%
# Epoch 150/250 	 Loss = 0.622 	 Train Acc = 78.550% 	 Sparsity = 68.608% 	 Test Loss = 0.594 	Test Acc = 79.610%
# Epoch 151/250 	 Loss = 0.628 	 Train Acc = 78.166% 	 Sparsity = 68.617% 	 Test Loss = 0.627 	Test Acc = 78.430%
# Epoch 152/250 	 Loss = 0.620 	 Train Acc = 78.378% 	 Sparsity = 68.626% 	 Test Loss = 0.581 	Test Acc = 79.890%
# Epoch 153/250 	 Loss = 0.622 	 Train Acc = 78.394% 	 Sparsity = 68.646% 	 Test Loss = 0.611 	Test Acc = 79.090%
# Epoch 154/250 	 Loss = 0.628 	 Train Acc = 78.362% 	 Sparsity = 68.649% 	 Test Loss = 0.601 	Test Acc = 79.370%
# Epoch 155/250 	 Loss = 0.619 	 Train Acc = 78.440% 	 Sparsity = 68.651% 	 Test Loss = 0.574 	Test Acc = 80.080%
# Epoch 156/250 	 Loss = 0.624 	 Train Acc = 78.164% 	 Sparsity = 68.654% 	 Test Loss = 0.597 	Test Acc = 79.550%
# Epoch 157/250 	 Loss = 0.621 	 Train Acc = 78.440% 	 Sparsity = 68.672% 	 Test Loss = 0.589 	Test Acc = 79.630%
# Epoch 158/250 	 Loss = 0.622 	 Train Acc = 78.326% 	 Sparsity = 68.675% 	 Test Loss = 0.653 	Test Acc = 77.650%
# Epoch 159/250 	 Loss = 0.621 	 Train Acc = 78.282% 	 Sparsity = 68.702% 	 Test Loss = 0.582 	Test Acc = 79.980%
# Epoch 160/250 	 Loss = 0.621 	 Train Acc = 78.444% 	 Sparsity = 68.727% 	 Test Loss = 0.583 	Test Acc = 79.910%
# Epoch 161/250 	 Loss = 0.622 	 Train Acc = 78.410% 	 Sparsity = 68.729% 	 Test Loss = 0.601 	Test Acc = 79.400%
# Epoch 162/250 	 Loss = 0.624 	 Train Acc = 78.238% 	 Sparsity = 68.743% 	 Test Loss = 0.604 	Test Acc = 79.660%
# Epoch 163/250 	 Loss = 0.627 	 Train Acc = 78.160% 	 Sparsity = 68.746% 	 Test Loss = 0.590 	Test Acc = 79.920%
# Epoch 164/250 	 Loss = 0.622 	 Train Acc = 78.164% 	 Sparsity = 68.748% 	 Test Loss = 0.609 	Test Acc = 79.150%
# Epoch 165/250 	 Loss = 0.624 	 Train Acc = 78.250% 	 Sparsity = 68.750% 	 Test Loss = 0.592 	Test Acc = 79.850%
# Epoch 166/250 	 Loss = 0.625 	 Train Acc = 78.360% 	 Sparsity = 68.759% 	 Test Loss = 0.589 	Test Acc = 79.840%
# Epoch 167/250 	 Loss = 0.624 	 Train Acc = 78.096% 	 Sparsity = 68.760% 	 Test Loss = 0.591 	Test Acc = 79.680%
# Epoch 168/250 	 Loss = 0.624 	 Train Acc = 78.278% 	 Sparsity = 68.763% 	 Test Loss = 0.599 	Test Acc = 79.480%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8256/794337805.py in <module>
#      55             if n_bits > 0:
#      56                 model_copy = keras.models.clone_model(model)
# ---> 57                 model_copy.set_weights(model.get_weights())
#      58
#      59             #Quantização
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py in set_weights(self, weights)
#    1856         weight_index += 1
#    1857
# -> 1858     backend.batch_set_value(weight_value_tuples)
#    1859
#    1860     # Perform any layer defined finalization of the layer state.
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\backend.py in batch_set_value(tuples)
#    3928   if tf.compat.v1.executing_eagerly_outside_functions():
#    3929     for x, value in tuples:
# -> 3930       x.assign(np.asarray(value, dtype=dtype_numpy(x)))
#    3931   else:
#    3932     with get_graph().as_default():
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     914              f"assigned value shape {value_tensor.shape} are incompatible."))
#     915       assign_op = gen_resource_variable_ops.assign_variable_op(
# --> 916           self.handle, value_tensor, name=name)
#     917       if read_value:
#     918         return self._lazy_read(assign_op)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py in assign_variable_op(resource, value, name)
#     139     try:
#     140       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# --> 141         _ctx, "AssignVariableOp", name, resource, value)
#     142       return _result
#     143     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
for (i,layer) in enumerate(model.trainable_weights):
        if 'bn' in layer.name or 'bias' in layer.name:
            pass
        else:
            print(layer.name)
            a = tf.reshape(layer,[-1])
            b = a.numpy()
            
            plt.axvline(x=-bk[i],color='r')
            plt.hist(b,100)
            
            plt.axvline(x=bk[i],color='r')
            #plt.text(bk[i], 600, 'bk')
            #plt.text(-bk[i], 600, '-bk')
            plt.ylim([0,300])
            plt.show()
# Out:
# conv1/kernel:0
# conv2/kernel:0
# conv3/kernel:0
# conv4/kernel:0
# conv5/kernel:0
# conv6/kernel:0
# dense3/kernel:0
# dense4/kernel:0

# %%
import pandas as pd

data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_9.csv')

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
model = keras.models.load_model('test_9.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
for layer in model.layers:
    if layer.name == 'conv4':
        a = tf.reshape(layer.weights[0],[-1])
        b = a.numpy()
        plt.hist(b,200)
        plt.show()

        plt.hist(b,200)
        plt.ylim((0,150))
        plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
with tf.device('/device:CPU:0'):
    test_accuracy = tf.keras.metrics.Accuracy()
    logits = model(x_test, training=False)
    prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
    test_accuracy(prediction, y_test)
    print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 80.270%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# 2.7.0
# 1
# /device:GPU:0

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255
#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout_44 (Dropout)        (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_45 (Dropout)        (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_46 (Dropout)        (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_47 (Dropout)        (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 250
alpha = 0.5
n_bits = 4

learning_rate = 0.015
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_7.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0 and alpha > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0 and alpha > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_5.csv')
# Out:
# Created Tensor of velocity
# Epoch 1/250 	 Loss = 1.735 	 Train Acc = 39.436% 	 Sparsity = 44.249% 	 Test Loss = 1.434 	Test Acc = 47.870%
# New test accuracy is 47.870%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/250 	 Loss = 1.322 	 Train Acc = 51.806% 	 Sparsity = 46.871% 	 Test Loss = 1.162 	Test Acc = 59.260%
# New test accuracy is 59.260%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/250 	 Loss = 1.160 	 Train Acc = 58.506% 	 Sparsity = 48.628% 	 Test Loss = 1.057 	Test Acc = 62.910%
# New test accuracy is 62.910%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/250 	 Loss = 1.060 	 Train Acc = 62.536% 	 Sparsity = 49.706% 	 Test Loss = 0.979 	Test Acc = 65.100%
# New test accuracy is 65.100%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 5/250 	 Loss = 0.980 	 Train Acc = 65.246% 	 Sparsity = 50.471% 	 Test Loss = 0.871 	Test Acc = 69.720%
# New test accuracy is 69.720%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/250 	 Loss = 0.934 	 Train Acc = 67.318% 	 Sparsity = 51.046% 	 Test Loss = 0.874 	Test Acc = 69.590%
# Epoch 7/250 	 Loss = 0.902 	 Train Acc = 68.628% 	 Sparsity = 51.445% 	 Test Loss = 0.803 	Test Acc = 71.840%
# New test accuracy is 71.840%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/250 	 Loss = 0.866 	 Train Acc = 69.802% 	 Sparsity = 51.773% 	 Test Loss = 0.787 	Test Acc = 72.520%
# New test accuracy is 72.520%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/250 	 Loss = 0.839 	 Train Acc = 70.836% 	 Sparsity = 52.039% 	 Test Loss = 0.813 	Test Acc = 71.660%
# Epoch 10/250 	 Loss = 0.827 	 Train Acc = 71.248% 	 Sparsity = 52.258% 	 Test Loss = 0.816 	Test Acc = 71.570%
# Epoch 11/250 	 Loss = 0.811 	 Train Acc = 71.728% 	 Sparsity = 52.448% 	 Test Loss = 0.757 	Test Acc = 74.000%
# New test accuracy is 74.000%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 12/250 	 Loss = 0.796 	 Train Acc = 72.440% 	 Sparsity = 52.603% 	 Test Loss = 0.778 	Test Acc = 73.420%
# Epoch 13/250 	 Loss = 0.787 	 Train Acc = 72.824% 	 Sparsity = 52.757% 	 Test Loss = 0.729 	Test Acc = 74.620%
# New test accuracy is 74.620%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 14/250 	 Loss = 0.777 	 Train Acc = 72.898% 	 Sparsity = 52.876% 	 Test Loss = 0.762 	Test Acc = 72.840%
# Epoch 15/250 	 Loss = 0.772 	 Train Acc = 73.098% 	 Sparsity = 52.970% 	 Test Loss = 0.690 	Test Acc = 75.870%
# New test accuracy is 75.870%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 16/250 	 Loss = 0.760 	 Train Acc = 73.588% 	 Sparsity = 53.048% 	 Test Loss = 0.685 	Test Acc = 76.080%
# New test accuracy is 76.080%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 17/250 	 Loss = 0.756 	 Train Acc = 73.788% 	 Sparsity = 53.114% 	 Test Loss = 0.734 	Test Acc = 74.510%
# Epoch 18/250 	 Loss = 0.753 	 Train Acc = 73.894% 	 Sparsity = 53.164% 	 Test Loss = 0.680 	Test Acc = 75.850%
# Epoch 19/250 	 Loss = 0.741 	 Train Acc = 74.314% 	 Sparsity = 53.204% 	 Test Loss = 0.691 	Test Acc = 75.890%
# Epoch 20/250 	 Loss = 0.743 	 Train Acc = 74.118% 	 Sparsity = 53.237% 	 Test Loss = 0.696 	Test Acc = 76.070%
# Epoch 21/250 	 Loss = 0.742 	 Train Acc = 74.302% 	 Sparsity = 53.265% 	 Test Loss = 0.686 	Test Acc = 76.310%
# New test accuracy is 76.310%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 22/250 	 Loss = 0.742 	 Train Acc = 74.480% 	 Sparsity = 53.285% 	 Test Loss = 0.720 	Test Acc = 75.450%
# Epoch 23/250 	 Loss = 0.741 	 Train Acc = 74.480% 	 Sparsity = 53.303% 	 Test Loss = 0.674 	Test Acc = 76.580%
# New test accuracy is 76.580%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 24/250 	 Loss = 0.734 	 Train Acc = 74.862% 	 Sparsity = 53.316% 	 Test Loss = 0.708 	Test Acc = 75.400%
# Epoch 25/250 	 Loss = 0.733 	 Train Acc = 74.742% 	 Sparsity = 53.326% 	 Test Loss = 0.685 	Test Acc = 76.330%
# Epoch 26/250 	 Loss = 0.729 	 Train Acc = 74.716% 	 Sparsity = 53.338% 	 Test Loss = 0.702 	Test Acc = 75.600%
# Epoch 27/250 	 Loss = 0.727 	 Train Acc = 74.830% 	 Sparsity = 53.346% 	 Test Loss = 0.658 	Test Acc = 76.990%
# New test accuracy is 76.990%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 28/250 	 Loss = 0.728 	 Train Acc = 74.704% 	 Sparsity = 53.354% 	 Test Loss = 0.657 	Test Acc = 77.180%
# New test accuracy is 77.180%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 29/250 	 Loss = 0.727 	 Train Acc = 74.836% 	 Sparsity = 53.361% 	 Test Loss = 0.662 	Test Acc = 77.360%
# New test accuracy is 77.360%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 30/250 	 Loss = 0.727 	 Train Acc = 74.942% 	 Sparsity = 53.368% 	 Test Loss = 0.663 	Test Acc = 77.190%
# Epoch 31/250 	 Loss = 0.724 	 Train Acc = 74.942% 	 Sparsity = 53.374% 	 Test Loss = 0.671 	Test Acc = 76.720%
# Epoch 32/250 	 Loss = 0.722 	 Train Acc = 75.186% 	 Sparsity = 53.381% 	 Test Loss = 0.649 	Test Acc = 77.690%
# New test accuracy is 77.690%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 33/250 	 Loss = 0.725 	 Train Acc = 74.800% 	 Sparsity = 53.387% 	 Test Loss = 0.674 	Test Acc = 76.540%
# Epoch 34/250 	 Loss = 0.719 	 Train Acc = 75.216% 	 Sparsity = 53.393% 	 Test Loss = 0.642 	Test Acc = 77.140%
# Epoch 35/250 	 Loss = 0.712 	 Train Acc = 75.196% 	 Sparsity = 53.399% 	 Test Loss = 0.654 	Test Acc = 77.250%
# Epoch 36/250 	 Loss = 0.719 	 Train Acc = 75.058% 	 Sparsity = 53.405% 	 Test Loss = 0.642 	Test Acc = 77.540%
# Epoch 37/250 	 Loss = 0.718 	 Train Acc = 75.086% 	 Sparsity = 53.412% 	 Test Loss = 0.669 	Test Acc = 76.750%
# Epoch 38/250 	 Loss = 0.716 	 Train Acc = 75.154% 	 Sparsity = 53.417% 	 Test Loss = 0.673 	Test Acc = 76.680%
# Epoch 39/250 	 Loss = 0.716 	 Train Acc = 75.442% 	 Sparsity = 53.423% 	 Test Loss = 0.644 	Test Acc = 77.190%
# Epoch 40/250 	 Loss = 0.716 	 Train Acc = 74.966% 	 Sparsity = 53.429% 	 Test Loss = 0.632 	Test Acc = 78.100%
# New test accuracy is 78.100%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 41/250 	 Loss = 0.712 	 Train Acc = 75.404% 	 Sparsity = 53.434% 	 Test Loss = 0.648 	Test Acc = 77.630%
# Epoch 42/250 	 Loss = 0.714 	 Train Acc = 75.410% 	 Sparsity = 53.438% 	 Test Loss = 0.651 	Test Acc = 77.450%
# Epoch 43/250 	 Loss = 0.715 	 Train Acc = 75.268% 	 Sparsity = 53.442% 	 Test Loss = 0.650 	Test Acc = 77.680%
# Epoch 44/250 	 Loss = 0.715 	 Train Acc = 75.368% 	 Sparsity = 53.447% 	 Test Loss = 0.653 	Test Acc = 77.380%
# Epoch 45/250 	 Loss = 0.711 	 Train Acc = 75.422% 	 Sparsity = 53.450% 	 Test Loss = 0.663 	Test Acc = 77.010%
# Epoch 46/250 	 Loss = 0.712 	 Train Acc = 75.246% 	 Sparsity = 53.452% 	 Test Loss = 0.666 	Test Acc = 76.830%
# Epoch 47/250 	 Loss = 0.708 	 Train Acc = 75.530% 	 Sparsity = 53.454% 	 Test Loss = 0.627 	Test Acc = 78.090%
# Epoch 48/250 	 Loss = 0.711 	 Train Acc = 75.448% 	 Sparsity = 53.457% 	 Test Loss = 0.646 	Test Acc = 77.500%
# Epoch 49/250 	 Loss = 0.713 	 Train Acc = 75.348% 	 Sparsity = 53.460% 	 Test Loss = 0.654 	Test Acc = 77.070%
# Epoch 50/250 	 Loss = 0.713 	 Train Acc = 75.270% 	 Sparsity = 53.462% 	 Test Loss = 0.636 	Test Acc = 77.770%
# Epoch 51/250 	 Loss = 0.712 	 Train Acc = 75.284% 	 Sparsity = 53.465% 	 Test Loss = 0.677 	Test Acc = 76.480%
# Epoch 52/250 	 Loss = 0.707 	 Train Acc = 75.458% 	 Sparsity = 53.468% 	 Test Loss = 0.658 	Test Acc = 77.290%
# Epoch 53/250 	 Loss = 0.710 	 Train Acc = 75.530% 	 Sparsity = 53.470% 	 Test Loss = 0.645 	Test Acc = 77.490%
# Epoch 54/250 	 Loss = 0.708 	 Train Acc = 75.650% 	 Sparsity = 53.473% 	 Test Loss = 0.660 	Test Acc = 77.210%
# Epoch 55/250 	 Loss = 0.710 	 Train Acc = 75.442% 	 Sparsity = 53.476% 	 Test Loss = 0.638 	Test Acc = 77.990%
# Epoch 56/250 	 Loss = 0.711 	 Train Acc = 75.222% 	 Sparsity = 53.479% 	 Test Loss = 0.653 	Test Acc = 77.310%
# Epoch 57/250 	 Loss = 0.711 	 Train Acc = 75.410% 	 Sparsity = 53.482% 	 Test Loss = 0.647 	Test Acc = 77.630%
# Epoch 58/250 	 Loss = 0.711 	 Train Acc = 75.542% 	 Sparsity = 53.484% 	 Test Loss = 0.639 	Test Acc = 77.490%
# Epoch 59/250 	 Loss = 0.709 	 Train Acc = 75.526% 	 Sparsity = 53.486% 	 Test Loss = 0.640 	Test Acc = 77.700%
# Epoch 60/250 	 Loss = 0.707 	 Train Acc = 75.456% 	 Sparsity = 53.489% 	 Test Loss = 0.656 	Test Acc = 77.530%
# Epoch 61/250 	 Loss = 0.712 	 Train Acc = 75.540% 	 Sparsity = 53.491% 	 Test Loss = 0.634 	Test Acc = 77.770%
# Epoch 62/250 	 Loss = 0.708 	 Train Acc = 75.592% 	 Sparsity = 53.493% 	 Test Loss = 0.630 	Test Acc = 78.310%
# New test accuracy is 78.310%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 63/250 	 Loss = 0.709 	 Train Acc = 75.438% 	 Sparsity = 53.495% 	 Test Loss = 0.646 	Test Acc = 77.640%
# Epoch 64/250 	 Loss = 0.709 	 Train Acc = 75.512% 	 Sparsity = 53.497% 	 Test Loss = 0.628 	Test Acc = 78.400%
# New test accuracy is 78.400%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 65/250 	 Loss = 0.712 	 Train Acc = 75.184% 	 Sparsity = 53.498% 	 Test Loss = 0.650 	Test Acc = 77.820%
# Epoch 66/250 	 Loss = 0.709 	 Train Acc = 75.654% 	 Sparsity = 53.500% 	 Test Loss = 0.640 	Test Acc = 78.090%
# Epoch 67/250 	 Loss = 0.711 	 Train Acc = 75.302% 	 Sparsity = 53.501% 	 Test Loss = 0.649 	Test Acc = 77.480%
# Epoch 68/250 	 Loss = 0.711 	 Train Acc = 75.392% 	 Sparsity = 53.502% 	 Test Loss = 0.638 	Test Acc = 77.630%
# Epoch 69/250 	 Loss = 0.711 	 Train Acc = 75.606% 	 Sparsity = 53.504% 	 Test Loss = 0.641 	Test Acc = 77.640%
# Epoch 70/250 	 Loss = 0.710 	 Train Acc = 75.552% 	 Sparsity = 53.505% 	 Test Loss = 0.627 	Test Acc = 78.050%
# Epoch 71/250 	 Loss = 0.712 	 Train Acc = 75.182% 	 Sparsity = 53.506% 	 Test Loss = 0.631 	Test Acc = 77.650%
# Epoch 72/250 	 Loss = 0.709 	 Train Acc = 75.428% 	 Sparsity = 53.507% 	 Test Loss = 0.632 	Test Acc = 78.180%
# Epoch 73/250 	 Loss = 0.708 	 Train Acc = 75.564% 	 Sparsity = 53.507% 	 Test Loss = 0.642 	Test Acc = 77.970%
# Epoch 74/250 	 Loss = 0.707 	 Train Acc = 75.524% 	 Sparsity = 53.508% 	 Test Loss = 0.636 	Test Acc = 77.840%
# Epoch 75/250 	 Loss = 0.713 	 Train Acc = 75.272% 	 Sparsity = 53.509% 	 Test Loss = 0.629 	Test Acc = 78.270%
# Epoch 76/250 	 Loss = 0.708 	 Train Acc = 75.384% 	 Sparsity = 53.510% 	 Test Loss = 0.624 	Test Acc = 78.200%
# Epoch 77/250 	 Loss = 0.714 	 Train Acc = 75.420% 	 Sparsity = 53.511% 	 Test Loss = 0.634 	Test Acc = 78.080%
# Epoch 78/250 	 Loss = 0.723 	 Train Acc = 74.912% 	 Sparsity = 53.512% 	 Test Loss = 0.644 	Test Acc = 77.650%
# Epoch 79/250 	 Loss = 0.713 	 Train Acc = 75.488% 	 Sparsity = 53.513% 	 Test Loss = 0.643 	Test Acc = 77.870%
# Epoch 80/250 	 Loss = 0.710 	 Train Acc = 75.488% 	 Sparsity = 53.514% 	 Test Loss = 0.639 	Test Acc = 77.900%
# Epoch 81/250 	 Loss = 0.708 	 Train Acc = 75.442% 	 Sparsity = 53.515% 	 Test Loss = 0.627 	Test Acc = 78.100%
# Epoch 82/250 	 Loss = 0.707 	 Train Acc = 75.472% 	 Sparsity = 53.517% 	 Test Loss = 0.636 	Test Acc = 77.760%
# Epoch 83/250 	 Loss = 0.718 	 Train Acc = 74.976% 	 Sparsity = 53.518% 	 Test Loss = 0.659 	Test Acc = 77.210%
# Epoch 84/250 	 Loss = 0.714 	 Train Acc = 75.292% 	 Sparsity = 53.520% 	 Test Loss = 0.643 	Test Acc = 77.380%
# Epoch 85/250 	 Loss = 0.715 	 Train Acc = 75.340% 	 Sparsity = 53.521% 	 Test Loss = 0.642 	Test Acc = 77.620%
# Epoch 86/250 	 Loss = 0.711 	 Train Acc = 75.190% 	 Sparsity = 53.523% 	 Test Loss = 0.669 	Test Acc = 76.770%
# Epoch 87/250 	 Loss = 0.711 	 Train Acc = 75.442% 	 Sparsity = 53.524% 	 Test Loss = 0.641 	Test Acc = 77.710%
# Epoch 88/250 	 Loss = 0.717 	 Train Acc = 75.146% 	 Sparsity = 53.525% 	 Test Loss = 0.632 	Test Acc = 77.980%
# Epoch 89/250 	 Loss = 0.718 	 Train Acc = 75.110% 	 Sparsity = 53.526% 	 Test Loss = 0.648 	Test Acc = 77.490%
# Epoch 90/250 	 Loss = 0.719 	 Train Acc = 75.214% 	 Sparsity = 53.527% 	 Test Loss = 0.649 	Test Acc = 77.380%
# Epoch 91/250 	 Loss = 0.720 	 Train Acc = 74.762% 	 Sparsity = 53.528% 	 Test Loss = 0.647 	Test Acc = 77.290%
# Epoch 92/250 	 Loss = 0.711 	 Train Acc = 75.278% 	 Sparsity = 53.529% 	 Test Loss = 0.629 	Test Acc = 77.910%
# Epoch 93/250 	 Loss = 0.714 	 Train Acc = 75.160% 	 Sparsity = 53.530% 	 Test Loss = 0.651 	Test Acc = 77.340%
# Epoch 94/250 	 Loss = 0.715 	 Train Acc = 75.216% 	 Sparsity = 53.531% 	 Test Loss = 0.649 	Test Acc = 77.370%
# Epoch 95/250 	 Loss = 0.716 	 Train Acc = 75.114% 	 Sparsity = 53.532% 	 Test Loss = 0.628 	Test Acc = 77.980%
# Epoch 96/250 	 Loss = 0.719 	 Train Acc = 74.982% 	 Sparsity = 53.534% 	 Test Loss = 0.635 	Test Acc = 77.850%
# Epoch 97/250 	 Loss = 0.719 	 Train Acc = 75.072% 	 Sparsity = 53.535% 	 Test Loss = 0.639 	Test Acc = 77.580%
# Epoch 98/250 	 Loss = 0.724 	 Train Acc = 74.748% 	 Sparsity = 53.536% 	 Test Loss = 0.639 	Test Acc = 77.330%
# Epoch 99/250 	 Loss = 0.717 	 Train Acc = 75.172% 	 Sparsity = 53.537% 	 Test Loss = 0.639 	Test Acc = 77.650%
# Epoch 100/250 	 Loss = 0.716 	 Train Acc = 75.044% 	 Sparsity = 53.538% 	 Test Loss = 0.656 	Test Acc = 77.440%
# Epoch 101/250 	 Loss = 0.721 	 Train Acc = 75.004% 	 Sparsity = 53.539% 	 Test Loss = 0.664 	Test Acc = 76.900%
# Epoch 102/250 	 Loss = 0.715 	 Train Acc = 75.264% 	 Sparsity = 53.540% 	 Test Loss = 0.655 	Test Acc = 77.210%
# Epoch 103/250 	 Loss = 0.722 	 Train Acc = 75.050% 	 Sparsity = 53.541% 	 Test Loss = 0.654 	Test Acc = 77.140%
# Epoch 104/250 	 Loss = 0.721 	 Train Acc = 74.956% 	 Sparsity = 53.542% 	 Test Loss = 0.639 	Test Acc = 77.760%
# Epoch 105/250 	 Loss = 0.718 	 Train Acc = 75.004% 	 Sparsity = 53.543% 	 Test Loss = 0.633 	Test Acc = 77.860%
# Epoch 106/250 	 Loss = 0.722 	 Train Acc = 74.998% 	 Sparsity = 53.544% 	 Test Loss = 0.653 	Test Acc = 77.180%
# Epoch 107/250 	 Loss = 0.716 	 Train Acc = 75.242% 	 Sparsity = 53.546% 	 Test Loss = 0.642 	Test Acc = 77.460%
# Epoch 108/250 	 Loss = 0.724 	 Train Acc = 75.018% 	 Sparsity = 53.547% 	 Test Loss = 0.638 	Test Acc = 77.690%
# Epoch 109/250 	 Loss = 0.722 	 Train Acc = 75.010% 	 Sparsity = 53.548% 	 Test Loss = 0.641 	Test Acc = 77.510%
# Epoch 110/250 	 Loss = 0.720 	 Train Acc = 74.824% 	 Sparsity = 53.549% 	 Test Loss = 0.641 	Test Acc = 77.670%
# Epoch 111/250 	 Loss = 0.721 	 Train Acc = 75.144% 	 Sparsity = 53.550% 	 Test Loss = 0.643 	Test Acc = 77.600%
# Epoch 112/250 	 Loss = 0.723 	 Train Acc = 74.768% 	 Sparsity = 53.551% 	 Test Loss = 0.652 	Test Acc = 77.390%
# Epoch 113/250 	 Loss = 0.721 	 Train Acc = 75.006% 	 Sparsity = 53.552% 	 Test Loss = 0.653 	Test Acc = 77.370%
# Epoch 114/250 	 Loss = 0.723 	 Train Acc = 74.948% 	 Sparsity = 53.553% 	 Test Loss = 0.663 	Test Acc = 76.810%
# Epoch 115/250 	 Loss = 0.725 	 Train Acc = 74.984% 	 Sparsity = 53.554% 	 Test Loss = 0.660 	Test Acc = 77.270%
# Epoch 116/250 	 Loss = 0.721 	 Train Acc = 74.886% 	 Sparsity = 53.555% 	 Test Loss = 0.656 	Test Acc = 77.140%
# Epoch 117/250 	 Loss = 0.723 	 Train Acc = 74.884% 	 Sparsity = 53.556% 	 Test Loss = 0.635 	Test Acc = 77.940%
# Epoch 118/250 	 Loss = 0.722 	 Train Acc = 75.190% 	 Sparsity = 53.557% 	 Test Loss = 0.654 	Test Acc = 77.160%
# Epoch 119/250 	 Loss = 0.723 	 Train Acc = 75.096% 	 Sparsity = 53.558% 	 Test Loss = 0.660 	Test Acc = 77.240%
# Epoch 120/250 	 Loss = 0.728 	 Train Acc = 75.166% 	 Sparsity = 53.559% 	 Test Loss = 0.653 	Test Acc = 77.390%
# Epoch 121/250 	 Loss = 0.720 	 Train Acc = 75.112% 	 Sparsity = 53.560% 	 Test Loss = 0.650 	Test Acc = 77.340%
# Epoch 122/250 	 Loss = 0.724 	 Train Acc = 74.942% 	 Sparsity = 53.560% 	 Test Loss = 0.649 	Test Acc = 77.310%
# Epoch 123/250 	 Loss = 0.727 	 Train Acc = 74.946% 	 Sparsity = 53.561% 	 Test Loss = 0.648 	Test Acc = 77.430%
# Epoch 124/250 	 Loss = 0.720 	 Train Acc = 75.132% 	 Sparsity = 53.561% 	 Test Loss = 0.635 	Test Acc = 78.010%
# Epoch 125/250 	 Loss = 0.723 	 Train Acc = 75.168% 	 Sparsity = 53.562% 	 Test Loss = 0.661 	Test Acc = 76.860%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2964/2722340303.py in <module>
#      63                         pass
#      64                     else:
# ---> 65                         qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
#      66                         ck = tf.math.round(layer_weights / qk_line) * qk_line
#      67                         layer_weights.assign(ck)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# KeyboardInterrupt:

# %%
l = len(model.trainable_weights)
for i in range(l):
  a = tf.reshape(model.trainable_weights[i],[-1])
  b = a.numpy()
  #print(a)
  #plt.ylim(0,300)
  plt.title(str(i))
  plt.hist(b,200)
  plt.show()

# %%
import pandas as pd

data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_7.csv')

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
model = keras.models.load_model('test_7.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
for layer in model.layers:
    if layer.name == 'conv1':
        a = tf.reshape(layer.weights[0],[-1])
        b = a.numpy()
        plt.hist(b,200)
        plt.show()

        plt.hist(b,200)
        plt.ylim((0,150))
        plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
with tf.device('/device:CPU:0'):
    test_accuracy = tf.keras.metrics.Accuracy()
    logits = model(x_test, training=False)
    prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
    test_accuracy(prediction, y_test)
    print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 78.390%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

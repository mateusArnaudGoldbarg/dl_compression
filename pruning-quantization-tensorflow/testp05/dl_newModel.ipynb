# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.7.0
# 1

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255

#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout (Dropout)           (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_1 (Dropout)         (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_2 (Dropout)         (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_3 (Dropout)         (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 250
alpha = 0.5
n_bits = 0

learning_rate = 0.015
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_p05.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        #bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_p05.csv')
# Out:
# Created Tensor of velocity
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Epoch 1/250 	 Loss = 1.677 	 Train Acc = 41.662% 	 Sparsity = 43.978% 	 Test Loss = 1.252 	Test Acc = 54.820%
# New test accuracy is 54.820%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/250 	 Loss = 1.241 	 Train Acc = 55.296% 	 Sparsity = 45.917% 	 Test Loss = 1.025 	Test Acc = 63.750%
# New test accuracy is 63.750%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/250 	 Loss = 1.092 	 Train Acc = 61.118% 	 Sparsity = 47.235% 	 Test Loss = 0.925 	Test Acc = 67.080%
# New test accuracy is 67.080%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/250 	 Loss = 0.992 	 Train Acc = 64.998% 	 Sparsity = 48.266% 	 Test Loss = 0.856 	Test Acc = 69.420%
# New test accuracy is 69.420%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 5/250 	 Loss = 0.921 	 Train Acc = 67.572% 	 Sparsity = 49.103% 	 Test Loss = 0.833 	Test Acc = 70.660%
# New test accuracy is 70.660%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/250 	 Loss = 0.869 	 Train Acc = 69.620% 	 Sparsity = 49.814% 	 Test Loss = 0.769 	Test Acc = 72.790%
# New test accuracy is 72.790%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/250 	 Loss = 0.829 	 Train Acc = 70.886% 	 Sparsity = 50.396% 	 Test Loss = 0.728 	Test Acc = 74.960%
# New test accuracy is 74.960%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/250 	 Loss = 0.792 	 Train Acc = 72.524% 	 Sparsity = 50.908% 	 Test Loss = 0.779 	Test Acc = 73.510%
# Epoch 9/250 	 Loss = 0.758 	 Train Acc = 73.716% 	 Sparsity = 51.369% 	 Test Loss = 0.686 	Test Acc = 75.650%
# New test accuracy is 75.650%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 10/250 	 Loss = 0.738 	 Train Acc = 74.250% 	 Sparsity = 51.780% 	 Test Loss = 0.748 	Test Acc = 74.230%
# Epoch 11/250 	 Loss = 0.722 	 Train Acc = 74.994% 	 Sparsity = 52.153% 	 Test Loss = 0.644 	Test Acc = 77.610%
# New test accuracy is 77.610%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 12/250 	 Loss = 0.701 	 Train Acc = 75.634% 	 Sparsity = 52.481% 	 Test Loss = 0.630 	Test Acc = 77.900%
# New test accuracy is 77.900%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 13/250 	 Loss = 0.683 	 Train Acc = 76.138% 	 Sparsity = 52.785% 	 Test Loss = 0.656 	Test Acc = 77.570%
# Epoch 14/250 	 Loss = 0.672 	 Train Acc = 76.898% 	 Sparsity = 53.053% 	 Test Loss = 0.668 	Test Acc = 77.020%
# Epoch 15/250 	 Loss = 0.668 	 Train Acc = 76.760% 	 Sparsity = 53.297% 	 Test Loss = 0.623 	Test Acc = 78.490%
# New test accuracy is 78.490%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 16/250 	 Loss = 0.656 	 Train Acc = 77.108% 	 Sparsity = 53.527% 	 Test Loss = 0.601 	Test Acc = 79.390%
# New test accuracy is 79.390%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 17/250 	 Loss = 0.648 	 Train Acc = 77.440% 	 Sparsity = 53.737% 	 Test Loss = 0.595 	Test Acc = 79.620%
# New test accuracy is 79.620%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 18/250 	 Loss = 0.638 	 Train Acc = 77.916% 	 Sparsity = 53.933% 	 Test Loss = 0.590 	Test Acc = 79.910%
# New test accuracy is 79.910%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 19/250 	 Loss = 0.630 	 Train Acc = 78.190% 	 Sparsity = 54.105% 	 Test Loss = 0.582 	Test Acc = 79.910%
# Epoch 20/250 	 Loss = 0.623 	 Train Acc = 78.356% 	 Sparsity = 54.278% 	 Test Loss = 0.592 	Test Acc = 79.690%
# Epoch 21/250 	 Loss = 0.620 	 Train Acc = 78.542% 	 Sparsity = 54.436% 	 Test Loss = 0.630 	Test Acc = 78.640%
# Epoch 22/250 	 Loss = 0.614 	 Train Acc = 78.680% 	 Sparsity = 54.587% 	 Test Loss = 0.591 	Test Acc = 79.870%
# Epoch 23/250 	 Loss = 0.607 	 Train Acc = 78.950% 	 Sparsity = 54.731% 	 Test Loss = 0.583 	Test Acc = 79.860%
# Epoch 24/250 	 Loss = 0.600 	 Train Acc = 79.076% 	 Sparsity = 54.864% 	 Test Loss = 0.626 	Test Acc = 78.660%
# Epoch 25/250 	 Loss = 0.597 	 Train Acc = 79.190% 	 Sparsity = 54.987% 	 Test Loss = 0.572 	Test Acc = 80.510%
# New test accuracy is 80.510%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 26/250 	 Loss = 0.595 	 Train Acc = 79.274% 	 Sparsity = 55.105% 	 Test Loss = 0.598 	Test Acc = 79.780%
# Epoch 27/250 	 Loss = 0.592 	 Train Acc = 79.212% 	 Sparsity = 55.218% 	 Test Loss = 0.563 	Test Acc = 80.440%
# Epoch 28/250 	 Loss = 0.591 	 Train Acc = 79.402% 	 Sparsity = 55.323% 	 Test Loss = 0.590 	Test Acc = 80.050%
# Epoch 29/250 	 Loss = 0.586 	 Train Acc = 79.664% 	 Sparsity = 55.422% 	 Test Loss = 0.572 	Test Acc = 80.520%
# New test accuracy is 80.520%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 30/250 	 Loss = 0.578 	 Train Acc = 79.918% 	 Sparsity = 55.517% 	 Test Loss = 0.592 	Test Acc = 79.720%
# Epoch 31/250 	 Loss = 0.576 	 Train Acc = 79.936% 	 Sparsity = 55.613% 	 Test Loss = 0.595 	Test Acc = 79.780%
# Epoch 32/250 	 Loss = 0.575 	 Train Acc = 79.816% 	 Sparsity = 55.704% 	 Test Loss = 0.550 	Test Acc = 81.170%
# New test accuracy is 81.170%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 33/250 	 Loss = 0.576 	 Train Acc = 80.006% 	 Sparsity = 55.787% 	 Test Loss = 0.611 	Test Acc = 79.210%
# Epoch 34/250 	 Loss = 0.571 	 Train Acc = 80.228% 	 Sparsity = 55.865% 	 Test Loss = 0.590 	Test Acc = 79.940%
# Epoch 35/250 	 Loss = 0.574 	 Train Acc = 80.172% 	 Sparsity = 55.940% 	 Test Loss = 0.588 	Test Acc = 79.950%
# Epoch 36/250 	 Loss = 0.571 	 Train Acc = 80.164% 	 Sparsity = 56.015% 	 Test Loss = 0.600 	Test Acc = 79.530%
# Epoch 37/250 	 Loss = 0.566 	 Train Acc = 80.490% 	 Sparsity = 56.085% 	 Test Loss = 0.557 	Test Acc = 80.820%
# Epoch 38/250 	 Loss = 0.562 	 Train Acc = 80.472% 	 Sparsity = 56.151% 	 Test Loss = 0.564 	Test Acc = 81.120%
# Epoch 39/250 	 Loss = 0.555 	 Train Acc = 80.690% 	 Sparsity = 56.217% 	 Test Loss = 0.555 	Test Acc = 80.930%
# Epoch 40/250 	 Loss = 0.558 	 Train Acc = 80.796% 	 Sparsity = 56.279% 	 Test Loss = 0.557 	Test Acc = 80.710%
# Epoch 41/250 	 Loss = 0.554 	 Train Acc = 80.732% 	 Sparsity = 56.338% 	 Test Loss = 0.563 	Test Acc = 81.230%
# New test accuracy is 81.230%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 42/250 	 Loss = 0.559 	 Train Acc = 80.594% 	 Sparsity = 56.397% 	 Test Loss = 0.553 	Test Acc = 81.130%
# Epoch 43/250 	 Loss = 0.552 	 Train Acc = 80.878% 	 Sparsity = 56.452% 	 Test Loss = 0.593 	Test Acc = 80.170%
# Epoch 44/250 	 Loss = 0.553 	 Train Acc = 80.706% 	 Sparsity = 56.507% 	 Test Loss = 0.553 	Test Acc = 81.450%
# New test accuracy is 81.450%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 45/250 	 Loss = 0.545 	 Train Acc = 81.022% 	 Sparsity = 56.562% 	 Test Loss = 0.603 	Test Acc = 80.030%
# Epoch 46/250 	 Loss = 0.549 	 Train Acc = 80.836% 	 Sparsity = 56.616% 	 Test Loss = 0.562 	Test Acc = 81.250%
# Epoch 47/250 	 Loss = 0.553 	 Train Acc = 80.780% 	 Sparsity = 56.668% 	 Test Loss = 0.554 	Test Acc = 81.390%
# Epoch 48/250 	 Loss = 0.548 	 Train Acc = 81.002% 	 Sparsity = 56.718% 	 Test Loss = 0.584 	Test Acc = 80.680%
# Epoch 49/250 	 Loss = 0.546 	 Train Acc = 81.018% 	 Sparsity = 56.765% 	 Test Loss = 0.582 	Test Acc = 80.320%
# Epoch 50/250 	 Loss = 0.547 	 Train Acc = 80.736% 	 Sparsity = 56.811% 	 Test Loss = 0.554 	Test Acc = 81.430%
# Epoch 51/250 	 Loss = 0.541 	 Train Acc = 81.244% 	 Sparsity = 56.857% 	 Test Loss = 0.579 	Test Acc = 80.340%
# Epoch 52/250 	 Loss = 0.544 	 Train Acc = 81.038% 	 Sparsity = 56.901% 	 Test Loss = 0.589 	Test Acc = 80.310%
# Epoch 53/250 	 Loss = 0.542 	 Train Acc = 81.124% 	 Sparsity = 56.942% 	 Test Loss = 0.573 	Test Acc = 80.770%
# Epoch 54/250 	 Loss = 0.544 	 Train Acc = 81.010% 	 Sparsity = 56.983% 	 Test Loss = 0.550 	Test Acc = 81.600%
# New test accuracy is 81.600%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 55/250 	 Loss = 0.537 	 Train Acc = 81.364% 	 Sparsity = 57.022% 	 Test Loss = 0.539 	Test Acc = 81.700%
# New test accuracy is 81.700%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 56/250 	 Loss = 0.544 	 Train Acc = 81.078% 	 Sparsity = 57.060% 	 Test Loss = 0.613 	Test Acc = 79.560%
# Epoch 57/250 	 Loss = 0.529 	 Train Acc = 81.514% 	 Sparsity = 57.098% 	 Test Loss = 0.582 	Test Acc = 80.820%
# Epoch 58/250 	 Loss = 0.537 	 Train Acc = 81.238% 	 Sparsity = 57.135% 	 Test Loss = 0.549 	Test Acc = 81.440%
# Epoch 59/250 	 Loss = 0.535 	 Train Acc = 81.424% 	 Sparsity = 57.172% 	 Test Loss = 0.585 	Test Acc = 80.920%
# Epoch 60/250 	 Loss = 0.534 	 Train Acc = 81.340% 	 Sparsity = 57.210% 	 Test Loss = 0.585 	Test Acc = 80.510%
# Epoch 61/250 	 Loss = 0.534 	 Train Acc = 81.272% 	 Sparsity = 57.247% 	 Test Loss = 0.589 	Test Acc = 80.530%
# Epoch 62/250 	 Loss = 0.532 	 Train Acc = 81.330% 	 Sparsity = 57.281% 	 Test Loss = 0.548 	Test Acc = 81.960%
# New test accuracy is 81.960%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 63/250 	 Loss = 0.531 	 Train Acc = 81.330% 	 Sparsity = 57.315% 	 Test Loss = 0.565 	Test Acc = 81.170%
# Epoch 64/250 	 Loss = 0.530 	 Train Acc = 81.780% 	 Sparsity = 57.349% 	 Test Loss = 0.576 	Test Acc = 80.660%
# Epoch 65/250 	 Loss = 0.530 	 Train Acc = 81.546% 	 Sparsity = 57.381% 	 Test Loss = 0.535 	Test Acc = 81.940%
# Epoch 66/250 	 Loss = 0.535 	 Train Acc = 81.358% 	 Sparsity = 57.413% 	 Test Loss = 0.536 	Test Acc = 81.990%
# New test accuracy is 81.990%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 67/250 	 Loss = 0.531 	 Train Acc = 81.560% 	 Sparsity = 57.446% 	 Test Loss = 0.558 	Test Acc = 81.480%
# Epoch 68/250 	 Loss = 0.534 	 Train Acc = 81.262% 	 Sparsity = 57.477% 	 Test Loss = 0.531 	Test Acc = 82.000%
# New test accuracy is 82.000%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 69/250 	 Loss = 0.533 	 Train Acc = 81.430% 	 Sparsity = 57.506% 	 Test Loss = 0.544 	Test Acc = 81.670%
# Epoch 70/250 	 Loss = 0.531 	 Train Acc = 81.414% 	 Sparsity = 57.535% 	 Test Loss = 0.570 	Test Acc = 81.050%
# Epoch 71/250 	 Loss = 0.531 	 Train Acc = 81.416% 	 Sparsity = 57.564% 	 Test Loss = 0.556 	Test Acc = 81.330%
# Epoch 72/250 	 Loss = 0.523 	 Train Acc = 81.704% 	 Sparsity = 57.593% 	 Test Loss = 0.551 	Test Acc = 81.440%
# Epoch 73/250 	 Loss = 0.530 	 Train Acc = 81.638% 	 Sparsity = 57.622% 	 Test Loss = 0.549 	Test Acc = 81.330%
# Epoch 74/250 	 Loss = 0.527 	 Train Acc = 81.580% 	 Sparsity = 57.650% 	 Test Loss = 0.544 	Test Acc = 81.690%
# Epoch 75/250 	 Loss = 0.522 	 Train Acc = 81.854% 	 Sparsity = 57.676% 	 Test Loss = 0.541 	Test Acc = 81.940%
# Epoch 76/250 	 Loss = 0.524 	 Train Acc = 81.752% 	 Sparsity = 57.704% 	 Test Loss = 0.560 	Test Acc = 81.120%
# Epoch 77/250 	 Loss = 0.521 	 Train Acc = 81.778% 	 Sparsity = 57.732% 	 Test Loss = 0.555 	Test Acc = 81.540%
# Epoch 78/250 	 Loss = 0.521 	 Train Acc = 81.942% 	 Sparsity = 57.758% 	 Test Loss = 0.560 	Test Acc = 81.320%
# Epoch 79/250 	 Loss = 0.529 	 Train Acc = 81.556% 	 Sparsity = 57.783% 	 Test Loss = 0.547 	Test Acc = 81.700%
# Epoch 80/250 	 Loss = 0.524 	 Train Acc = 81.644% 	 Sparsity = 57.808% 	 Test Loss = 0.525 	Test Acc = 82.500%
# New test accuracy is 82.500%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 81/250 	 Loss = 0.522 	 Train Acc = 81.716% 	 Sparsity = 57.834% 	 Test Loss = 0.560 	Test Acc = 81.490%
# Epoch 82/250 	 Loss = 0.517 	 Train Acc = 81.910% 	 Sparsity = 57.859% 	 Test Loss = 0.551 	Test Acc = 81.580%
# Epoch 83/250 	 Loss = 0.526 	 Train Acc = 81.846% 	 Sparsity = 57.883% 	 Test Loss = 0.527 	Test Acc = 82.080%
# Epoch 84/250 	 Loss = 0.522 	 Train Acc = 81.908% 	 Sparsity = 57.907% 	 Test Loss = 0.567 	Test Acc = 81.040%
# Epoch 85/250 	 Loss = 0.521 	 Train Acc = 81.764% 	 Sparsity = 57.931% 	 Test Loss = 0.523 	Test Acc = 82.220%
# Epoch 86/250 	 Loss = 0.524 	 Train Acc = 81.648% 	 Sparsity = 57.955% 	 Test Loss = 0.538 	Test Acc = 82.020%
# Epoch 87/250 	 Loss = 0.520 	 Train Acc = 81.826% 	 Sparsity = 57.977% 	 Test Loss = 0.563 	Test Acc = 81.360%
# Epoch 88/250 	 Loss = 0.522 	 Train Acc = 81.962% 	 Sparsity = 57.999% 	 Test Loss = 0.539 	Test Acc = 81.980%
# Epoch 89/250 	 Loss = 0.523 	 Train Acc = 82.016% 	 Sparsity = 58.021% 	 Test Loss = 0.553 	Test Acc = 81.450%
# Epoch 90/250 	 Loss = 0.518 	 Train Acc = 81.826% 	 Sparsity = 58.041% 	 Test Loss = 0.558 	Test Acc = 81.620%
# Epoch 91/250 	 Loss = 0.519 	 Train Acc = 81.962% 	 Sparsity = 58.063% 	 Test Loss = 0.543 	Test Acc = 81.920%
# Epoch 92/250 	 Loss = 0.516 	 Train Acc = 82.012% 	 Sparsity = 58.084% 	 Test Loss = 0.549 	Test Acc = 81.720%
# Epoch 93/250 	 Loss = 0.517 	 Train Acc = 82.026% 	 Sparsity = 58.105% 	 Test Loss = 0.524 	Test Acc = 82.300%
# Epoch 94/250 	 Loss = 0.529 	 Train Acc = 81.556% 	 Sparsity = 58.127% 	 Test Loss = 0.540 	Test Acc = 81.910%
# Epoch 95/250 	 Loss = 0.520 	 Train Acc = 81.884% 	 Sparsity = 58.148% 	 Test Loss = 0.564 	Test Acc = 81.350%
# Epoch 96/250 	 Loss = 0.517 	 Train Acc = 82.006% 	 Sparsity = 58.168% 	 Test Loss = 0.551 	Test Acc = 81.210%
# Epoch 97/250 	 Loss = 0.515 	 Train Acc = 81.962% 	 Sparsity = 58.189% 	 Test Loss = 0.547 	Test Acc = 81.970%
# Epoch 98/250 	 Loss = 0.515 	 Train Acc = 82.030% 	 Sparsity = 58.209% 	 Test Loss = 0.546 	Test Acc = 81.700%
# Epoch 99/250 	 Loss = 0.521 	 Train Acc = 81.818% 	 Sparsity = 58.228% 	 Test Loss = 0.529 	Test Acc = 82.410%
# Epoch 100/250 	 Loss = 0.521 	 Train Acc = 81.730% 	 Sparsity = 58.248% 	 Test Loss = 0.532 	Test Acc = 82.010%
# Epoch 101/250 	 Loss = 0.516 	 Train Acc = 81.810% 	 Sparsity = 58.267% 	 Test Loss = 0.543 	Test Acc = 81.860%
# Epoch 102/250 	 Loss = 0.516 	 Train Acc = 81.856% 	 Sparsity = 58.286% 	 Test Loss = 0.537 	Test Acc = 82.010%
# Epoch 103/250 	 Loss = 0.518 	 Train Acc = 81.770% 	 Sparsity = 58.304% 	 Test Loss = 0.533 	Test Acc = 82.320%
# Epoch 104/250 	 Loss = 0.512 	 Train Acc = 82.112% 	 Sparsity = 58.324% 	 Test Loss = 0.556 	Test Acc = 81.670%
# Epoch 105/250 	 Loss = 0.514 	 Train Acc = 82.048% 	 Sparsity = 58.343% 	 Test Loss = 0.560 	Test Acc = 81.460%
# Epoch 106/250 	 Loss = 0.515 	 Train Acc = 82.086% 	 Sparsity = 58.362% 	 Test Loss = 0.536 	Test Acc = 82.410%
# Epoch 107/250 	 Loss = 0.514 	 Train Acc = 82.068% 	 Sparsity = 58.379% 	 Test Loss = 0.561 	Test Acc = 81.200%
# Epoch 108/250 	 Loss = 0.517 	 Train Acc = 81.850% 	 Sparsity = 58.395% 	 Test Loss = 0.548 	Test Acc = 81.630%
# Epoch 109/250 	 Loss = 0.517 	 Train Acc = 82.042% 	 Sparsity = 58.414% 	 Test Loss = 0.562 	Test Acc = 81.230%
# Epoch 110/250 	 Loss = 0.511 	 Train Acc = 82.318% 	 Sparsity = 58.432% 	 Test Loss = 0.539 	Test Acc = 82.010%
# Epoch 111/250 	 Loss = 0.508 	 Train Acc = 82.252% 	 Sparsity = 58.449% 	 Test Loss = 0.551 	Test Acc = 82.030%
# Epoch 112/250 	 Loss = 0.516 	 Train Acc = 81.984% 	 Sparsity = 58.466% 	 Test Loss = 0.531 	Test Acc = 81.960%
# Epoch 113/250 	 Loss = 0.508 	 Train Acc = 82.146% 	 Sparsity = 58.484% 	 Test Loss = 0.532 	Test Acc = 82.420%
# Epoch 114/250 	 Loss = 0.514 	 Train Acc = 81.974% 	 Sparsity = 58.501% 	 Test Loss = 0.535 	Test Acc = 82.260%
# Epoch 115/250 	 Loss = 0.510 	 Train Acc = 82.200% 	 Sparsity = 58.517% 	 Test Loss = 0.527 	Test Acc = 82.540%
# New test accuracy is 82.540%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 116/250 	 Loss = 0.518 	 Train Acc = 81.976% 	 Sparsity = 58.534% 	 Test Loss = 0.550 	Test Acc = 81.540%
# Epoch 117/250 	 Loss = 0.518 	 Train Acc = 82.062% 	 Sparsity = 58.550% 	 Test Loss = 0.527 	Test Acc = 82.230%
# Epoch 118/250 	 Loss = 0.512 	 Train Acc = 82.176% 	 Sparsity = 58.568% 	 Test Loss = 0.550 	Test Acc = 81.360%
# Epoch 119/250 	 Loss = 0.513 	 Train Acc = 82.242% 	 Sparsity = 58.584% 	 Test Loss = 0.539 	Test Acc = 82.170%
# Epoch 120/250 	 Loss = 0.507 	 Train Acc = 82.200% 	 Sparsity = 58.600% 	 Test Loss = 0.530 	Test Acc = 82.140%
# Epoch 121/250 	 Loss = 0.511 	 Train Acc = 82.062% 	 Sparsity = 58.616% 	 Test Loss = 0.534 	Test Acc = 82.090%
# Epoch 122/250 	 Loss = 0.515 	 Train Acc = 82.006% 	 Sparsity = 58.632% 	 Test Loss = 0.566 	Test Acc = 81.320%
# Epoch 123/250 	 Loss = 0.508 	 Train Acc = 82.376% 	 Sparsity = 58.647% 	 Test Loss = 0.568 	Test Acc = 81.080%
# Epoch 124/250 	 Loss = 0.512 	 Train Acc = 82.092% 	 Sparsity = 58.662% 	 Test Loss = 0.610 	Test Acc = 79.810%
# Epoch 125/250 	 Loss = 0.510 	 Train Acc = 82.096% 	 Sparsity = 58.678% 	 Test Loss = 0.553 	Test Acc = 81.580%
# Epoch 126/250 	 Loss = 0.510 	 Train Acc = 82.392% 	 Sparsity = 58.693% 	 Test Loss = 0.577 	Test Acc = 80.800%
# Epoch 127/250 	 Loss = 0.509 	 Train Acc = 82.360% 	 Sparsity = 58.709% 	 Test Loss = 0.547 	Test Acc = 81.920%
# Epoch 128/250 	 Loss = 0.514 	 Train Acc = 82.258% 	 Sparsity = 58.723% 	 Test Loss = 0.548 	Test Acc = 81.790%
# Epoch 129/250 	 Loss = 0.506 	 Train Acc = 82.328% 	 Sparsity = 58.737% 	 Test Loss = 0.517 	Test Acc = 82.490%
# Epoch 130/250 	 Loss = 0.512 	 Train Acc = 82.110% 	 Sparsity = 58.751% 	 Test Loss = 0.587 	Test Acc = 80.750%
# Epoch 131/250 	 Loss = 0.509 	 Train Acc = 82.330% 	 Sparsity = 58.765% 	 Test Loss = 0.549 	Test Acc = 81.720%
# Epoch 132/250 	 Loss = 0.511 	 Train Acc = 82.180% 	 Sparsity = 58.781% 	 Test Loss = 0.548 	Test Acc = 81.970%
# Epoch 133/250 	 Loss = 0.508 	 Train Acc = 82.270% 	 Sparsity = 58.795% 	 Test Loss = 0.548 	Test Acc = 81.810%
# Epoch 134/250 	 Loss = 0.507 	 Train Acc = 82.284% 	 Sparsity = 58.808% 	 Test Loss = 0.530 	Test Acc = 82.290%
# Epoch 135/250 	 Loss = 0.509 	 Train Acc = 82.164% 	 Sparsity = 58.820% 	 Test Loss = 0.527 	Test Acc = 82.240%
# Epoch 136/250 	 Loss = 0.510 	 Train Acc = 82.434% 	 Sparsity = 58.832% 	 Test Loss = 0.536 	Test Acc = 82.000%
# Epoch 137/250 	 Loss = 0.512 	 Train Acc = 82.044% 	 Sparsity = 58.847% 	 Test Loss = 0.570 	Test Acc = 81.460%
# Epoch 138/250 	 Loss = 0.503 	 Train Acc = 82.356% 	 Sparsity = 58.861% 	 Test Loss = 0.572 	Test Acc = 81.020%
# Epoch 139/250 	 Loss = 0.510 	 Train Acc = 82.326% 	 Sparsity = 58.875% 	 Test Loss = 0.544 	Test Acc = 81.970%
# Epoch 140/250 	 Loss = 0.511 	 Train Acc = 82.074% 	 Sparsity = 58.888% 	 Test Loss = 0.529 	Test Acc = 82.470%
# Epoch 141/250 	 Loss = 0.508 	 Train Acc = 82.164% 	 Sparsity = 58.900% 	 Test Loss = 0.559 	Test Acc = 81.470%
# Epoch 142/250 	 Loss = 0.508 	 Train Acc = 82.100% 	 Sparsity = 58.912% 	 Test Loss = 0.575 	Test Acc = 80.980%
# Epoch 143/250 	 Loss = 0.514 	 Train Acc = 82.250% 	 Sparsity = 58.927% 	 Test Loss = 0.537 	Test Acc = 82.030%
# Epoch 144/250 	 Loss = 0.504 	 Train Acc = 82.388% 	 Sparsity = 58.941% 	 Test Loss = 0.570 	Test Acc = 81.150%
# Epoch 145/250 	 Loss = 0.505 	 Train Acc = 82.262% 	 Sparsity = 58.955% 	 Test Loss = 0.539 	Test Acc = 82.000%
# Epoch 146/250 	 Loss = 0.508 	 Train Acc = 82.144% 	 Sparsity = 58.969% 	 Test Loss = 0.539 	Test Acc = 82.140%
# Epoch 147/250 	 Loss = 0.510 	 Train Acc = 82.438% 	 Sparsity = 58.982% 	 Test Loss = 0.550 	Test Acc = 81.800%
# Epoch 148/250 	 Loss = 0.508 	 Train Acc = 82.108% 	 Sparsity = 58.994% 	 Test Loss = 0.560 	Test Acc = 81.480%
# Epoch 149/250 	 Loss = 0.507 	 Train Acc = 82.196% 	 Sparsity = 59.008% 	 Test Loss = 0.570 	Test Acc = 81.360%
# Epoch 150/250 	 Loss = 0.511 	 Train Acc = 81.966% 	 Sparsity = 59.019% 	 Test Loss = 0.524 	Test Acc = 82.350%
# Epoch 151/250 	 Loss = 0.501 	 Train Acc = 82.608% 	 Sparsity = 59.032% 	 Test Loss = 0.540 	Test Acc = 81.960%
# Epoch 152/250 	 Loss = 0.506 	 Train Acc = 82.224% 	 Sparsity = 59.044% 	 Test Loss = 0.541 	Test Acc = 82.270%
# Epoch 153/250 	 Loss = 0.509 	 Train Acc = 82.256% 	 Sparsity = 59.058% 	 Test Loss = 0.553 	Test Acc = 81.800%
# Epoch 154/250 	 Loss = 0.503 	 Train Acc = 82.400% 	 Sparsity = 59.069% 	 Test Loss = 0.526 	Test Acc = 82.580%
# New test accuracy is 82.580%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 155/250 	 Loss = 0.510 	 Train Acc = 82.216% 	 Sparsity = 59.081% 	 Test Loss = 0.554 	Test Acc = 81.700%
# Epoch 156/250 	 Loss = 0.504 	 Train Acc = 82.326% 	 Sparsity = 59.094% 	 Test Loss = 0.543 	Test Acc = 81.840%
# Epoch 157/250 	 Loss = 0.505 	 Train Acc = 82.210% 	 Sparsity = 59.106% 	 Test Loss = 0.568 	Test Acc = 81.140%
# Epoch 158/250 	 Loss = 0.502 	 Train Acc = 82.540% 	 Sparsity = 59.118% 	 Test Loss = 0.571 	Test Acc = 81.300%
# Epoch 159/250 	 Loss = 0.506 	 Train Acc = 82.344% 	 Sparsity = 59.130% 	 Test Loss = 0.534 	Test Acc = 82.220%
# Epoch 160/250 	 Loss = 0.505 	 Train Acc = 82.350% 	 Sparsity = 59.141% 	 Test Loss = 0.540 	Test Acc = 82.230%
# Epoch 161/250 	 Loss = 0.508 	 Train Acc = 82.280% 	 Sparsity = 59.153% 	 Test Loss = 0.546 	Test Acc = 81.530%
# Epoch 162/250 	 Loss = 0.509 	 Train Acc = 82.204% 	 Sparsity = 59.165% 	 Test Loss = 0.534 	Test Acc = 82.110%
# Epoch 163/250 	 Loss = 0.506 	 Train Acc = 82.302% 	 Sparsity = 59.177% 	 Test Loss = 0.574 	Test Acc = 81.080%
# Epoch 164/250 	 Loss = 0.506 	 Train Acc = 82.264% 	 Sparsity = 59.188% 	 Test Loss = 0.547 	Test Acc = 81.900%
# Epoch 165/250 	 Loss = 0.504 	 Train Acc = 82.308% 	 Sparsity = 59.201% 	 Test Loss = 0.550 	Test Acc = 81.700%
# Epoch 166/250 	 Loss = 0.501 	 Train Acc = 82.628% 	 Sparsity = 59.212% 	 Test Loss = 0.545 	Test Acc = 81.920%
# Epoch 167/250 	 Loss = 0.504 	 Train Acc = 82.354% 	 Sparsity = 59.225% 	 Test Loss = 0.575 	Test Acc = 81.210%
# Epoch 168/250 	 Loss = 0.503 	 Train Acc = 82.476% 	 Sparsity = 59.237% 	 Test Loss = 0.552 	Test Acc = 81.430%
# Epoch 169/250 	 Loss = 0.503 	 Train Acc = 82.314% 	 Sparsity = 59.250% 	 Test Loss = 0.552 	Test Acc = 81.610%
# Epoch 170/250 	 Loss = 0.504 	 Train Acc = 82.368% 	 Sparsity = 59.260% 	 Test Loss = 0.581 	Test Acc = 81.050%
# Epoch 171/250 	 Loss = 0.506 	 Train Acc = 82.488% 	 Sparsity = 59.271% 	 Test Loss = 0.539 	Test Acc = 81.890%
# Epoch 172/250 	 Loss = 0.504 	 Train Acc = 82.192% 	 Sparsity = 59.281% 	 Test Loss = 0.551 	Test Acc = 81.660%
# Epoch 173/250 	 Loss = 0.503 	 Train Acc = 82.334% 	 Sparsity = 59.291% 	 Test Loss = 0.576 	Test Acc = 81.130%
# Epoch 174/250 	 Loss = 0.503 	 Train Acc = 82.450% 	 Sparsity = 59.301% 	 Test Loss = 0.538 	Test Acc = 82.200%
# Epoch 175/250 	 Loss = 0.504 	 Train Acc = 82.392% 	 Sparsity = 59.312% 	 Test Loss = 0.560 	Test Acc = 81.530%
# Epoch 176/250 	 Loss = 0.500 	 Train Acc = 82.332% 	 Sparsity = 59.324% 	 Test Loss = 0.551 	Test Acc = 81.490%
# Epoch 177/250 	 Loss = 0.501 	 Train Acc = 82.318% 	 Sparsity = 59.334% 	 Test Loss = 0.544 	Test Acc = 82.100%
# Epoch 178/250 	 Loss = 0.504 	 Train Acc = 82.400% 	 Sparsity = 59.344% 	 Test Loss = 0.541 	Test Acc = 82.280%
# Epoch 179/250 	 Loss = 0.505 	 Train Acc = 82.246% 	 Sparsity = 59.356% 	 Test Loss = 0.567 	Test Acc = 81.220%
# Epoch 180/250 	 Loss = 0.503 	 Train Acc = 82.332% 	 Sparsity = 59.367% 	 Test Loss = 0.542 	Test Acc = 82.020%
# Epoch 181/250 	 Loss = 0.505 	 Train Acc = 82.458% 	 Sparsity = 59.378% 	 Test Loss = 0.536 	Test Acc = 82.120%
# Epoch 182/250 	 Loss = 0.504 	 Train Acc = 82.190% 	 Sparsity = 59.387% 	 Test Loss = 0.537 	Test Acc = 82.150%
# Epoch 183/250 	 Loss = 0.504 	 Train Acc = 82.320% 	 Sparsity = 59.397% 	 Test Loss = 0.546 	Test Acc = 81.770%
# Epoch 184/250 	 Loss = 0.506 	 Train Acc = 82.152% 	 Sparsity = 59.407% 	 Test Loss = 0.559 	Test Acc = 81.460%
# Epoch 185/250 	 Loss = 0.508 	 Train Acc = 82.414% 	 Sparsity = 59.417% 	 Test Loss = 0.548 	Test Acc = 81.670%
# Epoch 186/250 	 Loss = 0.499 	 Train Acc = 82.610% 	 Sparsity = 59.429% 	 Test Loss = 0.540 	Test Acc = 81.890%
# Epoch 187/250 	 Loss = 0.499 	 Train Acc = 82.398% 	 Sparsity = 59.439% 	 Test Loss = 0.543 	Test Acc = 82.090%
# Epoch 188/250 	 Loss = 0.505 	 Train Acc = 82.176% 	 Sparsity = 59.450% 	 Test Loss = 0.532 	Test Acc = 82.170%
# Epoch 189/250 	 Loss = 0.498 	 Train Acc = 82.466% 	 Sparsity = 59.460% 	 Test Loss = 0.551 	Test Acc = 81.650%
# Epoch 190/250 	 Loss = 0.500 	 Train Acc = 82.434% 	 Sparsity = 59.470% 	 Test Loss = 0.535 	Test Acc = 82.040%
# Epoch 191/250 	 Loss = 0.503 	 Train Acc = 82.458% 	 Sparsity = 59.480% 	 Test Loss = 0.533 	Test Acc = 82.240%
# Epoch 192/250 	 Loss = 0.502 	 Train Acc = 82.612% 	 Sparsity = 59.491% 	 Test Loss = 0.534 	Test Acc = 81.980%
# Epoch 193/250 	 Loss = 0.502 	 Train Acc = 82.496% 	 Sparsity = 59.499% 	 Test Loss = 0.573 	Test Acc = 81.090%
# Epoch 194/250 	 Loss = 0.503 	 Train Acc = 82.292% 	 Sparsity = 59.510% 	 Test Loss = 0.534 	Test Acc = 82.040%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8a3d986d7b2e> in <module>()
#      89                     v[i] = tf.math.subtract(momentum*v[i], grads[i])
#      90                     #WEIGHT UPDATE
# ---> 91                     layer_weights.assign(tf.math.add(layer_weights, v[i]))
#      92             predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
#      93             train_accuracy.update_state(y_batch_train,predictions)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     916           self.handle, value_tensor, name=name)
#     917       if read_value:
# --> 918         return self._lazy_read(assign_op)
#     919     return assign_op
#     920
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _lazy_read(self, op)
#     882         deleter=self._handle_deleter if not self._in_graph_mode else None,
#     883         parent_op=op,
# --> 884         unique_id=self._unique_id)
#     885
#     886   def assign(self, value, use_locking=None, name=None, read_value=True):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     270       return cls._variable_v2_call(*args, **kwargs)
#     271     else:
# --> 272       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     273
#     274
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, handle, dtype, shape, in_graph_mode, deleter, parent_op, unique_id)
#    2099         dtype=dtype,
#    2100         handle_deleter=deleter,
# -> 2101         graph_element=graph_element)
#    2102     self._parent_op = parent_op
#    2103
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, trainable, shape, dtype, handle, constraint, synchronization, aggregation, distribute_strategy, name, unique_id, handle_name, graph_element, initial_value, initializer_op, is_initialized_op, cached_value, save_slice_info, handle_deleter, caching_device, in_graph_mode, **unused_kwargs)
#     430     self._shape = tensor_shape.as_shape(shape)
#     431     self._dtype = dtypes.as_dtype(dtype)
# --> 432     self._handle = handle
#     433     self._unique_id = unique_id
#     434     self._handle_name = handle_name + ":0"
#
# KeyboardInterrupt:

# %%
#for i in bk:
#    print(float(i))

for (i,layer) in enumerate(model.trainable_weights):
    print(layer.name, float(bk[i]))
# Out:
# conv1/kernel:0 0.29409199953079224
# conv1/bias:0 0.20199888944625854
# bn1/gamma:0 -1.0
# bn1/beta:0 -1.0
# conv2/kernel:0 0.1113639622926712
# conv2/bias:0 0.0179990716278553
# bn2/gamma:0 -1.0
# bn2/beta:0 -1.0
# conv3/kernel:0 0.07567309588193893
# conv3/bias:0 0.23392564058303833
# bn3/gamma:0 -1.0
# bn3/beta:0 -1.0
# conv4/kernel:0 0.06147156283259392
# conv4/bias:0 0.09200463443994522
# bn4/gamma:0 -1.0
# bn4/beta:0 -1.0
# conv5/kernel:0 0.04933227226138115
# conv5/bias:0 0.08148693293333054
# bn5/gamma:0 -1.0
# bn5/beta:0 -1.0
# conv6/kernel:0 0.04033384844660759
# conv6/bias:0 0.029106643050909042
# bn6/gamma:0 -1.0
# bn6/beta:0 -1.0
# dense3/kernel:0 0.016647687181830406
# dense3/bias:0 0.05647328123450279
# bn9/gamma:0 -1.0
# bn9/beta:0 -1.0
# dense4/kernel:0 0.030234485864639282
# dense4/bias:0 0.033354103565216064

# %%
for (i,layer) in enumerate(model.trainable_weights):
        #if layer.name == 'conv1':
        '''
        print(layer.weights[0])
        '''
        if 'bn' in layer.name or 'bias' in layer.name :
            pass
        else:
            print(layer.name)
            a = tf.reshape(layer,[-1])
            b = a.numpy()
            
            plt.axvline(x=-bk[i],color='r')
            plt.hist(b,500)
            
            plt.axvline(x=bk[i],color='r')
            plt.ylim((0,100))
            plt.show()

        '''
        plt.hist(b,200)
        plt.axvline(x=bk[i],color='red')
        plt.axvline(x=-bk[i],color='r')
        plt.ylim((0,150))
        plt.show()
        '''
# Out:
# conv1/kernel:0
# conv2/kernel:0
# conv3/kernel:0
# conv4/kernel:0
# conv5/kernel:0
# conv6/kernel:0
# dense3/kernel:0
# dense4/kernel:0

# %%
model = keras.models.load_model('test_p05.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
l = len(model.trainable_weights)
j = 0
for i in range(l):
  a = tf.reshape(model.trainable_weights[i],[-1])
  b = a.numpy()
  #print(a)
  #plt.ylim(0,300)
  plt.axvline(x=bk[j],color='r')
  plt.axvline(x=-bk[j],color='r')
  plt.hist(b,200)
  plt.show()

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
test_accuracy = tf.keras.metrics.Accuracy()
logits = model(x_test, training=False)
prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
test_accuracy(prediction, y_test)
print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 82.580%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

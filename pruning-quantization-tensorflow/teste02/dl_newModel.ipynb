# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# 2.7.0
# 1
# /device:GPU:0

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255
#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout_24 (Dropout)        (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_25 (Dropout)        (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_26 (Dropout)        (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_27 (Dropout)        (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 250
alpha = 0
n_bits = 8

learning_rate = 0.015
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_02.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_5.csv')
# Out:
# Created Tensor of velocity
# Epoch 1/250 	 Loss = 2.892 	 Train Acc = 32.474% 	 Sparsity = 0.000% 	 Test Loss = 2.144 	Test Acc = 29.100%
# New test accuracy is 29.100%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/250 	 Loss = 2.393 	 Train Acc = 38.472% 	 Sparsity = 0.000% 	 Test Loss = 2.467 	Test Acc = 40.410%
# New test accuracy is 40.410%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/250 	 Loss = 1.798 	 Train Acc = 43.546% 	 Sparsity = 0.000% 	 Test Loss = 1.319 	Test Acc = 52.360%
# New test accuracy is 52.360%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/250 	 Loss = 1.343 	 Train Acc = 52.204% 	 Sparsity = 0.000% 	 Test Loss = 1.169 	Test Acc = 57.470%
# New test accuracy is 57.470%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 5/250 	 Loss = 1.197 	 Train Acc = 57.490% 	 Sparsity = 0.000% 	 Test Loss = 1.022 	Test Acc = 63.710%
# New test accuracy is 63.710%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/250 	 Loss = 1.100 	 Train Acc = 60.630% 	 Sparsity = 0.000% 	 Test Loss = 0.948 	Test Acc = 66.110%
# New test accuracy is 66.110%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/250 	 Loss = 1.028 	 Train Acc = 63.570% 	 Sparsity = 0.000% 	 Test Loss = 0.891 	Test Acc = 68.160%
# New test accuracy is 68.160%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/250 	 Loss = 0.965 	 Train Acc = 65.734% 	 Sparsity = 0.000% 	 Test Loss = 0.886 	Test Acc = 69.400%
# New test accuracy is 69.400%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/250 	 Loss = 0.914 	 Train Acc = 67.896% 	 Sparsity = 0.000% 	 Test Loss = 6.450 	Test Acc = 66.130%
# Epoch 10/250 	 Loss = 0.880 	 Train Acc = 69.020% 	 Sparsity = 0.000% 	 Test Loss = 0.782 	Test Acc = 72.560%
# New test accuracy is 72.560%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 11/250 	 Loss = 0.866 	 Train Acc = 69.708% 	 Sparsity = 0.000% 	 Test Loss = 0.740 	Test Acc = 73.950%
# New test accuracy is 73.950%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 12/250 	 Loss = 0.796 	 Train Acc = 71.978% 	 Sparsity = 0.000% 	 Test Loss = 0.778 	Test Acc = 73.120%
# Epoch 13/250 	 Loss = 0.773 	 Train Acc = 72.844% 	 Sparsity = 0.000% 	 Test Loss = 0.722 	Test Acc = 74.900%
# New test accuracy is 74.900%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 14/250 	 Loss = 0.730 	 Train Acc = 74.362% 	 Sparsity = 0.000% 	 Test Loss = 0.667 	Test Acc = 76.440%
# New test accuracy is 76.440%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 15/250 	 Loss = 0.705 	 Train Acc = 75.402% 	 Sparsity = 0.000% 	 Test Loss = 0.824 	Test Acc = 77.680%
# New test accuracy is 77.680%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 16/250 	 Loss = 0.680 	 Train Acc = 76.172% 	 Sparsity = 0.000% 	 Test Loss = 0.654 	Test Acc = 77.560%
# Epoch 17/250 	 Loss = 0.659 	 Train Acc = 76.868% 	 Sparsity = 0.000% 	 Test Loss = 0.631 	Test Acc = 77.800%
# New test accuracy is 77.800%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 18/250 	 Loss = 0.643 	 Train Acc = 77.368% 	 Sparsity = 0.000% 	 Test Loss = 0.695 	Test Acc = 76.430%
# Epoch 19/250 	 Loss = 0.628 	 Train Acc = 78.104% 	 Sparsity = 0.000% 	 Test Loss = 0.626 	Test Acc = 78.540%
# New test accuracy is 78.540%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 20/250 	 Loss = 0.614 	 Train Acc = 78.604% 	 Sparsity = 0.000% 	 Test Loss = 0.581 	Test Acc = 79.600%
# New test accuracy is 79.600%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 21/250 	 Loss = 0.590 	 Train Acc = 79.082% 	 Sparsity = 0.000% 	 Test Loss = 0.651 	Test Acc = 79.250%
# Epoch 22/250 	 Loss = 0.577 	 Train Acc = 79.820% 	 Sparsity = 0.000% 	 Test Loss = 0.563 	Test Acc = 80.610%
# New test accuracy is 80.610%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 23/250 	 Loss = 0.561 	 Train Acc = 80.202% 	 Sparsity = 0.000% 	 Test Loss = 0.573 	Test Acc = 80.470%
# Epoch 24/250 	 Loss = 0.548 	 Train Acc = 80.790% 	 Sparsity = 0.000% 	 Test Loss = 0.562 	Test Acc = 80.620%
# New test accuracy is 80.620%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 25/250 	 Loss = 0.541 	 Train Acc = 80.842% 	 Sparsity = 0.000% 	 Test Loss = 0.605 	Test Acc = 79.670%
# Epoch 26/250 	 Loss = 0.530 	 Train Acc = 81.456% 	 Sparsity = 0.000% 	 Test Loss = 0.575 	Test Acc = 80.920%
# New test accuracy is 80.920%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 27/250 	 Loss = 0.518 	 Train Acc = 81.738% 	 Sparsity = 0.000% 	 Test Loss = 0.564 	Test Acc = 80.520%
# Epoch 28/250 	 Loss = 0.507 	 Train Acc = 82.246% 	 Sparsity = 0.000% 	 Test Loss = 0.543 	Test Acc = 81.530%
# New test accuracy is 81.530%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 29/250 	 Loss = 0.498 	 Train Acc = 82.568% 	 Sparsity = 0.000% 	 Test Loss = 0.612 	Test Acc = 79.440%
# Epoch 30/250 	 Loss = 0.490 	 Train Acc = 82.920% 	 Sparsity = 0.000% 	 Test Loss = 0.533 	Test Acc = 81.940%
# New test accuracy is 81.940%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 31/250 	 Loss = 0.475 	 Train Acc = 83.266% 	 Sparsity = 0.000% 	 Test Loss = 0.543 	Test Acc = 81.840%
# Epoch 32/250 	 Loss = 0.468 	 Train Acc = 83.564% 	 Sparsity = 0.000% 	 Test Loss = 0.521 	Test Acc = 82.350%
# New test accuracy is 82.350%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 33/250 	 Loss = 0.463 	 Train Acc = 83.542% 	 Sparsity = 0.000% 	 Test Loss = 0.538 	Test Acc = 81.960%
# Epoch 34/250 	 Loss = 0.456 	 Train Acc = 83.894% 	 Sparsity = 0.000% 	 Test Loss = 0.535 	Test Acc = 82.140%
# Epoch 35/250 	 Loss = 0.443 	 Train Acc = 84.360% 	 Sparsity = 0.000% 	 Test Loss = 0.521 	Test Acc = 82.590%
# New test accuracy is 82.590%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 36/250 	 Loss = 0.435 	 Train Acc = 84.652% 	 Sparsity = 0.000% 	 Test Loss = 0.567 	Test Acc = 81.110%
# Epoch 37/250 	 Loss = 0.435 	 Train Acc = 84.758% 	 Sparsity = 0.000% 	 Test Loss = 0.501 	Test Acc = 82.900%
# New test accuracy is 82.900%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 38/250 	 Loss = 0.429 	 Train Acc = 84.716% 	 Sparsity = 0.000% 	 Test Loss = 0.529 	Test Acc = 82.300%
# Epoch 39/250 	 Loss = 0.422 	 Train Acc = 85.032% 	 Sparsity = 0.000% 	 Test Loss = 0.503 	Test Acc = 83.200%
# New test accuracy is 83.200%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 40/250 	 Loss = 0.413 	 Train Acc = 85.432% 	 Sparsity = 0.000% 	 Test Loss = 0.528 	Test Acc = 82.570%
# Epoch 41/250 	 Loss = 0.409 	 Train Acc = 85.580% 	 Sparsity = 0.000% 	 Test Loss = 0.514 	Test Acc = 82.870%
# Epoch 42/250 	 Loss = 0.398 	 Train Acc = 86.134% 	 Sparsity = 0.000% 	 Test Loss = 0.490 	Test Acc = 83.690%
# New test accuracy is 83.690%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 43/250 	 Loss = 0.394 	 Train Acc = 86.202% 	 Sparsity = 0.000% 	 Test Loss = 0.499 	Test Acc = 83.350%
# Epoch 44/250 	 Loss = 0.390 	 Train Acc = 86.182% 	 Sparsity = 0.000% 	 Test Loss = 0.524 	Test Acc = 82.870%
# Epoch 45/250 	 Loss = 0.383 	 Train Acc = 86.508% 	 Sparsity = 0.000% 	 Test Loss = 0.510 	Test Acc = 83.430%
# Epoch 46/250 	 Loss = 0.381 	 Train Acc = 86.584% 	 Sparsity = 0.000% 	 Test Loss = 0.508 	Test Acc = 83.780%
# New test accuracy is 83.780%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 47/250 	 Loss = 0.376 	 Train Acc = 86.704% 	 Sparsity = 0.000% 	 Test Loss = 0.539 	Test Acc = 82.550%
# Epoch 48/250 	 Loss = 0.370 	 Train Acc = 86.806% 	 Sparsity = 0.000% 	 Test Loss = 0.507 	Test Acc = 83.470%
# Epoch 49/250 	 Loss = 0.365 	 Train Acc = 87.062% 	 Sparsity = 0.000% 	 Test Loss = 0.494 	Test Acc = 83.650%
# Epoch 50/250 	 Loss = 0.366 	 Train Acc = 87.000% 	 Sparsity = 0.000% 	 Test Loss = 0.504 	Test Acc = 83.490%
# Epoch 51/250 	 Loss = 0.353 	 Train Acc = 87.424% 	 Sparsity = 0.000% 	 Test Loss = 0.503 	Test Acc = 83.990%
# New test accuracy is 83.990%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 52/250 	 Loss = 0.353 	 Train Acc = 87.460% 	 Sparsity = 0.000% 	 Test Loss = 0.495 	Test Acc = 84.050%
# New test accuracy is 84.050%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 53/250 	 Loss = 0.345 	 Train Acc = 87.678% 	 Sparsity = 0.000% 	 Test Loss = 0.492 	Test Acc = 84.020%
# Epoch 54/250 	 Loss = 0.343 	 Train Acc = 87.836% 	 Sparsity = 0.000% 	 Test Loss = 0.528 	Test Acc = 83.220%
# Epoch 55/250 	 Loss = 0.337 	 Train Acc = 88.002% 	 Sparsity = 0.000% 	 Test Loss = 0.529 	Test Acc = 83.220%
# Epoch 56/250 	 Loss = 0.332 	 Train Acc = 88.218% 	 Sparsity = 0.000% 	 Test Loss = 0.489 	Test Acc = 84.110%
# New test accuracy is 84.110%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 57/250 	 Loss = 0.328 	 Train Acc = 88.426% 	 Sparsity = 0.000% 	 Test Loss = 0.493 	Test Acc = 84.140%
# New test accuracy is 84.140%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 58/250 	 Loss = 0.331 	 Train Acc = 88.338% 	 Sparsity = 0.000% 	 Test Loss = 0.506 	Test Acc = 83.740%
# Epoch 59/250 	 Loss = 0.323 	 Train Acc = 88.522% 	 Sparsity = 0.000% 	 Test Loss = 0.491 	Test Acc = 83.790%
# Epoch 60/250 	 Loss = 0.315 	 Train Acc = 88.736% 	 Sparsity = 0.000% 	 Test Loss = 0.511 	Test Acc = 83.830%
# Epoch 61/250 	 Loss = 0.315 	 Train Acc = 88.876% 	 Sparsity = 0.000% 	 Test Loss = 0.512 	Test Acc = 83.910%
# Epoch 62/250 	 Loss = 0.310 	 Train Acc = 88.836% 	 Sparsity = 0.000% 	 Test Loss = 0.504 	Test Acc = 84.150%
# New test accuracy is 84.150%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 63/250 	 Loss = 0.307 	 Train Acc = 89.066% 	 Sparsity = 0.000% 	 Test Loss = 0.516 	Test Acc = 83.740%
# Epoch 64/250 	 Loss = 0.305 	 Train Acc = 89.092% 	 Sparsity = 0.000% 	 Test Loss = 0.485 	Test Acc = 84.630%
# New test accuracy is 84.630%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 65/250 	 Loss = 0.299 	 Train Acc = 89.390% 	 Sparsity = 0.000% 	 Test Loss = 0.507 	Test Acc = 83.970%
# Epoch 66/250 	 Loss = 0.297 	 Train Acc = 89.230% 	 Sparsity = 0.000% 	 Test Loss = 0.499 	Test Acc = 84.190%
# Epoch 67/250 	 Loss = 0.293 	 Train Acc = 89.626% 	 Sparsity = 0.000% 	 Test Loss = 0.516 	Test Acc = 84.140%
# Epoch 68/250 	 Loss = 0.295 	 Train Acc = 89.542% 	 Sparsity = 0.000% 	 Test Loss = 0.507 	Test Acc = 84.260%
# Epoch 69/250 	 Loss = 0.292 	 Train Acc = 89.550% 	 Sparsity = 0.000% 	 Test Loss = 0.509 	Test Acc = 83.980%
# Epoch 70/250 	 Loss = 0.287 	 Train Acc = 89.788% 	 Sparsity = 0.000% 	 Test Loss = 0.509 	Test Acc = 84.300%
# Epoch 71/250 	 Loss = 0.282 	 Train Acc = 89.946% 	 Sparsity = 0.000% 	 Test Loss = 0.503 	Test Acc = 84.550%
# Epoch 72/250 	 Loss = 0.280 	 Train Acc = 89.936% 	 Sparsity = 0.000% 	 Test Loss = 0.484 	Test Acc = 85.050%
# New test accuracy is 85.050%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 73/250 	 Loss = 0.272 	 Train Acc = 90.264% 	 Sparsity = 0.000% 	 Test Loss = 0.507 	Test Acc = 84.250%
# Epoch 74/250 	 Loss = 0.272 	 Train Acc = 90.318% 	 Sparsity = 0.000% 	 Test Loss = 0.499 	Test Acc = 84.560%
# Epoch 75/250 	 Loss = 0.270 	 Train Acc = 90.248% 	 Sparsity = 0.000% 	 Test Loss = 0.496 	Test Acc = 84.660%
# Epoch 76/250 	 Loss = 0.274 	 Train Acc = 90.278% 	 Sparsity = 0.000% 	 Test Loss = 0.523 	Test Acc = 83.700%
# Epoch 77/250 	 Loss = 0.272 	 Train Acc = 90.302% 	 Sparsity = 0.000% 	 Test Loss = 0.491 	Test Acc = 84.620%
# Epoch 78/250 	 Loss = 0.266 	 Train Acc = 90.462% 	 Sparsity = 0.000% 	 Test Loss = 0.484 	Test Acc = 85.340%
# New test accuracy is 85.340%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 79/250 	 Loss = 0.259 	 Train Acc = 90.608% 	 Sparsity = 0.000% 	 Test Loss = 0.496 	Test Acc = 84.510%
# Epoch 80/250 	 Loss = 0.264 	 Train Acc = 90.562% 	 Sparsity = 0.000% 	 Test Loss = 0.483 	Test Acc = 85.000%
# Epoch 81/250 	 Loss = 0.259 	 Train Acc = 90.794% 	 Sparsity = 0.000% 	 Test Loss = 0.496 	Test Acc = 85.030%
# Epoch 82/250 	 Loss = 0.255 	 Train Acc = 90.856% 	 Sparsity = 0.000% 	 Test Loss = 0.477 	Test Acc = 85.220%
# Epoch 83/250 	 Loss = 0.253 	 Train Acc = 90.872% 	 Sparsity = 0.000% 	 Test Loss = 0.491 	Test Acc = 84.970%
# Epoch 84/250 	 Loss = 0.250 	 Train Acc = 90.878% 	 Sparsity = 0.000% 	 Test Loss = 0.493 	Test Acc = 84.970%
# Epoch 85/250 	 Loss = 0.246 	 Train Acc = 91.148% 	 Sparsity = 0.000% 	 Test Loss = 0.487 	Test Acc = 84.960%
# Epoch 86/250 	 Loss = 0.250 	 Train Acc = 91.136% 	 Sparsity = 0.000% 	 Test Loss = 0.485 	Test Acc = 84.950%
# Epoch 87/250 	 Loss = 0.246 	 Train Acc = 91.178% 	 Sparsity = 0.000% 	 Test Loss = 0.489 	Test Acc = 85.110%
# Epoch 88/250 	 Loss = 0.244 	 Train Acc = 91.258% 	 Sparsity = 0.000% 	 Test Loss = 0.485 	Test Acc = 85.230%
# Epoch 89/250 	 Loss = 0.237 	 Train Acc = 91.412% 	 Sparsity = 0.000% 	 Test Loss = 0.479 	Test Acc = 85.490%
# New test accuracy is 85.490%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 90/250 	 Loss = 0.239 	 Train Acc = 91.414% 	 Sparsity = 0.000% 	 Test Loss = 0.486 	Test Acc = 85.000%
# Epoch 91/250 	 Loss = 0.235 	 Train Acc = 91.620% 	 Sparsity = 0.000% 	 Test Loss = 0.486 	Test Acc = 85.530%
# New test accuracy is 85.530%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 92/250 	 Loss = 0.234 	 Train Acc = 91.452% 	 Sparsity = 0.000% 	 Test Loss = 0.507 	Test Acc = 85.290%
# Epoch 93/250 	 Loss = 0.232 	 Train Acc = 91.718% 	 Sparsity = 0.000% 	 Test Loss = 0.518 	Test Acc = 84.640%
# Epoch 94/250 	 Loss = 0.234 	 Train Acc = 91.584% 	 Sparsity = 0.000% 	 Test Loss = 0.503 	Test Acc = 84.780%
# Epoch 95/250 	 Loss = 0.234 	 Train Acc = 91.714% 	 Sparsity = 0.000% 	 Test Loss = 0.477 	Test Acc = 85.440%
# Epoch 96/250 	 Loss = 0.228 	 Train Acc = 91.786% 	 Sparsity = 0.000% 	 Test Loss = 0.492 	Test Acc = 85.160%
# Epoch 97/250 	 Loss = 0.230 	 Train Acc = 91.718% 	 Sparsity = 0.000% 	 Test Loss = 0.488 	Test Acc = 85.280%
# Epoch 98/250 	 Loss = 0.228 	 Train Acc = 91.812% 	 Sparsity = 0.000% 	 Test Loss = 0.496 	Test Acc = 85.280%
# Epoch 99/250 	 Loss = 0.222 	 Train Acc = 92.106% 	 Sparsity = 0.000% 	 Test Loss = 0.492 	Test Acc = 85.530%
# Epoch 100/250 	 Loss = 0.222 	 Train Acc = 92.060% 	 Sparsity = 0.000% 	 Test Loss = 0.498 	Test Acc = 85.680%
# New test accuracy is 85.680%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 101/250 	 Loss = 0.224 	 Train Acc = 92.068% 	 Sparsity = 0.000% 	 Test Loss = 0.498 	Test Acc = 85.450%
# Epoch 102/250 	 Loss = 0.219 	 Train Acc = 92.192% 	 Sparsity = 0.000% 	 Test Loss = 0.500 	Test Acc = 85.140%
# Epoch 103/250 	 Loss = 0.217 	 Train Acc = 92.212% 	 Sparsity = 0.000% 	 Test Loss = 0.480 	Test Acc = 85.650%
# Epoch 104/250 	 Loss = 0.218 	 Train Acc = 92.188% 	 Sparsity = 0.000% 	 Test Loss = 0.485 	Test Acc = 85.490%
# Epoch 105/250 	 Loss = 0.214 	 Train Acc = 92.226% 	 Sparsity = 0.000% 	 Test Loss = 0.491 	Test Acc = 85.440%
# Epoch 106/250 	 Loss = 0.215 	 Train Acc = 92.280% 	 Sparsity = 0.000% 	 Test Loss = 0.494 	Test Acc = 85.230%
# Epoch 107/250 	 Loss = 0.210 	 Train Acc = 92.428% 	 Sparsity = 0.000% 	 Test Loss = 0.504 	Test Acc = 85.360%
# Epoch 108/250 	 Loss = 0.210 	 Train Acc = 92.358% 	 Sparsity = 0.000% 	 Test Loss = 0.561 	Test Acc = 84.160%
# Epoch 109/250 	 Loss = 0.210 	 Train Acc = 92.452% 	 Sparsity = 0.000% 	 Test Loss = 0.481 	Test Acc = 85.560%
# Epoch 110/250 	 Loss = 0.216 	 Train Acc = 92.266% 	 Sparsity = 0.000% 	 Test Loss = 0.504 	Test Acc = 85.430%
# Epoch 111/250 	 Loss = 0.204 	 Train Acc = 92.604% 	 Sparsity = 0.000% 	 Test Loss = 0.490 	Test Acc = 85.560%
# Epoch 112/250 	 Loss = 0.207 	 Train Acc = 92.582% 	 Sparsity = 0.000% 	 Test Loss = 0.503 	Test Acc = 85.350%
# Epoch 113/250 	 Loss = 0.206 	 Train Acc = 92.620% 	 Sparsity = 0.000% 	 Test Loss = 0.502 	Test Acc = 85.120%
# Epoch 114/250 	 Loss = 0.209 	 Train Acc = 92.434% 	 Sparsity = 0.000% 	 Test Loss = 0.504 	Test Acc = 85.530%
# Epoch 115/250 	 Loss = 0.205 	 Train Acc = 92.700% 	 Sparsity = 0.000% 	 Test Loss = 0.485 	Test Acc = 85.840%
# New test accuracy is 85.840%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 116/250 	 Loss = 0.202 	 Train Acc = 92.700% 	 Sparsity = 0.000% 	 Test Loss = 0.498 	Test Acc = 85.420%
# Epoch 117/250 	 Loss = 0.203 	 Train Acc = 92.866% 	 Sparsity = 0.000% 	 Test Loss = 0.508 	Test Acc = 85.440%
# Epoch 118/250 	 Loss = 0.200 	 Train Acc = 92.848% 	 Sparsity = 0.000% 	 Test Loss = 0.518 	Test Acc = 84.940%
# Epoch 119/250 	 Loss = 0.200 	 Train Acc = 92.694% 	 Sparsity = 0.000% 	 Test Loss = 0.533 	Test Acc = 84.910%
# Epoch 120/250 	 Loss = 0.196 	 Train Acc = 92.998% 	 Sparsity = 0.000% 	 Test Loss = 0.509 	Test Acc = 85.390%
# Epoch 121/250 	 Loss = 0.197 	 Train Acc = 92.870% 	 Sparsity = 0.000% 	 Test Loss = 0.526 	Test Acc = 85.100%
# Epoch 122/250 	 Loss = 0.198 	 Train Acc = 92.886% 	 Sparsity = 0.000% 	 Test Loss = 0.512 	Test Acc = 85.440%
# Epoch 123/250 	 Loss = 0.196 	 Train Acc = 92.992% 	 Sparsity = 0.000% 	 Test Loss = 0.502 	Test Acc = 85.650%
# Epoch 124/250 	 Loss = 0.193 	 Train Acc = 93.154% 	 Sparsity = 0.000% 	 Test Loss = 0.506 	Test Acc = 85.260%
# Epoch 125/250 	 Loss = 0.193 	 Train Acc = 93.060% 	 Sparsity = 0.000% 	 Test Loss = 0.504 	Test Acc = 85.690%
# Epoch 126/250 	 Loss = 0.196 	 Train Acc = 92.900% 	 Sparsity = 0.000% 	 Test Loss = 0.485 	Test Acc = 85.870%
# New test accuracy is 85.870%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 127/250 	 Loss = 0.193 	 Train Acc = 93.140% 	 Sparsity = 0.000% 	 Test Loss = 0.508 	Test Acc = 85.330%
# Epoch 128/250 	 Loss = 0.190 	 Train Acc = 93.162% 	 Sparsity = 0.000% 	 Test Loss = 0.503 	Test Acc = 85.630%
# Epoch 129/250 	 Loss = 0.194 	 Train Acc = 93.162% 	 Sparsity = 0.000% 	 Test Loss = 0.498 	Test Acc = 85.820%
# Epoch 130/250 	 Loss = 0.189 	 Train Acc = 93.264% 	 Sparsity = 0.000% 	 Test Loss = 0.511 	Test Acc = 85.420%
# Epoch 131/250 	 Loss = 0.192 	 Train Acc = 93.010% 	 Sparsity = 0.000% 	 Test Loss = 0.509 	Test Acc = 85.180%
# Epoch 132/250 	 Loss = 0.186 	 Train Acc = 93.298% 	 Sparsity = 0.000% 	 Test Loss = 0.505 	Test Acc = 85.800%
# Epoch 133/250 	 Loss = 0.184 	 Train Acc = 93.450% 	 Sparsity = 0.000% 	 Test Loss = 0.529 	Test Acc = 85.430%
# Epoch 134/250 	 Loss = 0.182 	 Train Acc = 93.452% 	 Sparsity = 0.000% 	 Test Loss = 0.517 	Test Acc = 85.540%
# Epoch 135/250 	 Loss = 0.186 	 Train Acc = 93.338% 	 Sparsity = 0.000% 	 Test Loss = 0.539 	Test Acc = 84.900%
# Epoch 136/250 	 Loss = 0.185 	 Train Acc = 93.336% 	 Sparsity = 0.000% 	 Test Loss = 0.505 	Test Acc = 85.900%
# New test accuracy is 85.900%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 137/250 	 Loss = 0.183 	 Train Acc = 93.464% 	 Sparsity = 0.000% 	 Test Loss = 0.505 	Test Acc = 85.550%
# Epoch 138/250 	 Loss = 0.185 	 Train Acc = 93.462% 	 Sparsity = 0.000% 	 Test Loss = 0.514 	Test Acc = 85.650%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12192/2031906028.py in <module>
#      54             #Cópia do modelo
#      55             if n_bits > 0:
# ---> 56                 model_copy = keras.models.clone_model(model)
#      57                 model_copy.set_weights(model.get_weights())
#      58
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\models.py in clone_model(model, input_tensors, clone_function)
#     452     if isinstance(model, Sequential):
#     453       return _clone_sequential_model(
# --> 454           model, input_tensors=input_tensors, layer_fn=clone_function)
#     455     else:
#     456       return _clone_functional_model(
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\models.py in _clone_sequential_model(model, input_tensors, layer_fn)
#     334
#     335   if input_tensors is None:
# --> 336     cloned_model = Sequential(layers=layers, name=model.name)
#     337   elif len(generic_utils.to_list(input_tensors)) != 1:
#     338     raise ValueError(
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\sequential.py in __init__(self, layers, name)
#     134         layers = [layers]
#     135       for layer in layers:
# --> 136         self.add(layer)
#     137
#     138   @property
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     218       # If the model is being built continuously on top of an input layer:
#     219       # refresh its output.
# --> 220       output_tensor = layer(self.outputs[0])
#     221       if len(tf.nest.flatten(output_tensor)) != 1:
#     222         raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1018     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#    1019       return self._functional_construction_call(inputs, args, kwargs,
# -> 1020                                                 input_list)
#    1021
#    1022     # Maintains info about the `Layer.call` stack.
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1159       # Check input assumptions set after layer building, e.g. input shape.
#    1160       outputs = self._keras_tensor_symbolic_call(
# -> 1161           inputs, input_masks, args, kwargs)
#    1162
#    1163       if outputs is None:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     883       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     884     else:
# --> 885       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     886
#     887   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     909     # output signatures, then we build KerasTensors corresponding to those
#     910     # outputs.
# --> 911     scratch_graph = tf.__internal__.FuncGraph(str(self.name) + '_scratch_graph')
#     912     with scratch_graph.as_default():
#     913       inputs = tf.nest.map_structure(
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\framework\func_graph.py in __init__(self, name, collections, capture_by_value)
#     188         from outer graphs, and failing that will default to False.
#     189     """
# --> 190     super(FuncGraph, self).__init__()
#     191
#     192     self.name = name
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self)
#    3111     # TODO(skyewm): fold as much of the above as possible into the C
#    3112     # implementation
# -> 3113     self._scoped_c_graph = c_api_util.ScopedTFGraph()
#    3114     # The C API requires all ops to have shape functions. Disable this
#    3115     # requirement (many custom ops do not have shape functions, and we don't
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\framework\c_api_util.py in __init__(self)
#      48
#      49   def __init__(self):
# ---> 50     self.graph = c_api.TF_NewGraph()
#      51     # Note: when we're destructing the global context (i.e when the process is
#      52     # terminating) we may have already deleted other modules. By capturing the
#
# KeyboardInterrupt:

# %%
for (i,layer) in enumerate(model.trainable_weights):
        if 'bn' in layer.name or 'bias' in layer.name:
            pass
        else:
            print(layer.name)
            a = tf.reshape(layer,[-1])
            b = a.numpy()
            
            plt.axvline(x=-bk[i],color='r')
            plt.hist(b,100)
            
            plt.axvline(x=bk[i],color='r')
            plt.text(bk[i], 600, 'bk')
            plt.text(-bk[i], 600, '-bk')
            #plt.ylim([0,100])
            plt.show()

# %%
import pandas as pd

data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_02.csv')

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
model = keras.models.load_model('test_02.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
for layer in model.layers:
    if layer.name == 'conv4':
        a = tf.reshape(layer.weights[0],[-1])
        b = a.numpy()
        plt.hist(b,200)
        plt.show()

        plt.hist(b,200)
        plt.ylim((0,150))
        plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
with tf.device('/device:CPU:0'):
    test_accuracy = tf.keras.metrics.Accuracy()
    logits = model(x_test, training=False)
    prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
    test_accuracy(prediction, y_test)
    print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 85.900%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# 2.7.0
# 1
# /device:GPU:0

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255
#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout (Dropout)           (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_1 (Dropout)         (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_2 (Dropout)         (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_3 (Dropout)         (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 140
alpha = 0.75
n_bits = 8

learning_rate = 0.015
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_10.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_10.csv')
# Out:
# Created Tensor of velocity
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Epoch 1/140 	 Loss = 1.657 	 Train Acc = 41.428% 	 Sparsity = 56.245% 	 Test Loss = 1.576 	Test Acc = 45.450%
# New test accuracy is 45.450%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/140 	 Loss = 1.275 	 Train Acc = 54.038% 	 Sparsity = 58.004% 	 Test Loss = 1.111 	Test Acc = 60.540%
# New test accuracy is 60.540%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/140 	 Loss = 1.121 	 Train Acc = 60.086% 	 Sparsity = 59.414% 	 Test Loss = 0.975 	Test Acc = 65.450%
# New test accuracy is 65.450%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/140 	 Loss = 1.024 	 Train Acc = 63.672% 	 Sparsity = 60.249% 	 Test Loss = 0.907 	Test Acc = 67.840%
# New test accuracy is 67.840%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 5/140 	 Loss = 0.949 	 Train Acc = 66.588% 	 Sparsity = 60.904% 	 Test Loss = 0.877 	Test Acc = 68.780%
# New test accuracy is 68.780%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/140 	 Loss = 0.901 	 Train Acc = 68.592% 	 Sparsity = 61.420% 	 Test Loss = 0.853 	Test Acc = 70.490%
# New test accuracy is 70.490%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/140 	 Loss = 0.860 	 Train Acc = 69.594% 	 Sparsity = 61.855% 	 Test Loss = 0.809 	Test Acc = 71.740%
# New test accuracy is 71.740%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/140 	 Loss = 0.839 	 Train Acc = 70.720% 	 Sparsity = 63.484% 	 Test Loss = 0.716 	Test Acc = 75.320%
# New test accuracy is 75.320%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/140 	 Loss = 0.812 	 Train Acc = 71.932% 	 Sparsity = 63.788% 	 Test Loss = 0.847 	Test Acc = 70.540%
# Epoch 10/140 	 Loss = 0.794 	 Train Acc = 72.232% 	 Sparsity = 64.049% 	 Test Loss = 0.709 	Test Acc = 75.370%
# New test accuracy is 75.370%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 11/140 	 Loss = 0.780 	 Train Acc = 72.840% 	 Sparsity = 64.276% 	 Test Loss = 0.789 	Test Acc = 72.680%
# Epoch 12/140 	 Loss = 0.762 	 Train Acc = 73.460% 	 Sparsity = 64.486% 	 Test Loss = 0.683 	Test Acc = 76.350%
# New test accuracy is 76.350%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 13/140 	 Loss = 0.756 	 Train Acc = 73.924% 	 Sparsity = 64.665% 	 Test Loss = 0.686 	Test Acc = 76.420%
# New test accuracy is 76.420%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 14/140 	 Loss = 0.751 	 Train Acc = 74.098% 	 Sparsity = 64.825% 	 Test Loss = 0.682 	Test Acc = 76.460%
# New test accuracy is 76.460%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 15/140 	 Loss = 0.736 	 Train Acc = 74.422% 	 Sparsity = 64.971% 	 Test Loss = 0.680 	Test Acc = 76.420%
# Epoch 16/140 	 Loss = 0.728 	 Train Acc = 74.596% 	 Sparsity = 65.107% 	 Test Loss = 0.662 	Test Acc = 77.560%
# New test accuracy is 77.560%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 17/140 	 Loss = 0.721 	 Train Acc = 75.110% 	 Sparsity = 65.229% 	 Test Loss = 0.661 	Test Acc = 77.510%
# Epoch 18/140 	 Loss = 0.714 	 Train Acc = 75.316% 	 Sparsity = 65.339% 	 Test Loss = 0.667 	Test Acc = 77.220%
# Epoch 19/140 	 Loss = 0.711 	 Train Acc = 75.102% 	 Sparsity = 65.435% 	 Test Loss = 0.665 	Test Acc = 77.130%
# Epoch 20/140 	 Loss = 0.703 	 Train Acc = 75.628% 	 Sparsity = 65.527% 	 Test Loss = 0.678 	Test Acc = 76.580%
# Epoch 21/140 	 Loss = 0.701 	 Train Acc = 75.870% 	 Sparsity = 65.606% 	 Test Loss = 0.657 	Test Acc = 77.600%
# New test accuracy is 77.600%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 22/140 	 Loss = 0.697 	 Train Acc = 76.050% 	 Sparsity = 65.684% 	 Test Loss = 0.654 	Test Acc = 77.480%
# Epoch 23/140 	 Loss = 0.695 	 Train Acc = 75.842% 	 Sparsity = 65.758% 	 Test Loss = 0.645 	Test Acc = 77.970%
# New test accuracy is 77.970%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 24/140 	 Loss = 0.694 	 Train Acc = 76.014% 	 Sparsity = 65.832% 	 Test Loss = 0.732 	Test Acc = 75.070%
# Epoch 25/140 	 Loss = 0.688 	 Train Acc = 76.082% 	 Sparsity = 65.895% 	 Test Loss = 0.646 	Test Acc = 77.930%
# Epoch 26/140 	 Loss = 0.686 	 Train Acc = 76.206% 	 Sparsity = 65.953% 	 Test Loss = 0.634 	Test Acc = 78.510%
# New test accuracy is 78.510%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 27/140 	 Loss = 0.687 	 Train Acc = 76.106% 	 Sparsity = 66.007% 	 Test Loss = 0.653 	Test Acc = 77.390%
# Epoch 28/140 	 Loss = 0.683 	 Train Acc = 76.252% 	 Sparsity = 66.060% 	 Test Loss = 0.662 	Test Acc = 77.300%
# Epoch 29/140 	 Loss = 0.675 	 Train Acc = 76.564% 	 Sparsity = 66.107% 	 Test Loss = 0.668 	Test Acc = 76.720%
# Epoch 30/140 	 Loss = 0.673 	 Train Acc = 76.684% 	 Sparsity = 66.153% 	 Test Loss = 0.680 	Test Acc = 76.810%
# Epoch 31/140 	 Loss = 0.673 	 Train Acc = 76.722% 	 Sparsity = 66.194% 	 Test Loss = 0.618 	Test Acc = 78.760%
# New test accuracy is 78.760%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 32/140 	 Loss = 0.677 	 Train Acc = 76.632% 	 Sparsity = 66.236% 	 Test Loss = 0.608 	Test Acc = 79.020%
# New test accuracy is 79.020%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 33/140 	 Loss = 0.669 	 Train Acc = 76.838% 	 Sparsity = 66.275% 	 Test Loss = 0.615 	Test Acc = 79.250%
# New test accuracy is 79.250%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 34/140 	 Loss = 0.675 	 Train Acc = 76.728% 	 Sparsity = 66.312% 	 Test Loss = 0.619 	Test Acc = 78.760%
# Epoch 35/140 	 Loss = 0.671 	 Train Acc = 76.656% 	 Sparsity = 66.351% 	 Test Loss = 0.618 	Test Acc = 79.080%
# Epoch 36/140 	 Loss = 0.668 	 Train Acc = 76.724% 	 Sparsity = 66.383% 	 Test Loss = 0.627 	Test Acc = 78.740%
# Epoch 37/140 	 Loss = 0.668 	 Train Acc = 76.670% 	 Sparsity = 66.413% 	 Test Loss = 0.663 	Test Acc = 76.930%
# Epoch 38/140 	 Loss = 0.669 	 Train Acc = 76.546% 	 Sparsity = 66.442% 	 Test Loss = 0.639 	Test Acc = 78.090%
# Epoch 39/140 	 Loss = 0.662 	 Train Acc = 77.158% 	 Sparsity = 66.473% 	 Test Loss = 0.628 	Test Acc = 78.500%
# Epoch 40/140 	 Loss = 0.665 	 Train Acc = 76.840% 	 Sparsity = 66.501% 	 Test Loss = 0.630 	Test Acc = 78.600%
# Epoch 41/140 	 Loss = 0.660 	 Train Acc = 77.088% 	 Sparsity = 66.527% 	 Test Loss = 0.645 	Test Acc = 78.020%
# Epoch 42/140 	 Loss = 0.661 	 Train Acc = 77.004% 	 Sparsity = 66.553% 	 Test Loss = 0.616 	Test Acc = 78.970%
# Epoch 43/140 	 Loss = 0.657 	 Train Acc = 77.216% 	 Sparsity = 66.576% 	 Test Loss = 0.636 	Test Acc = 78.380%
# Epoch 44/140 	 Loss = 0.654 	 Train Acc = 77.206% 	 Sparsity = 66.597% 	 Test Loss = 0.646 	Test Acc = 77.860%
# Epoch 45/140 	 Loss = 0.661 	 Train Acc = 76.972% 	 Sparsity = 66.620% 	 Test Loss = 0.646 	Test Acc = 78.020%
# Epoch 46/140 	 Loss = 0.661 	 Train Acc = 77.168% 	 Sparsity = 66.640% 	 Test Loss = 0.627 	Test Acc = 78.570%
# Epoch 47/140 	 Loss = 0.656 	 Train Acc = 77.238% 	 Sparsity = 66.659% 	 Test Loss = 0.632 	Test Acc = 78.260%
# Epoch 48/140 	 Loss = 0.660 	 Train Acc = 76.994% 	 Sparsity = 66.677% 	 Test Loss = 0.603 	Test Acc = 79.630%
# New test accuracy is 79.630%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 49/140 	 Loss = 0.652 	 Train Acc = 77.486% 	 Sparsity = 66.695% 	 Test Loss = 0.613 	Test Acc = 78.920%
# Epoch 50/140 	 Loss = 0.656 	 Train Acc = 77.258% 	 Sparsity = 66.714% 	 Test Loss = 0.624 	Test Acc = 78.870%
# Epoch 51/140 	 Loss = 0.653 	 Train Acc = 77.318% 	 Sparsity = 66.733% 	 Test Loss = 0.598 	Test Acc = 79.690%
# New test accuracy is 79.690%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 52/140 	 Loss = 0.652 	 Train Acc = 77.304% 	 Sparsity = 66.750% 	 Test Loss = 0.629 	Test Acc = 78.750%
# Epoch 53/140 	 Loss = 0.654 	 Train Acc = 77.134% 	 Sparsity = 66.766% 	 Test Loss = 0.670 	Test Acc = 77.190%
# Epoch 54/140 	 Loss = 0.651 	 Train Acc = 77.372% 	 Sparsity = 66.782% 	 Test Loss = 0.620 	Test Acc = 78.660%
# Epoch 55/140 	 Loss = 0.652 	 Train Acc = 77.252% 	 Sparsity = 66.797% 	 Test Loss = 0.624 	Test Acc = 78.770%
# Epoch 56/140 	 Loss = 0.648 	 Train Acc = 77.398% 	 Sparsity = 66.812% 	 Test Loss = 0.607 	Test Acc = 79.380%
# Epoch 57/140 	 Loss = 0.646 	 Train Acc = 77.620% 	 Sparsity = 66.829% 	 Test Loss = 0.599 	Test Acc = 79.440%
# Epoch 58/140 	 Loss = 0.647 	 Train Acc = 77.394% 	 Sparsity = 66.844% 	 Test Loss = 0.617 	Test Acc = 78.820%
# Epoch 59/140 	 Loss = 0.648 	 Train Acc = 77.506% 	 Sparsity = 66.857% 	 Test Loss = 0.620 	Test Acc = 78.720%
# Epoch 60/140 	 Loss = 0.656 	 Train Acc = 77.118% 	 Sparsity = 66.871% 	 Test Loss = 0.628 	Test Acc = 78.480%
# Epoch 61/140 	 Loss = 0.645 	 Train Acc = 77.592% 	 Sparsity = 66.885% 	 Test Loss = 0.623 	Test Acc = 78.760%
# Epoch 62/140 	 Loss = 0.646 	 Train Acc = 77.598% 	 Sparsity = 66.897% 	 Test Loss = 0.651 	Test Acc = 77.880%
# Epoch 63/140 	 Loss = 0.645 	 Train Acc = 77.654% 	 Sparsity = 66.910% 	 Test Loss = 0.623 	Test Acc = 78.590%
# Epoch 64/140 	 Loss = 0.646 	 Train Acc = 77.726% 	 Sparsity = 66.922% 	 Test Loss = 0.610 	Test Acc = 78.730%
# Epoch 65/140 	 Loss = 0.647 	 Train Acc = 77.682% 	 Sparsity = 66.933% 	 Test Loss = 0.604 	Test Acc = 79.160%
# Epoch 66/140 	 Loss = 0.642 	 Train Acc = 77.610% 	 Sparsity = 66.945% 	 Test Loss = 0.616 	Test Acc = 78.890%
# Epoch 67/140 	 Loss = 0.644 	 Train Acc = 77.644% 	 Sparsity = 66.957% 	 Test Loss = 0.626 	Test Acc = 78.560%
# Epoch 68/140 	 Loss = 0.644 	 Train Acc = 77.788% 	 Sparsity = 66.968% 	 Test Loss = 0.620 	Test Acc = 78.820%
# Epoch 69/140 	 Loss = 0.639 	 Train Acc = 77.590% 	 Sparsity = 66.978% 	 Test Loss = 0.606 	Test Acc = 79.400%
# Epoch 70/140 	 Loss = 0.644 	 Train Acc = 77.796% 	 Sparsity = 66.988% 	 Test Loss = 0.637 	Test Acc = 78.230%
# Epoch 71/140 	 Loss = 0.644 	 Train Acc = 77.624% 	 Sparsity = 66.998% 	 Test Loss = 0.636 	Test Acc = 78.110%
# Epoch 72/140 	 Loss = 0.640 	 Train Acc = 77.786% 	 Sparsity = 67.010% 	 Test Loss = 0.620 	Test Acc = 78.810%
# Epoch 73/140 	 Loss = 0.641 	 Train Acc = 77.722% 	 Sparsity = 67.021% 	 Test Loss = 0.636 	Test Acc = 78.380%
# Epoch 74/140 	 Loss = 0.645 	 Train Acc = 77.684% 	 Sparsity = 67.030% 	 Test Loss = 0.624 	Test Acc = 78.730%
# Epoch 75/140 	 Loss = 0.639 	 Train Acc = 77.828% 	 Sparsity = 67.039% 	 Test Loss = 0.603 	Test Acc = 79.190%
# Epoch 76/140 	 Loss = 0.642 	 Train Acc = 77.682% 	 Sparsity = 67.050% 	 Test Loss = 0.630 	Test Acc = 78.360%
# Epoch 77/140 	 Loss = 0.642 	 Train Acc = 77.722% 	 Sparsity = 67.059% 	 Test Loss = 0.622 	Test Acc = 78.740%
# Epoch 78/140 	 Loss = 0.637 	 Train Acc = 77.902% 	 Sparsity = 67.068% 	 Test Loss = 0.611 	Test Acc = 79.070%
# Epoch 79/140 	 Loss = 0.637 	 Train Acc = 77.818% 	 Sparsity = 67.077% 	 Test Loss = 0.665 	Test Acc = 77.470%
# Epoch 80/140 	 Loss = 0.641 	 Train Acc = 77.728% 	 Sparsity = 67.086% 	 Test Loss = 0.590 	Test Acc = 79.780%
# New test accuracy is 79.780%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 81/140 	 Loss = 0.642 	 Train Acc = 77.778% 	 Sparsity = 67.094% 	 Test Loss = 0.591 	Test Acc = 79.640%
# Epoch 82/140 	 Loss = 0.640 	 Train Acc = 77.664% 	 Sparsity = 67.102% 	 Test Loss = 0.604 	Test Acc = 79.350%
# Epoch 83/140 	 Loss = 0.642 	 Train Acc = 77.472% 	 Sparsity = 67.109% 	 Test Loss = 0.635 	Test Acc = 77.910%
# Epoch 84/140 	 Loss = 0.637 	 Train Acc = 77.790% 	 Sparsity = 67.117% 	 Test Loss = 0.631 	Test Acc = 78.420%
# Epoch 85/140 	 Loss = 0.630 	 Train Acc = 78.188% 	 Sparsity = 67.123% 	 Test Loss = 0.628 	Test Acc = 78.530%
# Epoch 86/140 	 Loss = 0.640 	 Train Acc = 77.750% 	 Sparsity = 67.131% 	 Test Loss = 0.588 	Test Acc = 79.840%
# New test accuracy is 79.840%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 87/140 	 Loss = 0.634 	 Train Acc = 78.232% 	 Sparsity = 67.139% 	 Test Loss = 0.623 	Test Acc = 78.550%
# Epoch 88/140 	 Loss = 0.638 	 Train Acc = 77.816% 	 Sparsity = 67.145% 	 Test Loss = 0.616 	Test Acc = 78.850%
# Epoch 89/140 	 Loss = 0.634 	 Train Acc = 78.080% 	 Sparsity = 67.152% 	 Test Loss = 0.606 	Test Acc = 79.070%
# Epoch 90/140 	 Loss = 0.636 	 Train Acc = 77.810% 	 Sparsity = 67.160% 	 Test Loss = 0.611 	Test Acc = 78.990%
# Epoch 91/140 	 Loss = 0.635 	 Train Acc = 77.986% 	 Sparsity = 67.168% 	 Test Loss = 0.627 	Test Acc = 78.870%
# Epoch 92/140 	 Loss = 0.640 	 Train Acc = 77.720% 	 Sparsity = 67.174% 	 Test Loss = 0.632 	Test Acc = 78.250%
# Epoch 93/140 	 Loss = 0.641 	 Train Acc = 77.848% 	 Sparsity = 67.181% 	 Test Loss = 0.605 	Test Acc = 79.330%
# Epoch 94/140 	 Loss = 0.637 	 Train Acc = 77.850% 	 Sparsity = 67.187% 	 Test Loss = 0.600 	Test Acc = 79.720%
# Epoch 95/140 	 Loss = 0.636 	 Train Acc = 77.746% 	 Sparsity = 67.194% 	 Test Loss = 0.591 	Test Acc = 79.770%
# Epoch 96/140 	 Loss = 0.641 	 Train Acc = 77.566% 	 Sparsity = 67.200% 	 Test Loss = 0.594 	Test Acc = 79.670%
# Epoch 97/140 	 Loss = 0.631 	 Train Acc = 78.202% 	 Sparsity = 67.205% 	 Test Loss = 0.597 	Test Acc = 79.290%
# Epoch 98/140 	 Loss = 0.633 	 Train Acc = 78.118% 	 Sparsity = 67.211% 	 Test Loss = 0.604 	Test Acc = 79.620%
# Epoch 99/140 	 Loss = 0.637 	 Train Acc = 77.812% 	 Sparsity = 67.217% 	 Test Loss = 0.616 	Test Acc = 78.940%
# Epoch 100/140 	 Loss = 0.635 	 Train Acc = 77.828% 	 Sparsity = 67.223% 	 Test Loss = 0.608 	Test Acc = 79.170%
# Epoch 101/140 	 Loss = 0.634 	 Train Acc = 78.010% 	 Sparsity = 67.227% 	 Test Loss = 0.625 	Test Acc = 78.730%
# Epoch 102/140 	 Loss = 0.630 	 Train Acc = 78.040% 	 Sparsity = 67.233% 	 Test Loss = 0.605 	Test Acc = 79.260%
# Epoch 103/140 	 Loss = 0.636 	 Train Acc = 77.836% 	 Sparsity = 67.237% 	 Test Loss = 0.608 	Test Acc = 79.180%
# Epoch 104/140 	 Loss = 0.637 	 Train Acc = 77.878% 	 Sparsity = 67.242% 	 Test Loss = 0.608 	Test Acc = 79.250%
# Epoch 105/140 	 Loss = 0.629 	 Train Acc = 77.994% 	 Sparsity = 67.247% 	 Test Loss = 0.599 	Test Acc = 79.600%
# Epoch 106/140 	 Loss = 0.635 	 Train Acc = 77.748% 	 Sparsity = 67.252% 	 Test Loss = 0.631 	Test Acc = 78.320%
# Epoch 107/140 	 Loss = 0.630 	 Train Acc = 78.272% 	 Sparsity = 67.257% 	 Test Loss = 0.602 	Test Acc = 79.720%
# Epoch 108/140 	 Loss = 0.636 	 Train Acc = 77.878% 	 Sparsity = 67.262% 	 Test Loss = 0.616 	Test Acc = 79.150%
# Epoch 109/140 	 Loss = 0.637 	 Train Acc = 77.686% 	 Sparsity = 67.267% 	 Test Loss = 0.624 	Test Acc = 78.450%
# Epoch 110/140 	 Loss = 0.634 	 Train Acc = 78.172% 	 Sparsity = 67.272% 	 Test Loss = 0.596 	Test Acc = 79.560%
# Epoch 111/140 	 Loss = 0.631 	 Train Acc = 77.946% 	 Sparsity = 67.277% 	 Test Loss = 0.578 	Test Acc = 80.160%
# New test accuracy is 80.160%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 112/140 	 Loss = 0.632 	 Train Acc = 78.024% 	 Sparsity = 67.281% 	 Test Loss = 0.592 	Test Acc = 79.750%
# Epoch 113/140 	 Loss = 0.628 	 Train Acc = 78.232% 	 Sparsity = 67.286% 	 Test Loss = 0.605 	Test Acc = 79.410%
# Epoch 114/140 	 Loss = 0.640 	 Train Acc = 77.786% 	 Sparsity = 67.290% 	 Test Loss = 0.604 	Test Acc = 79.440%
# Epoch 115/140 	 Loss = 0.636 	 Train Acc = 77.876% 	 Sparsity = 67.294% 	 Test Loss = 0.633 	Test Acc = 78.490%
# Epoch 116/140 	 Loss = 0.633 	 Train Acc = 77.968% 	 Sparsity = 67.298% 	 Test Loss = 0.607 	Test Acc = 79.370%
# Epoch 117/140 	 Loss = 0.633 	 Train Acc = 77.874% 	 Sparsity = 67.302% 	 Test Loss = 0.597 	Test Acc = 79.560%
# Epoch 118/140 	 Loss = 0.631 	 Train Acc = 77.924% 	 Sparsity = 67.307% 	 Test Loss = 0.592 	Test Acc = 79.750%
# Epoch 119/140 	 Loss = 0.633 	 Train Acc = 78.130% 	 Sparsity = 67.311% 	 Test Loss = 0.596 	Test Acc = 79.580%
# Epoch 120/140 	 Loss = 0.632 	 Train Acc = 77.982% 	 Sparsity = 67.316% 	 Test Loss = 0.626 	Test Acc = 78.510%
# Epoch 121/140 	 Loss = 0.630 	 Train Acc = 78.050% 	 Sparsity = 67.320% 	 Test Loss = 0.610 	Test Acc = 79.110%
# Epoch 122/140 	 Loss = 0.632 	 Train Acc = 78.006% 	 Sparsity = 67.324% 	 Test Loss = 0.608 	Test Acc = 79.200%
# Epoch 123/140 	 Loss = 0.632 	 Train Acc = 77.808% 	 Sparsity = 67.328% 	 Test Loss = 0.619 	Test Acc = 78.800%
# Epoch 124/140 	 Loss = 0.630 	 Train Acc = 78.054% 	 Sparsity = 67.333% 	 Test Loss = 0.619 	Test Acc = 78.770%
# Epoch 125/140 	 Loss = 0.629 	 Train Acc = 77.880% 	 Sparsity = 67.336% 	 Test Loss = 0.602 	Test Acc = 79.740%
# Epoch 126/140 	 Loss = 0.631 	 Train Acc = 78.072% 	 Sparsity = 67.340% 	 Test Loss = 0.596 	Test Acc = 79.540%
# Epoch 127/140 	 Loss = 0.632 	 Train Acc = 77.974% 	 Sparsity = 67.344% 	 Test Loss = 0.614 	Test Acc = 79.020%
# Epoch 128/140 	 Loss = 0.632 	 Train Acc = 77.916% 	 Sparsity = 67.348% 	 Test Loss = 0.609 	Test Acc = 78.980%
# Epoch 129/140 	 Loss = 0.634 	 Train Acc = 77.884% 	 Sparsity = 67.351% 	 Test Loss = 0.611 	Test Acc = 78.990%
# Epoch 130/140 	 Loss = 0.633 	 Train Acc = 78.050% 	 Sparsity = 67.354% 	 Test Loss = 0.614 	Test Acc = 78.860%
# Epoch 131/140 	 Loss = 0.632 	 Train Acc = 78.096% 	 Sparsity = 67.357% 	 Test Loss = 0.626 	Test Acc = 78.520%
# Epoch 132/140 	 Loss = 0.631 	 Train Acc = 77.908% 	 Sparsity = 67.361% 	 Test Loss = 0.592 	Test Acc = 79.680%
# Epoch 133/140 	 Loss = 0.637 	 Train Acc = 77.986% 	 Sparsity = 67.364% 	 Test Loss = 0.616 	Test Acc = 78.920%
# Epoch 134/140 	 Loss = 0.630 	 Train Acc = 77.990% 	 Sparsity = 67.367% 	 Test Loss = 0.617 	Test Acc = 78.730%
# Epoch 135/140 	 Loss = 0.631 	 Train Acc = 78.104% 	 Sparsity = 67.371% 	 Test Loss = 0.615 	Test Acc = 79.170%
# Epoch 136/140 	 Loss = 0.628 	 Train Acc = 78.282% 	 Sparsity = 67.374% 	 Test Loss = 0.596 	Test Acc = 79.570%
# Epoch 137/140 	 Loss = 0.633 	 Train Acc = 78.070% 	 Sparsity = 67.378% 	 Test Loss = 0.640 	Test Acc = 77.870%
# Epoch 138/140 	 Loss = 0.631 	 Train Acc = 78.194% 	 Sparsity = 67.381% 	 Test Loss = 0.607 	Test Acc = 79.260%
# Epoch 139/140 	 Loss = 0.634 	 Train Acc = 77.884% 	 Sparsity = 67.384% 	 Test Loss = 0.607 	Test Acc = 79.100%
# Epoch 140/140 	 Loss = 0.632 	 Train Acc = 78.140% 	 Sparsity = 67.387% 	 Test Loss = 0.625 	Test Acc = 78.810%

# %%
bk
# Out:
# []

# %%
for (i,layer) in enumerate(model.trainable_weights):
        if 'bn' in layer.name or 'bias' in layer.name:
            pass
        else:
            print(layer.name)
            a = tf.reshape(layer,[-1])
            b = a.numpy()
            
            plt.axvline(x=-bk[i],color='r')
            plt.hist(b,100)
            
            plt.axvline(x=bk[i],color='r')
            #plt.text(bk[i], 600, 'bk')
            #plt.text(-bk[i], 600, '-bk')
            plt.ylim([0,300])
            plt.show()
# Out:
# conv1/kernel:0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8844/4165136830.py in <module>
#       7             b = a.numpy()
#       8
# ----> 9             plt.axvline(x=-bk[i],color='r')
#      10             plt.hist(b,100)
#      11
#
# IndexError: list index out of range

# %%
import pandas as pd

data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_10.csv')

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
model = keras.models.load_model('test_10.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
for layer in model.layers:
    if layer.name == 'conv4':
        a = tf.reshape(layer.weights[0],[-1])
        b = a.numpy()
        plt.hist(b,200)
        plt.show()

        plt.hist(b,200)
        plt.ylim((0,150))
        plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
with tf.device('/device:CPU:0'):
    test_accuracy = tf.keras.metrics.Accuracy()
    logits = model(x_test, training=False)
    prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
    test_accuracy(prediction, y_test)
    print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 80.160%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

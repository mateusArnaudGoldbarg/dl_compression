# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# 2.7.0
# 1
# /device:GPU:0

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255
#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout_8 (Dropout)         (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_9 (Dropout)         (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_10 (Dropout)        (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_11 (Dropout)        (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 150
alpha = 0.5
n_bits = 8

learning_rate = 0.015
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_6.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0 and alpha > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0 and alpha > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        #bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_6.csv')
# Out:
# Created Tensor of velocity
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Epoch 1/150 	 Loss = 1.686 	 Train Acc = 41.504% 	 Sparsity = 43.944% 	 Test Loss = 1.526 	Test Acc = 45.580%
# New test accuracy is 45.580%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/150 	 Loss = 1.251 	 Train Acc = 54.728% 	 Sparsity = 46.202% 	 Test Loss = 1.036 	Test Acc = 63.540%
# New test accuracy is 63.540%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/150 	 Loss = 1.070 	 Train Acc = 62.076% 	 Sparsity = 47.650% 	 Test Loss = 0.897 	Test Acc = 68.790%
# New test accuracy is 68.790%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/150 	 Loss = 0.963 	 Train Acc = 65.998% 	 Sparsity = 48.678% 	 Test Loss = 0.920 	Test Acc = 67.090%
# Epoch 5/150 	 Loss = 0.894 	 Train Acc = 68.846% 	 Sparsity = 49.500% 	 Test Loss = 0.741 	Test Acc = 73.990%
# New test accuracy is 73.990%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/150 	 Loss = 0.840 	 Train Acc = 70.684% 	 Sparsity = 50.186% 	 Test Loss = 0.738 	Test Acc = 74.290%
# New test accuracy is 74.290%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/150 	 Loss = 0.799 	 Train Acc = 72.254% 	 Sparsity = 50.765% 	 Test Loss = 0.680 	Test Acc = 76.350%
# New test accuracy is 76.350%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/150 	 Loss = 0.771 	 Train Acc = 73.226% 	 Sparsity = 51.276% 	 Test Loss = 0.667 	Test Acc = 76.980%
# New test accuracy is 76.980%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/150 	 Loss = 0.743 	 Train Acc = 74.400% 	 Sparsity = 51.718% 	 Test Loss = 0.642 	Test Acc = 77.790%
# New test accuracy is 77.790%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 10/150 	 Loss = 0.722 	 Train Acc = 75.052% 	 Sparsity = 52.768% 	 Test Loss = 0.666 	Test Acc = 76.920%
# Epoch 11/150 	 Loss = 0.700 	 Train Acc = 75.844% 	 Sparsity = 53.108% 	 Test Loss = 0.610 	Test Acc = 79.310%
# New test accuracy is 79.310%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 12/150 	 Loss = 0.687 	 Train Acc = 76.274% 	 Sparsity = 53.419% 	 Test Loss = 0.612 	Test Acc = 78.840%
# Epoch 13/150 	 Loss = 0.669 	 Train Acc = 76.786% 	 Sparsity = 53.707% 	 Test Loss = 0.619 	Test Acc = 79.050%
# Epoch 14/150 	 Loss = 0.660 	 Train Acc = 77.088% 	 Sparsity = 53.970% 	 Test Loss = 0.618 	Test Acc = 78.800%
# Epoch 15/150 	 Loss = 0.651 	 Train Acc = 77.602% 	 Sparsity = 54.210% 	 Test Loss = 0.642 	Test Acc = 77.910%
# Epoch 16/150 	 Loss = 0.637 	 Train Acc = 78.032% 	 Sparsity = 54.424% 	 Test Loss = 0.590 	Test Acc = 79.680%
# New test accuracy is 79.680%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 17/150 	 Loss = 0.630 	 Train Acc = 78.138% 	 Sparsity = 54.619% 	 Test Loss = 0.653 	Test Acc = 77.780%
# Epoch 18/150 	 Loss = 0.620 	 Train Acc = 78.560% 	 Sparsity = 54.801% 	 Test Loss = 0.595 	Test Acc = 79.420%
# Epoch 19/150 	 Loss = 0.616 	 Train Acc = 78.678% 	 Sparsity = 54.969% 	 Test Loss = 0.589 	Test Acc = 79.560%
# Epoch 20/150 	 Loss = 0.607 	 Train Acc = 79.090% 	 Sparsity = 55.127% 	 Test Loss = 0.568 	Test Acc = 80.640%
# New test accuracy is 80.640%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 21/150 	 Loss = 0.607 	 Train Acc = 78.972% 	 Sparsity = 55.269% 	 Test Loss = 0.607 	Test Acc = 79.300%
# Epoch 22/150 	 Loss = 0.600 	 Train Acc = 79.116% 	 Sparsity = 55.399% 	 Test Loss = 0.638 	Test Acc = 78.180%
# Epoch 23/150 	 Loss = 0.596 	 Train Acc = 79.364% 	 Sparsity = 55.524% 	 Test Loss = 0.599 	Test Acc = 79.660%
# Epoch 24/150 	 Loss = 0.589 	 Train Acc = 79.686% 	 Sparsity = 55.636% 	 Test Loss = 0.599 	Test Acc = 79.890%
# Epoch 25/150 	 Loss = 0.588 	 Train Acc = 79.580% 	 Sparsity = 55.746% 	 Test Loss = 0.610 	Test Acc = 79.640%
# Epoch 26/150 	 Loss = 0.583 	 Train Acc = 79.740% 	 Sparsity = 55.847% 	 Test Loss = 0.565 	Test Acc = 80.910%
# New test accuracy is 80.910%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 27/150 	 Loss = 0.578 	 Train Acc = 79.864% 	 Sparsity = 55.940% 	 Test Loss = 0.552 	Test Acc = 81.200%
# New test accuracy is 81.200%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 28/150 	 Loss = 0.578 	 Train Acc = 80.006% 	 Sparsity = 56.025% 	 Test Loss = 0.575 	Test Acc = 80.380%
# Epoch 29/150 	 Loss = 0.572 	 Train Acc = 80.028% 	 Sparsity = 56.109% 	 Test Loss = 0.567 	Test Acc = 80.570%
# Epoch 30/150 	 Loss = 0.568 	 Train Acc = 80.270% 	 Sparsity = 56.187% 	 Test Loss = 0.576 	Test Acc = 80.400%
# Epoch 31/150 	 Loss = 0.568 	 Train Acc = 80.446% 	 Sparsity = 56.264% 	 Test Loss = 0.557 	Test Acc = 80.950%
# Epoch 32/150 	 Loss = 0.569 	 Train Acc = 80.230% 	 Sparsity = 56.335% 	 Test Loss = 0.550 	Test Acc = 81.240%
# New test accuracy is 81.240%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 33/150 	 Loss = 0.560 	 Train Acc = 80.530% 	 Sparsity = 56.406% 	 Test Loss = 0.571 	Test Acc = 80.900%
# Epoch 34/150 	 Loss = 0.557 	 Train Acc = 80.502% 	 Sparsity = 56.477% 	 Test Loss = 0.555 	Test Acc = 81.330%
# New test accuracy is 81.330%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 35/150 	 Loss = 0.556 	 Train Acc = 80.612% 	 Sparsity = 56.540% 	 Test Loss = 0.586 	Test Acc = 80.240%
# Epoch 36/150 	 Loss = 0.556 	 Train Acc = 80.566% 	 Sparsity = 56.601% 	 Test Loss = 0.554 	Test Acc = 81.080%
# Epoch 37/150 	 Loss = 0.554 	 Train Acc = 80.804% 	 Sparsity = 56.661% 	 Test Loss = 0.553 	Test Acc = 81.460%
# New test accuracy is 81.460%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 38/150 	 Loss = 0.551 	 Train Acc = 80.842% 	 Sparsity = 56.718% 	 Test Loss = 0.560 	Test Acc = 80.830%
# Epoch 39/150 	 Loss = 0.551 	 Train Acc = 80.834% 	 Sparsity = 56.770% 	 Test Loss = 0.555 	Test Acc = 81.110%
# Epoch 40/150 	 Loss = 0.549 	 Train Acc = 80.856% 	 Sparsity = 56.823% 	 Test Loss = 0.561 	Test Acc = 81.170%
# Epoch 41/150 	 Loss = 0.554 	 Train Acc = 80.716% 	 Sparsity = 56.874% 	 Test Loss = 0.551 	Test Acc = 81.400%
# Epoch 42/150 	 Loss = 0.547 	 Train Acc = 80.902% 	 Sparsity = 56.919% 	 Test Loss = 0.548 	Test Acc = 81.390%
# Epoch 43/150 	 Loss = 0.549 	 Train Acc = 81.038% 	 Sparsity = 56.966% 	 Test Loss = 0.547 	Test Acc = 81.430%
# Epoch 44/150 	 Loss = 0.546 	 Train Acc = 80.926% 	 Sparsity = 57.008% 	 Test Loss = 0.553 	Test Acc = 81.320%
# Epoch 45/150 	 Loss = 0.542 	 Train Acc = 81.050% 	 Sparsity = 57.051% 	 Test Loss = 0.549 	Test Acc = 81.500%
# New test accuracy is 81.500%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 46/150 	 Loss = 0.540 	 Train Acc = 81.260% 	 Sparsity = 57.090% 	 Test Loss = 0.563 	Test Acc = 81.240%
# Epoch 47/150 	 Loss = 0.538 	 Train Acc = 81.232% 	 Sparsity = 57.129% 	 Test Loss = 0.570 	Test Acc = 80.800%
# Epoch 48/150 	 Loss = 0.535 	 Train Acc = 81.192% 	 Sparsity = 57.166% 	 Test Loss = 0.564 	Test Acc = 81.180%
# Epoch 49/150 	 Loss = 0.539 	 Train Acc = 81.216% 	 Sparsity = 57.202% 	 Test Loss = 0.568 	Test Acc = 80.460%
# Epoch 50/150 	 Loss = 0.539 	 Train Acc = 81.432% 	 Sparsity = 57.237% 	 Test Loss = 0.543 	Test Acc = 81.240%
# Epoch 51/150 	 Loss = 0.540 	 Train Acc = 81.130% 	 Sparsity = 57.271% 	 Test Loss = 0.543 	Test Acc = 81.700%
# New test accuracy is 81.700%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 52/150 	 Loss = 0.528 	 Train Acc = 81.832% 	 Sparsity = 57.305% 	 Test Loss = 0.557 	Test Acc = 80.830%
# Epoch 53/150 	 Loss = 0.535 	 Train Acc = 81.580% 	 Sparsity = 57.337% 	 Test Loss = 0.544 	Test Acc = 81.390%
# Epoch 54/150 	 Loss = 0.531 	 Train Acc = 81.534% 	 Sparsity = 57.367% 	 Test Loss = 0.547 	Test Acc = 81.310%
# Epoch 55/150 	 Loss = 0.530 	 Train Acc = 81.724% 	 Sparsity = 57.396% 	 Test Loss = 0.591 	Test Acc = 80.100%
# Epoch 56/150 	 Loss = 0.530 	 Train Acc = 81.494% 	 Sparsity = 57.424% 	 Test Loss = 0.544 	Test Acc = 81.310%
# Epoch 57/150 	 Loss = 0.530 	 Train Acc = 81.464% 	 Sparsity = 57.456% 	 Test Loss = 0.555 	Test Acc = 81.460%
# Epoch 58/150 	 Loss = 0.531 	 Train Acc = 81.316% 	 Sparsity = 57.482% 	 Test Loss = 0.568 	Test Acc = 81.260%
# Epoch 59/150 	 Loss = 0.526 	 Train Acc = 81.698% 	 Sparsity = 57.509% 	 Test Loss = 0.532 	Test Acc = 81.910%
# New test accuracy is 81.910%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 60/150 	 Loss = 0.528 	 Train Acc = 81.658% 	 Sparsity = 57.536% 	 Test Loss = 0.550 	Test Acc = 81.300%
# Epoch 61/150 	 Loss = 0.524 	 Train Acc = 81.788% 	 Sparsity = 57.560% 	 Test Loss = 0.543 	Test Acc = 81.610%
# Epoch 62/150 	 Loss = 0.529 	 Train Acc = 81.538% 	 Sparsity = 57.583% 	 Test Loss = 0.560 	Test Acc = 81.280%
# Epoch 63/150 	 Loss = 0.522 	 Train Acc = 81.976% 	 Sparsity = 57.607% 	 Test Loss = 0.557 	Test Acc = 81.150%
# Epoch 64/150 	 Loss = 0.523 	 Train Acc = 81.714% 	 Sparsity = 57.632% 	 Test Loss = 0.554 	Test Acc = 81.080%
# Epoch 65/150 	 Loss = 0.521 	 Train Acc = 81.904% 	 Sparsity = 57.653% 	 Test Loss = 0.536 	Test Acc = 81.900%
# Epoch 66/150 	 Loss = 0.519 	 Train Acc = 81.846% 	 Sparsity = 57.674% 	 Test Loss = 0.588 	Test Acc = 80.010%
# Epoch 67/150 	 Loss = 0.526 	 Train Acc = 81.662% 	 Sparsity = 57.697% 	 Test Loss = 0.531 	Test Acc = 81.720%
# Epoch 68/150 	 Loss = 0.521 	 Train Acc = 81.812% 	 Sparsity = 57.717% 	 Test Loss = 0.547 	Test Acc = 81.670%
# Epoch 69/150 	 Loss = 0.524 	 Train Acc = 81.568% 	 Sparsity = 57.738% 	 Test Loss = 0.545 	Test Acc = 81.320%
# Epoch 70/150 	 Loss = 0.518 	 Train Acc = 81.996% 	 Sparsity = 57.758% 	 Test Loss = 0.542 	Test Acc = 81.400%
# Epoch 71/150 	 Loss = 0.522 	 Train Acc = 81.730% 	 Sparsity = 57.776% 	 Test Loss = 0.539 	Test Acc = 81.970%
# New test accuracy is 81.970%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 72/150 	 Loss = 0.517 	 Train Acc = 81.962% 	 Sparsity = 57.794% 	 Test Loss = 0.530 	Test Acc = 81.860%
# Epoch 73/150 	 Loss = 0.519 	 Train Acc = 81.804% 	 Sparsity = 57.812% 	 Test Loss = 0.531 	Test Acc = 82.090%
# New test accuracy is 82.090%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 74/150 	 Loss = 0.515 	 Train Acc = 81.952% 	 Sparsity = 57.830% 	 Test Loss = 0.547 	Test Acc = 81.390%
# Epoch 75/150 	 Loss = 0.512 	 Train Acc = 82.288% 	 Sparsity = 57.847% 	 Test Loss = 0.534 	Test Acc = 82.210%
# New test accuracy is 82.210%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 76/150 	 Loss = 0.518 	 Train Acc = 81.764% 	 Sparsity = 57.864% 	 Test Loss = 0.536 	Test Acc = 82.140%
# Epoch 77/150 	 Loss = 0.523 	 Train Acc = 81.678% 	 Sparsity = 57.881% 	 Test Loss = 0.543 	Test Acc = 81.630%
# Epoch 78/150 	 Loss = 0.519 	 Train Acc = 81.730% 	 Sparsity = 57.898% 	 Test Loss = 0.524 	Test Acc = 82.210%
# Epoch 79/150 	 Loss = 0.512 	 Train Acc = 82.032% 	 Sparsity = 57.913% 	 Test Loss = 0.538 	Test Acc = 81.670%
# Epoch 80/150 	 Loss = 0.515 	 Train Acc = 82.134% 	 Sparsity = 57.929% 	 Test Loss = 0.536 	Test Acc = 82.070%
# Epoch 81/150 	 Loss = 0.514 	 Train Acc = 82.070% 	 Sparsity = 57.946% 	 Test Loss = 0.539 	Test Acc = 81.780%
# Epoch 82/150 	 Loss = 0.516 	 Train Acc = 81.920% 	 Sparsity = 57.962% 	 Test Loss = 0.546 	Test Acc = 81.270%
# Epoch 83/150 	 Loss = 0.511 	 Train Acc = 82.054% 	 Sparsity = 57.978% 	 Test Loss = 0.533 	Test Acc = 82.130%
# Epoch 84/150 	 Loss = 0.518 	 Train Acc = 81.936% 	 Sparsity = 57.992% 	 Test Loss = 0.552 	Test Acc = 81.150%
# Epoch 85/150 	 Loss = 0.514 	 Train Acc = 81.862% 	 Sparsity = 58.005% 	 Test Loss = 0.575 	Test Acc = 80.400%
# Epoch 86/150 	 Loss = 0.512 	 Train Acc = 81.934% 	 Sparsity = 58.019% 	 Test Loss = 0.534 	Test Acc = 82.130%
# Epoch 87/150 	 Loss = 0.514 	 Train Acc = 82.120% 	 Sparsity = 58.033% 	 Test Loss = 0.537 	Test Acc = 81.740%
# Epoch 88/150 	 Loss = 0.517 	 Train Acc = 81.888% 	 Sparsity = 58.047% 	 Test Loss = 0.543 	Test Acc = 81.700%
# Epoch 89/150 	 Loss = 0.512 	 Train Acc = 82.004% 	 Sparsity = 58.060% 	 Test Loss = 0.559 	Test Acc = 81.310%
# Epoch 90/150 	 Loss = 0.511 	 Train Acc = 82.038% 	 Sparsity = 58.072% 	 Test Loss = 0.557 	Test Acc = 81.340%
# Epoch 91/150 	 Loss = 0.512 	 Train Acc = 82.014% 	 Sparsity = 58.085% 	 Test Loss = 0.525 	Test Acc = 82.200%
# Epoch 92/150 	 Loss = 0.510 	 Train Acc = 82.276% 	 Sparsity = 58.096% 	 Test Loss = 0.526 	Test Acc = 82.200%
# Epoch 93/150 	 Loss = 0.511 	 Train Acc = 82.246% 	 Sparsity = 58.108% 	 Test Loss = 0.529 	Test Acc = 82.230%
# New test accuracy is 82.230%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 94/150 	 Loss = 0.507 	 Train Acc = 82.470% 	 Sparsity = 58.119% 	 Test Loss = 0.536 	Test Acc = 82.100%
# Epoch 95/150 	 Loss = 0.510 	 Train Acc = 82.166% 	 Sparsity = 58.130% 	 Test Loss = 0.525 	Test Acc = 82.020%
# Epoch 96/150 	 Loss = 0.509 	 Train Acc = 82.214% 	 Sparsity = 58.143% 	 Test Loss = 0.519 	Test Acc = 82.470%
# New test accuracy is 82.470%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 97/150 	 Loss = 0.512 	 Train Acc = 82.272% 	 Sparsity = 58.154% 	 Test Loss = 0.526 	Test Acc = 82.070%
# Epoch 98/150 	 Loss = 0.508 	 Train Acc = 82.372% 	 Sparsity = 58.166% 	 Test Loss = 0.531 	Test Acc = 81.880%
# Epoch 99/150 	 Loss = 0.511 	 Train Acc = 82.040% 	 Sparsity = 58.177% 	 Test Loss = 0.525 	Test Acc = 82.160%
# Epoch 100/150 	 Loss = 0.506 	 Train Acc = 82.316% 	 Sparsity = 58.188% 	 Test Loss = 0.533 	Test Acc = 81.880%
# Epoch 101/150 	 Loss = 0.511 	 Train Acc = 82.044% 	 Sparsity = 58.199% 	 Test Loss = 0.547 	Test Acc = 81.400%
# Epoch 102/150 	 Loss = 0.509 	 Train Acc = 82.168% 	 Sparsity = 58.209% 	 Test Loss = 0.516 	Test Acc = 82.370%
# Epoch 103/150 	 Loss = 0.507 	 Train Acc = 82.228% 	 Sparsity = 58.219% 	 Test Loss = 0.526 	Test Acc = 82.250%
# Epoch 104/150 	 Loss = 0.509 	 Train Acc = 82.244% 	 Sparsity = 58.230% 	 Test Loss = 0.560 	Test Acc = 80.880%
# Epoch 105/150 	 Loss = 0.509 	 Train Acc = 82.134% 	 Sparsity = 58.239% 	 Test Loss = 0.522 	Test Acc = 82.620%
# New test accuracy is 82.620%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 106/150 	 Loss = 0.503 	 Train Acc = 82.318% 	 Sparsity = 58.249% 	 Test Loss = 0.550 	Test Acc = 81.600%
# Epoch 107/150 	 Loss = 0.510 	 Train Acc = 82.098% 	 Sparsity = 58.261% 	 Test Loss = 0.538 	Test Acc = 81.650%
# Epoch 108/150 	 Loss = 0.507 	 Train Acc = 82.348% 	 Sparsity = 58.271% 	 Test Loss = 0.524 	Test Acc = 82.180%
# Epoch 109/150 	 Loss = 0.507 	 Train Acc = 82.234% 	 Sparsity = 58.281% 	 Test Loss = 0.518 	Test Acc = 82.570%
# Epoch 110/150 	 Loss = 0.506 	 Train Acc = 82.258% 	 Sparsity = 58.291% 	 Test Loss = 0.548 	Test Acc = 81.700%
# Epoch 111/150 	 Loss = 0.505 	 Train Acc = 82.332% 	 Sparsity = 58.300% 	 Test Loss = 0.527 	Test Acc = 82.300%
# Epoch 112/150 	 Loss = 0.502 	 Train Acc = 82.364% 	 Sparsity = 58.309% 	 Test Loss = 0.531 	Test Acc = 81.640%
# Epoch 113/150 	 Loss = 0.506 	 Train Acc = 82.242% 	 Sparsity = 58.318% 	 Test Loss = 0.525 	Test Acc = 82.220%
# Epoch 114/150 	 Loss = 0.506 	 Train Acc = 82.278% 	 Sparsity = 58.329% 	 Test Loss = 0.536 	Test Acc = 81.860%
# Epoch 115/150 	 Loss = 0.500 	 Train Acc = 82.390% 	 Sparsity = 58.336% 	 Test Loss = 0.557 	Test Acc = 80.850%
# Epoch 116/150 	 Loss = 0.506 	 Train Acc = 82.206% 	 Sparsity = 58.345% 	 Test Loss = 0.514 	Test Acc = 82.360%
# Epoch 117/150 	 Loss = 0.507 	 Train Acc = 82.300% 	 Sparsity = 58.354% 	 Test Loss = 0.518 	Test Acc = 82.360%
# Epoch 118/150 	 Loss = 0.503 	 Train Acc = 82.318% 	 Sparsity = 58.362% 	 Test Loss = 0.525 	Test Acc = 82.170%
# Epoch 119/150 	 Loss = 0.506 	 Train Acc = 82.352% 	 Sparsity = 58.370% 	 Test Loss = 0.552 	Test Acc = 81.610%
# Epoch 120/150 	 Loss = 0.508 	 Train Acc = 82.230% 	 Sparsity = 58.379% 	 Test Loss = 0.562 	Test Acc = 81.330%
# Epoch 121/150 	 Loss = 0.497 	 Train Acc = 82.766% 	 Sparsity = 58.386% 	 Test Loss = 0.571 	Test Acc = 81.150%
# Epoch 122/150 	 Loss = 0.503 	 Train Acc = 82.456% 	 Sparsity = 58.394% 	 Test Loss = 0.526 	Test Acc = 82.360%
# Epoch 123/150 	 Loss = 0.503 	 Train Acc = 82.358% 	 Sparsity = 58.402% 	 Test Loss = 0.508 	Test Acc = 82.770%
# New test accuracy is 82.770%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 124/150 	 Loss = 0.499 	 Train Acc = 82.518% 	 Sparsity = 58.409% 	 Test Loss = 0.540 	Test Acc = 81.700%
# Epoch 125/150 	 Loss = 0.504 	 Train Acc = 82.378% 	 Sparsity = 58.416% 	 Test Loss = 0.537 	Test Acc = 81.890%
# Epoch 126/150 	 Loss = 0.502 	 Train Acc = 82.376% 	 Sparsity = 58.423% 	 Test Loss = 0.537 	Test Acc = 82.120%
# Epoch 127/150 	 Loss = 0.494 	 Train Acc = 82.714% 	 Sparsity = 58.430% 	 Test Loss = 0.538 	Test Acc = 82.020%
# Epoch 128/150 	 Loss = 0.501 	 Train Acc = 82.536% 	 Sparsity = 58.437% 	 Test Loss = 0.545 	Test Acc = 81.850%
# Epoch 129/150 	 Loss = 0.500 	 Train Acc = 82.552% 	 Sparsity = 58.444% 	 Test Loss = 0.532 	Test Acc = 82.040%
# Epoch 130/150 	 Loss = 0.501 	 Train Acc = 82.566% 	 Sparsity = 58.450% 	 Test Loss = 0.521 	Test Acc = 82.390%
# Epoch 131/150 	 Loss = 0.505 	 Train Acc = 82.240% 	 Sparsity = 58.458% 	 Test Loss = 0.522 	Test Acc = 82.590%
# Epoch 132/150 	 Loss = 0.501 	 Train Acc = 82.576% 	 Sparsity = 58.464% 	 Test Loss = 0.554 	Test Acc = 81.450%
# Epoch 133/150 	 Loss = 0.500 	 Train Acc = 82.642% 	 Sparsity = 58.470% 	 Test Loss = 0.517 	Test Acc = 82.440%
# Epoch 134/150 	 Loss = 0.498 	 Train Acc = 82.692% 	 Sparsity = 58.477% 	 Test Loss = 0.525 	Test Acc = 82.300%
# Epoch 135/150 	 Loss = 0.497 	 Train Acc = 82.712% 	 Sparsity = 58.483% 	 Test Loss = 0.518 	Test Acc = 82.780%
# New test accuracy is 82.780%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 136/150 	 Loss = 0.503 	 Train Acc = 82.500% 	 Sparsity = 58.489% 	 Test Loss = 0.534 	Test Acc = 82.170%
# Epoch 137/150 	 Loss = 0.502 	 Train Acc = 82.348% 	 Sparsity = 58.495% 	 Test Loss = 0.523 	Test Acc = 82.340%
# Epoch 138/150 	 Loss = 0.504 	 Train Acc = 82.410% 	 Sparsity = 58.501% 	 Test Loss = 0.536 	Test Acc = 82.060%
# Epoch 139/150 	 Loss = 0.502 	 Train Acc = 82.642% 	 Sparsity = 58.506% 	 Test Loss = 0.524 	Test Acc = 82.240%
# Epoch 140/150 	 Loss = 0.495 	 Train Acc = 82.672% 	 Sparsity = 58.512% 	 Test Loss = 0.530 	Test Acc = 82.290%
# Epoch 141/150 	 Loss = 0.501 	 Train Acc = 82.432% 	 Sparsity = 58.518% 	 Test Loss = 0.525 	Test Acc = 82.210%
# Epoch 142/150 	 Loss = 0.499 	 Train Acc = 82.500% 	 Sparsity = 58.524% 	 Test Loss = 0.517 	Test Acc = 82.580%
# Epoch 143/150 	 Loss = 0.504 	 Train Acc = 82.390% 	 Sparsity = 58.530% 	 Test Loss = 0.534 	Test Acc = 81.900%
# Epoch 144/150 	 Loss = 0.505 	 Train Acc = 82.082% 	 Sparsity = 58.536% 	 Test Loss = 0.520 	Test Acc = 82.600%
# Epoch 145/150 	 Loss = 0.501 	 Train Acc = 82.464% 	 Sparsity = 58.541% 	 Test Loss = 0.537 	Test Acc = 81.820%
# Epoch 146/150 	 Loss = 0.499 	 Train Acc = 82.626% 	 Sparsity = 58.547% 	 Test Loss = 0.533 	Test Acc = 82.010%
# Epoch 147/150 	 Loss = 0.497 	 Train Acc = 82.588% 	 Sparsity = 58.551% 	 Test Loss = 0.541 	Test Acc = 82.080%
# Epoch 148/150 	 Loss = 0.499 	 Train Acc = 82.688% 	 Sparsity = 58.556% 	 Test Loss = 0.521 	Test Acc = 82.300%
# Epoch 149/150 	 Loss = 0.498 	 Train Acc = 82.552% 	 Sparsity = 58.561% 	 Test Loss = 0.521 	Test Acc = 82.350%
# Epoch 150/150 	 Loss = 0.498 	 Train Acc = 82.526% 	 Sparsity = 58.566% 	 Test Loss = 0.525 	Test Acc = 82.180%

# %%
for (i,layer) in enumerate(model.trainable_weights):
        if 'bn' in layer.name or 'bias' in layer.name:
            pass
        else:
            print(layer.name)
            a = tf.reshape(layer,[-1])
            b = a.numpy()
            
            plt.axvline(x=-bk[i],color='r')
            plt.hist(b,100)
            
            plt.axvline(x=bk[i],color='r')
            plt.text(bk[i], 600, 'bk')
            plt.text(-bk[i], 600, '-bk')
            #plt.ylim([0,100])
            plt.show()
# Out:
# conv1/kernel:0
# conv2/kernel:0
# conv3/kernel:0
# conv4/kernel:0
# conv5/kernel:0
# conv6/kernel:0
# dense3/kernel:0
# dense4/kernel:0

# %%
import pandas as pd

data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_6.csv')

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
model = keras.models.load_model('test_6.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
for layer in model.layers:
    if layer.name == 'conv4':
        a = tf.reshape(layer.weights[0],[-1])
        b = a.numpy()
        plt.hist(b,200)
        plt.show()

        plt.hist(b,200)
        plt.ylim((0,150))
        plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
with tf.device('/device:CPU:0'):
    test_accuracy = tf.keras.metrics.Accuracy()
    logits = model(x_test, training=False)
    prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
    test_accuracy(prediction, y_test)
    print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 82.780%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.7.0
# 1

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255

#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        keras.layers.Dense(256, name="dense1", activation='relu'),
        keras.layers.BatchNormalization(name="bn7"),
        keras.layers.Dropout(0.4),
        keras.layers.Dense(128, name="dense2", activation='relu'),
        #keras.layers.Dropout(0.2),
        #keras.layers.Dense(128, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn8"),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout_1 (Dropout)         (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_2 (Dropout)         (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_3 (Dropout)         (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense1 (Dense)              (64, 256)                 524544
#
#  bn7 (BatchNormalization)    (64, 256)                 1024
#
#  dropout_4 (Dropout)         (64, 256)                 0
#
#  dense2 (Dense)              (64, 128)                 32896
#
#  bn8 (BatchNormalization)    (64, 128)                 512
#
#  dropout_5 (Dropout)         (64, 128)                 0
#
#  dense4 (Dense)              (64, 10)                  1290
#
# =================================================================
# Total params: 849,066
# Trainable params: 847,402
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
epochs = 100
alpha = 0.25
n_bits = 16

learning_rate = 0.05
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "alpha_025_bits_16_lr_005.h5"

#TODO: Quantizition of gammas and betas of batch_normalization layer
for epoch in range(epochs):
    # Iterate over the batches of the dataset.
    loss_batch = np.array([])
    loss_test_batch = np.array([])
    for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
      n_zeros = 0
      size = 0
      #pruning
      if alpha > 0:
        bk = []
        for layer_weights in model.trainable_variables:
          if 'bn' in layer_weights.name:
              bk.append(-1)
          else:
              #flatten weights
              f_weights = tf.reshape(layer_weights,[-1])
              #get standard deviation of each layer
              lim = alpha*tf.math.reduce_std(f_weights)
              bk.append(lim)
              #create a mask
              mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
              #assign pruned weights to the layer
              layer_weights.assign(tf.math.multiply(layer_weights,mask))
              #check sparsity
              flat_array = np.array((tf.reshape(mask,[-1])))
              n_zeros += np.count_nonzero(np.array(flat_array) == 0)
              size += flat_array.shape[0]
              sparsity = n_zeros*100/size
      else:
        bk = [0] * len(model.trainable_weights)

      #Cópia do modelo
      if n_bits > 0 and alpha > 0:
          model_copy = keras.models.clone_model(model)
          model_copy.set_weights(model.get_weights())
      
      #Quantização
      if n_bits > 0 and alpha > 0:
          for i, layer_weights in enumerate(model.trainable_variables):
              if 'bn' in layer_weights.name:
                  pass
              else:
                  qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                  ck = tf.math.round(layer_weights / qk_line) * qk_line
                  layer_weights.assign(ck)

      with tf.GradientTape() as tape:
        pred = model(x_batch_train, training=True)
        loss = loss_fn(y_batch_train, pred)
        
      grads = tape.gradient(loss, model.trainable_weights)
      if step==0 and epoch==0:
          print("Created Tensor of velocity")
          v = np.zeros_like(grads)
      if n_bits > 0 and alpha > 0:
          for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
              #TODO: Add momentum and velocity
              grads[i] = grads[i] * learning_rate
              #Get value of velocity
              v[i] = tf.math.subtract(momentum*v[i], grads[i])
              # WEIGHT UPDATE
              layer_weights.assign(tf.math.add(copied_weights, v[i]))
      else:
          for i, layer_weights in enumerate(model.trainable_variables):
              
              grads[i] = grads[i] * learning_rate
              v[i] = tf.math.subtract(momentum*v[i], grads[i])
              #WEIGHT UPDATE
              layer_weights.assign(tf.math.add(layer_weights, v[i]))
      predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
      train_accuracy.update_state(y_batch_train,predictions)

      #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
      #acc = train_accuracy(y_batch_train, predictions)

      #keep track of loss by batch
      loss_batch = np.append(loss_batch, loss)
    acc = train_accuracy.result()

    #reset states
    train_accuracy.reset_states()
    #mean of loss by epoch
    model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
    #train accuracy by epoch
    model_train_acc = np.append(model_train_acc, acc*100)
    #sparsity by epoch
    model_sparsity = np.append(model_sparsity, sparsity)

    if alpha > 0:
        bk = []
        for layer_weights in model.trainable_variables:
            if 'bn' in layer_weights.name:
                bk.append(-1)
            else:
                #flatten weights
                f_weights = tf.reshape(layer_weights,[-1])
                #get standard deviation of each layer
                lim = alpha*tf.math.reduce_std(f_weights)
                bk.append(lim)
                #create a mask
                mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                #assign pruned weights to the layer
                layer_weights.assign(tf.math.multiply(layer_weights,mask))
                #check sparsity
                flat_array = np.array((tf.reshape(mask,[-1])))
                n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                size += flat_array.shape[0]
                sparsity = n_zeros*100/size
    else:
        bk = [0] * len(model.trainable_weights)

    #Quantização
    if n_bits > 0 and alpha > 0:
        for i, layer_weights in enumerate(model.trainable_variables):
            if 'bn' in layer_weights.name:
                pass
            else:
                qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                ck = tf.math.round(layer_weights / qk_line) * qk_line
                layer_weights.assign(ck)
    
    bk.clear()
    
    #Test
    acc_val = np.array([])
    for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
      test_pred = model(x_batch_test, training=False)
      test_loss = loss_fn(y_batch_test,test_pred)
      test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
      #test_acc = test_accuracy(y_batch_test, test_prediction)
      
      #acc_val = np.append(acc_val,float(test_acc))

      loss_test_batch = np.append(loss_batch,test_loss)
      test_accuracy.update_state(y_batch_test,test_prediction)

    test_acc = test_accuracy.result()
    test_accuracy.reset_states()

    model_test_acc = np.append(model_test_acc, test_acc*100)
    model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
    
    print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Acc = {:.3f}%".format(epoch+1,epochs,float(loss),float(acc*100),sparsity,float(test_acc*100)))

    if last_test_acc < test_acc:
        print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
        last_test_acc = test_acc
        model.save(model_name)
# Out:
# Created Tensor of velocity
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Epoch 1/100 	 Loss = 0.957 	 Train Acc = 48.310% 	 Sparsity = 49.292% 	 Test Acc = 53.930%
# New test accuracy is 53.930%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/100 	 Loss = 1.446 	 Train Acc = 54.856% 	 Sparsity = 55.373% 	 Test Acc = 61.260%
# New test accuracy is 61.260%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/100 	 Loss = 1.115 	 Train Acc = 61.576% 	 Sparsity = 59.846% 	 Test Acc = 63.050%
# New test accuracy is 63.050%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/100 	 Loss = 1.470 	 Train Acc = 65.346% 	 Sparsity = 63.229% 	 Test Acc = 68.130%
# New test accuracy is 68.130%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 5/100 	 Loss = 1.726 	 Train Acc = 68.020% 	 Sparsity = 65.949% 	 Test Acc = 72.680%
# New test accuracy is 72.680%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/100 	 Loss = 0.640 	 Train Acc = 70.352% 	 Sparsity = 68.160% 	 Test Acc = 73.360%
# New test accuracy is 73.360%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/100 	 Loss = 1.367 	 Train Acc = 71.412% 	 Sparsity = 70.034% 	 Test Acc = 73.490%
# New test accuracy is 73.490%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/100 	 Loss = 0.587 	 Train Acc = 72.760% 	 Sparsity = 71.613% 	 Test Acc = 75.580%
# New test accuracy is 75.580%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/100 	 Loss = 0.695 	 Train Acc = 73.532% 	 Sparsity = 73.003% 	 Test Acc = 75.410%
# Epoch 10/100 	 Loss = 0.879 	 Train Acc = 74.422% 	 Sparsity = 74.218% 	 Test Acc = 76.420%
# New test accuracy is 76.420%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 11/100 	 Loss = 0.696 	 Train Acc = 75.478% 	 Sparsity = 75.272% 	 Test Acc = 77.580%
# New test accuracy is 77.580%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 12/100 	 Loss = 0.431 	 Train Acc = 75.892% 	 Sparsity = 76.211% 	 Test Acc = 77.540%
# Epoch 13/100 	 Loss = 1.402 	 Train Acc = 76.306% 	 Sparsity = 77.035% 	 Test Acc = 78.050%
# New test accuracy is 78.050%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 14/100 	 Loss = 0.409 	 Train Acc = 76.656% 	 Sparsity = 77.794% 	 Test Acc = 78.920%
# New test accuracy is 78.920%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 15/100 	 Loss = 0.679 	 Train Acc = 77.220% 	 Sparsity = 78.437% 	 Test Acc = 77.930%
# Epoch 16/100 	 Loss = 0.669 	 Train Acc = 77.626% 	 Sparsity = 79.024% 	 Test Acc = 78.260%
# Epoch 17/100 	 Loss = 0.566 	 Train Acc = 77.850% 	 Sparsity = 79.562% 	 Test Acc = 78.480%
# Epoch 18/100 	 Loss = 0.531 	 Train Acc = 77.946% 	 Sparsity = 80.056% 	 Test Acc = 79.430%
# New test accuracy is 79.430%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 19/100 	 Loss = 0.672 	 Train Acc = 78.180% 	 Sparsity = 80.512% 	 Test Acc = 77.550%
# Epoch 20/100 	 Loss = 0.939 	 Train Acc = 78.658% 	 Sparsity = 80.928% 	 Test Acc = 78.510%
# Epoch 21/100 	 Loss = 1.013 	 Train Acc = 78.678% 	 Sparsity = 81.316% 	 Test Acc = 80.360%
# New test accuracy is 80.360%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 22/100 	 Loss = 1.123 	 Train Acc = 79.006% 	 Sparsity = 81.674% 	 Test Acc = 79.830%
# Epoch 23/100 	 Loss = 0.864 	 Train Acc = 79.052% 	 Sparsity = 81.999% 	 Test Acc = 80.250%
# Epoch 24/100 	 Loss = 1.787 	 Train Acc = 79.248% 	 Sparsity = 82.309% 	 Test Acc = 80.250%
# Epoch 25/100 	 Loss = 1.050 	 Train Acc = 79.702% 	 Sparsity = 82.616% 	 Test Acc = 80.390%
# New test accuracy is 80.390%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 26/100 	 Loss = 0.488 	 Train Acc = 79.536% 	 Sparsity = 82.880% 	 Test Acc = 80.390%
# Epoch 27/100 	 Loss = 0.417 	 Train Acc = 79.722% 	 Sparsity = 83.145% 	 Test Acc = 80.190%
# Epoch 28/100 	 Loss = 1.150 	 Train Acc = 79.800% 	 Sparsity = 83.383% 	 Test Acc = 80.290%
# Epoch 29/100 	 Loss = 1.670 	 Train Acc = 79.870% 	 Sparsity = 83.611% 	 Test Acc = 80.660%
# New test accuracy is 80.660%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 30/100 	 Loss = 0.706 	 Train Acc = 79.938% 	 Sparsity = 83.837% 	 Test Acc = 80.360%
# Epoch 31/100 	 Loss = 0.999 	 Train Acc = 80.192% 	 Sparsity = 84.051% 	 Test Acc = 80.710%
# New test accuracy is 80.710%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 32/100 	 Loss = 1.386 	 Train Acc = 80.392% 	 Sparsity = 84.254% 	 Test Acc = 79.340%
# Epoch 33/100 	 Loss = 0.354 	 Train Acc = 80.664% 	 Sparsity = 84.438% 	 Test Acc = 79.950%
# Epoch 34/100 	 Loss = 0.714 	 Train Acc = 80.416% 	 Sparsity = 84.615% 	 Test Acc = 81.350%
# New test accuracy is 81.350%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 35/100 	 Loss = 0.613 	 Train Acc = 80.412% 	 Sparsity = 84.789% 	 Test Acc = 80.740%
# Epoch 36/100 	 Loss = 0.629 	 Train Acc = 80.518% 	 Sparsity = 84.958% 	 Test Acc = 79.700%
# Epoch 37/100 	 Loss = 0.450 	 Train Acc = 80.624% 	 Sparsity = 85.123% 	 Test Acc = 81.880%
# New test accuracy is 81.880%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 38/100 	 Loss = 0.878 	 Train Acc = 80.740% 	 Sparsity = 85.275% 	 Test Acc = 80.240%
# Epoch 39/100 	 Loss = 0.976 	 Train Acc = 80.922% 	 Sparsity = 85.418% 	 Test Acc = 80.960%
# Epoch 40/100 	 Loss = 0.769 	 Train Acc = 81.066% 	 Sparsity = 85.562% 	 Test Acc = 80.600%
# Epoch 41/100 	 Loss = 0.760 	 Train Acc = 80.958% 	 Sparsity = 85.687% 	 Test Acc = 81.190%
# Epoch 42/100 	 Loss = 1.047 	 Train Acc = 81.006% 	 Sparsity = 85.813% 	 Test Acc = 80.420%
# Epoch 43/100 	 Loss = 0.681 	 Train Acc = 81.048% 	 Sparsity = 85.935% 	 Test Acc = 81.230%
# Epoch 44/100 	 Loss = 0.679 	 Train Acc = 81.330% 	 Sparsity = 86.053% 	 Test Acc = 81.430%
# Epoch 45/100 	 Loss = 0.846 	 Train Acc = 81.166% 	 Sparsity = 86.172% 	 Test Acc = 81.060%
# Epoch 46/100 	 Loss = 0.387 	 Train Acc = 81.392% 	 Sparsity = 86.283% 	 Test Acc = 82.070%
# New test accuracy is 82.070%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 47/100 	 Loss = 0.378 	 Train Acc = 81.484% 	 Sparsity = 86.397% 	 Test Acc = 80.620%
# Epoch 48/100 	 Loss = 0.773 	 Train Acc = 81.440% 	 Sparsity = 86.501% 	 Test Acc = 81.630%
# Epoch 49/100 	 Loss = 0.415 	 Train Acc = 81.464% 	 Sparsity = 86.601% 	 Test Acc = 81.470%
# Epoch 50/100 	 Loss = 0.895 	 Train Acc = 81.424% 	 Sparsity = 86.702% 	 Test Acc = 81.760%
# Epoch 51/100 	 Loss = 0.607 	 Train Acc = 81.852% 	 Sparsity = 86.793% 	 Test Acc = 81.970%
# Epoch 52/100 	 Loss = 1.102 	 Train Acc = 81.502% 	 Sparsity = 86.883% 	 Test Acc = 81.630%
# Epoch 53/100 	 Loss = 0.333 	 Train Acc = 81.620% 	 Sparsity = 86.961% 	 Test Acc = 82.100%
# New test accuracy is 82.100%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 54/100 	 Loss = 1.071 	 Train Acc = 81.546% 	 Sparsity = 87.042% 	 Test Acc = 81.160%
# Epoch 55/100 	 Loss = 0.497 	 Train Acc = 81.550% 	 Sparsity = 87.130% 	 Test Acc = 82.100%
# Epoch 56/100 	 Loss = 1.599 	 Train Acc = 81.848% 	 Sparsity = 87.203% 	 Test Acc = 81.940%
# Epoch 57/100 	 Loss = 0.644 	 Train Acc = 81.860% 	 Sparsity = 87.284% 	 Test Acc = 81.910%
# Epoch 58/100 	 Loss = 0.374 	 Train Acc = 81.704% 	 Sparsity = 87.358% 	 Test Acc = 81.050%
# Epoch 59/100 	 Loss = 0.454 	 Train Acc = 81.988% 	 Sparsity = 87.425% 	 Test Acc = 80.920%
# Epoch 60/100 	 Loss = 1.082 	 Train Acc = 81.848% 	 Sparsity = 87.502% 	 Test Acc = 80.580%
# Epoch 61/100 	 Loss = 0.511 	 Train Acc = 81.768% 	 Sparsity = 87.566% 	 Test Acc = 81.200%
# Epoch 62/100 	 Loss = 0.647 	 Train Acc = 82.022% 	 Sparsity = 87.633% 	 Test Acc = 80.270%
# Epoch 63/100 	 Loss = 0.430 	 Train Acc = 81.844% 	 Sparsity = 87.700% 	 Test Acc = 81.720%
# Epoch 64/100 	 Loss = 0.617 	 Train Acc = 82.014% 	 Sparsity = 87.769% 	 Test Acc = 81.150%
# Epoch 65/100 	 Loss = 0.695 	 Train Acc = 82.086% 	 Sparsity = 87.831% 	 Test Acc = 82.040%
# Epoch 66/100 	 Loss = 0.586 	 Train Acc = 81.860% 	 Sparsity = 87.888% 	 Test Acc = 81.640%
# Epoch 67/100 	 Loss = 0.372 	 Train Acc = 81.984% 	 Sparsity = 87.946% 	 Test Acc = 80.630%
# Epoch 68/100 	 Loss = 0.854 	 Train Acc = 82.276% 	 Sparsity = 88.000% 	 Test Acc = 82.360%
# New test accuracy is 82.360%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 69/100 	 Loss = 0.370 	 Train Acc = 82.316% 	 Sparsity = 88.058% 	 Test Acc = 81.830%
# Epoch 70/100 	 Loss = 1.051 	 Train Acc = 82.310% 	 Sparsity = 88.110% 	 Test Acc = 81.850%
# Epoch 71/100 	 Loss = 0.710 	 Train Acc = 82.084% 	 Sparsity = 88.164% 	 Test Acc = 82.070%
# Epoch 72/100 	 Loss = 1.305 	 Train Acc = 82.084% 	 Sparsity = 88.215% 	 Test Acc = 80.330%
# Epoch 73/100 	 Loss = 0.331 	 Train Acc = 82.188% 	 Sparsity = 88.266% 	 Test Acc = 81.670%
# Epoch 74/100 	 Loss = 0.513 	 Train Acc = 82.140% 	 Sparsity = 88.313% 	 Test Acc = 81.910%

# %%
l = len(model.trainable_weights)
for i in range(l):
  a = tf.reshape(model.trainable_weights[i],[-1])
  b = a.numpy()
  #print(a)
  #plt.ylim(0,300)
  plt.title(str(i))
  plt.hist(b,200)
  plt.show()

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
test_accuracy = tf.keras.metrics.Accuracy()
logits = model(x_test, training=False)
prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
test_accuracy(prediction, y_test)
print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 70.520%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ce30bbed0c7e> in <module>()
#       1 classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
# ----> 2 cm = confusion_matrix(y_true=y_test, y_pred=prediction)
#       3 plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
#
# NameError: name 'confusion_matrix' is not defined

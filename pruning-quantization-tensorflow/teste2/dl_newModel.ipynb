# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# 2.7.0
# 1
# /device:GPU:0

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255
#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout_16 (Dropout)        (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_17 (Dropout)        (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_18 (Dropout)        (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_19 (Dropout)        (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 250
alpha = 0.25
n_bits = 8

learning_rate = 0.01
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_2.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0 and alpha > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0 and alpha > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)
# Out:
# Created Tensor of velocity
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Epoch 1/250 	 Loss = 1.708 	 Train Acc = 41.510% 	 Sparsity = 26.950% 	 Test Loss = 1.247 	Test Acc = 55.090%
# New test accuracy is 55.090%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/250 	 Loss = 1.208 	 Train Acc = 56.626% 	 Sparsity = 28.962% 	 Test Loss = 1.207 	Test Acc = 58.460%
# New test accuracy is 58.460%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/250 	 Loss = 1.053 	 Train Acc = 62.422% 	 Sparsity = 30.355% 	 Test Loss = 0.937 	Test Acc = 67.170%
# New test accuracy is 67.170%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/250 	 Loss = 0.949 	 Train Acc = 66.502% 	 Sparsity = 31.482% 	 Test Loss = 1.060 	Test Acc = 63.500%
# Epoch 5/250 	 Loss = 0.872 	 Train Acc = 69.312% 	 Sparsity = 32.437% 	 Test Loss = 0.850 	Test Acc = 70.010%
# New test accuracy is 70.010%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/250 	 Loss = 0.815 	 Train Acc = 71.342% 	 Sparsity = 33.264% 	 Test Loss = 0.766 	Test Acc = 72.760%
# New test accuracy is 72.760%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/250 	 Loss = 0.771 	 Train Acc = 73.078% 	 Sparsity = 34.017% 	 Test Loss = 0.804 	Test Acc = 71.690%
# Epoch 8/250 	 Loss = 0.733 	 Train Acc = 74.194% 	 Sparsity = 34.688% 	 Test Loss = 0.671 	Test Acc = 76.770%
# New test accuracy is 76.770%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/250 	 Loss = 0.710 	 Train Acc = 75.070% 	 Sparsity = 35.315% 	 Test Loss = 0.699 	Test Acc = 75.930%
# Epoch 10/250 	 Loss = 0.680 	 Train Acc = 76.164% 	 Sparsity = 35.890% 	 Test Loss = 0.650 	Test Acc = 77.660%
# New test accuracy is 77.660%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 11/250 	 Loss = 0.653 	 Train Acc = 77.222% 	 Sparsity = 36.426% 	 Test Loss = 0.627 	Test Acc = 78.150%
# New test accuracy is 78.150%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 12/250 	 Loss = 0.636 	 Train Acc = 77.756% 	 Sparsity = 36.935% 	 Test Loss = 0.592 	Test Acc = 79.210%
# New test accuracy is 79.210%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 13/250 	 Loss = 0.625 	 Train Acc = 78.152% 	 Sparsity = 37.417% 	 Test Loss = 0.594 	Test Acc = 79.540%
# New test accuracy is 79.540%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 14/250 	 Loss = 0.601 	 Train Acc = 78.954% 	 Sparsity = 37.861% 	 Test Loss = 0.594 	Test Acc = 79.680%
# New test accuracy is 79.680%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 15/250 	 Loss = 0.587 	 Train Acc = 79.670% 	 Sparsity = 38.272% 	 Test Loss = 0.621 	Test Acc = 78.770%
# Epoch 16/250 	 Loss = 0.575 	 Train Acc = 79.878% 	 Sparsity = 38.663% 	 Test Loss = 0.565 	Test Acc = 80.720%
# New test accuracy is 80.720%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 17/250 	 Loss = 0.563 	 Train Acc = 80.218% 	 Sparsity = 39.046% 	 Test Loss = 0.621 	Test Acc = 78.720%
# Epoch 18/250 	 Loss = 0.551 	 Train Acc = 80.780% 	 Sparsity = 39.398% 	 Test Loss = 0.589 	Test Acc = 80.010%
# Epoch 19/250 	 Loss = 0.538 	 Train Acc = 81.162% 	 Sparsity = 39.737% 	 Test Loss = 0.545 	Test Acc = 81.220%
# New test accuracy is 81.220%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 20/250 	 Loss = 0.535 	 Train Acc = 81.164% 	 Sparsity = 40.056% 	 Test Loss = 0.602 	Test Acc = 79.460%
# Epoch 21/250 	 Loss = 0.521 	 Train Acc = 81.884% 	 Sparsity = 40.353% 	 Test Loss = 0.590 	Test Acc = 80.250%
# Epoch 22/250 	 Loss = 0.512 	 Train Acc = 82.000% 	 Sparsity = 40.643% 	 Test Loss = 0.564 	Test Acc = 80.960%
# Epoch 23/250 	 Loss = 0.506 	 Train Acc = 82.372% 	 Sparsity = 40.913% 	 Test Loss = 0.533 	Test Acc = 82.060%
# New test accuracy is 82.060%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 24/250 	 Loss = 0.507 	 Train Acc = 82.352% 	 Sparsity = 41.177% 	 Test Loss = 0.524 	Test Acc = 82.040%
# Epoch 25/250 	 Loss = 0.495 	 Train Acc = 82.536% 	 Sparsity = 41.421% 	 Test Loss = 0.549 	Test Acc = 81.280%
# Epoch 26/250 	 Loss = 0.488 	 Train Acc = 82.806% 	 Sparsity = 41.662% 	 Test Loss = 0.519 	Test Acc = 82.460%
# New test accuracy is 82.460%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 27/250 	 Loss = 0.483 	 Train Acc = 82.860% 	 Sparsity = 41.899% 	 Test Loss = 0.572 	Test Acc = 80.530%
# Epoch 28/250 	 Loss = 0.475 	 Train Acc = 83.460% 	 Sparsity = 42.119% 	 Test Loss = 0.539 	Test Acc = 81.640%
# Epoch 29/250 	 Loss = 0.474 	 Train Acc = 83.224% 	 Sparsity = 42.329% 	 Test Loss = 0.548 	Test Acc = 81.600%
# Epoch 30/250 	 Loss = 0.465 	 Train Acc = 83.502% 	 Sparsity = 42.530% 	 Test Loss = 0.523 	Test Acc = 82.100%
# Epoch 31/250 	 Loss = 0.464 	 Train Acc = 83.580% 	 Sparsity = 42.727% 	 Test Loss = 0.565 	Test Acc = 81.000%
# Epoch 32/250 	 Loss = 0.459 	 Train Acc = 83.944% 	 Sparsity = 42.913% 	 Test Loss = 0.500 	Test Acc = 83.390%
# New test accuracy is 83.390%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 33/250 	 Loss = 0.451 	 Train Acc = 84.252% 	 Sparsity = 43.099% 	 Test Loss = 0.525 	Test Acc = 82.580%
# Epoch 34/250 	 Loss = 0.455 	 Train Acc = 83.990% 	 Sparsity = 43.279% 	 Test Loss = 0.524 	Test Acc = 82.390%
# Epoch 35/250 	 Loss = 0.442 	 Train Acc = 84.418% 	 Sparsity = 43.449% 	 Test Loss = 0.520 	Test Acc = 82.680%
# Epoch 36/250 	 Loss = 0.444 	 Train Acc = 84.406% 	 Sparsity = 43.607% 	 Test Loss = 0.508 	Test Acc = 82.990%
# Epoch 37/250 	 Loss = 0.434 	 Train Acc = 84.590% 	 Sparsity = 43.759% 	 Test Loss = 0.511 	Test Acc = 82.860%
# Epoch 38/250 	 Loss = 0.437 	 Train Acc = 84.458% 	 Sparsity = 43.911% 	 Test Loss = 0.553 	Test Acc = 81.520%
# Epoch 39/250 	 Loss = 0.431 	 Train Acc = 84.654% 	 Sparsity = 44.051% 	 Test Loss = 0.512 	Test Acc = 82.760%
# Epoch 40/250 	 Loss = 0.430 	 Train Acc = 84.964% 	 Sparsity = 44.188% 	 Test Loss = 0.516 	Test Acc = 82.680%
# Epoch 41/250 	 Loss = 0.426 	 Train Acc = 84.988% 	 Sparsity = 44.324% 	 Test Loss = 0.561 	Test Acc = 81.160%
# Epoch 42/250 	 Loss = 0.423 	 Train Acc = 85.190% 	 Sparsity = 44.455% 	 Test Loss = 0.573 	Test Acc = 81.170%
# Epoch 43/250 	 Loss = 0.421 	 Train Acc = 85.096% 	 Sparsity = 44.580% 	 Test Loss = 0.510 	Test Acc = 82.970%
# Epoch 44/250 	 Loss = 0.418 	 Train Acc = 85.376% 	 Sparsity = 44.701% 	 Test Loss = 0.501 	Test Acc = 83.250%
# Epoch 45/250 	 Loss = 0.419 	 Train Acc = 85.280% 	 Sparsity = 44.817% 	 Test Loss = 0.517 	Test Acc = 82.800%
# Epoch 46/250 	 Loss = 0.415 	 Train Acc = 85.410% 	 Sparsity = 44.932% 	 Test Loss = 0.494 	Test Acc = 83.390%
# Epoch 47/250 	 Loss = 0.412 	 Train Acc = 85.410% 	 Sparsity = 45.039% 	 Test Loss = 0.509 	Test Acc = 83.030%
# Epoch 48/250 	 Loss = 0.412 	 Train Acc = 85.212% 	 Sparsity = 45.148% 	 Test Loss = 0.556 	Test Acc = 81.610%
# Epoch 49/250 	 Loss = 0.404 	 Train Acc = 85.596% 	 Sparsity = 45.251% 	 Test Loss = 0.506 	Test Acc = 83.400%
# New test accuracy is 83.400%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 50/250 	 Loss = 0.406 	 Train Acc = 85.620% 	 Sparsity = 45.355% 	 Test Loss = 0.547 	Test Acc = 82.160%
# Epoch 51/250 	 Loss = 0.404 	 Train Acc = 85.744% 	 Sparsity = 45.452% 	 Test Loss = 0.536 	Test Acc = 82.680%
# Epoch 52/250 	 Loss = 0.403 	 Train Acc = 85.784% 	 Sparsity = 45.547% 	 Test Loss = 0.512 	Test Acc = 83.330%
# Epoch 53/250 	 Loss = 0.396 	 Train Acc = 85.896% 	 Sparsity = 45.642% 	 Test Loss = 0.486 	Test Acc = 83.810%
# New test accuracy is 83.810%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 54/250 	 Loss = 0.395 	 Train Acc = 86.040% 	 Sparsity = 45.735% 	 Test Loss = 0.511 	Test Acc = 83.160%
# Epoch 55/250 	 Loss = 0.396 	 Train Acc = 86.068% 	 Sparsity = 45.821% 	 Test Loss = 0.510 	Test Acc = 83.110%
# Epoch 56/250 	 Loss = 0.393 	 Train Acc = 86.172% 	 Sparsity = 45.909% 	 Test Loss = 0.521 	Test Acc = 82.840%
# Epoch 57/250 	 Loss = 0.397 	 Train Acc = 85.894% 	 Sparsity = 45.996% 	 Test Loss = 0.512 	Test Acc = 82.990%
# Epoch 58/250 	 Loss = 0.389 	 Train Acc = 86.184% 	 Sparsity = 46.081% 	 Test Loss = 0.486 	Test Acc = 83.890%
# New test accuracy is 83.890%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 59/250 	 Loss = 0.391 	 Train Acc = 86.220% 	 Sparsity = 46.158% 	 Test Loss = 0.495 	Test Acc = 83.620%
# Epoch 60/250 	 Loss = 0.390 	 Train Acc = 86.240% 	 Sparsity = 46.238% 	 Test Loss = 0.520 	Test Acc = 82.630%
# Epoch 61/250 	 Loss = 0.387 	 Train Acc = 86.128% 	 Sparsity = 46.313% 	 Test Loss = 0.521 	Test Acc = 82.790%
# Epoch 62/250 	 Loss = 0.380 	 Train Acc = 86.426% 	 Sparsity = 46.386% 	 Test Loss = 0.515 	Test Acc = 83.300%
# Epoch 63/250 	 Loss = 0.386 	 Train Acc = 86.322% 	 Sparsity = 46.459% 	 Test Loss = 0.500 	Test Acc = 83.670%
# Epoch 64/250 	 Loss = 0.383 	 Train Acc = 86.496% 	 Sparsity = 46.528% 	 Test Loss = 0.514 	Test Acc = 83.260%
# Epoch 65/250 	 Loss = 0.388 	 Train Acc = 86.252% 	 Sparsity = 46.599% 	 Test Loss = 0.500 	Test Acc = 83.610%
# Epoch 66/250 	 Loss = 0.385 	 Train Acc = 86.300% 	 Sparsity = 46.664% 	 Test Loss = 0.495 	Test Acc = 83.590%
# Epoch 67/250 	 Loss = 0.380 	 Train Acc = 86.538% 	 Sparsity = 46.727% 	 Test Loss = 0.494 	Test Acc = 83.780%
# Epoch 68/250 	 Loss = 0.381 	 Train Acc = 86.498% 	 Sparsity = 46.794% 	 Test Loss = 0.525 	Test Acc = 82.820%
# Epoch 69/250 	 Loss = 0.376 	 Train Acc = 86.628% 	 Sparsity = 46.857% 	 Test Loss = 0.488 	Test Acc = 83.660%
# Epoch 70/250 	 Loss = 0.383 	 Train Acc = 86.574% 	 Sparsity = 46.919% 	 Test Loss = 0.519 	Test Acc = 83.170%
# Epoch 71/250 	 Loss = 0.376 	 Train Acc = 86.634% 	 Sparsity = 46.979% 	 Test Loss = 0.511 	Test Acc = 83.270%
# Epoch 72/250 	 Loss = 0.378 	 Train Acc = 86.684% 	 Sparsity = 47.035% 	 Test Loss = 0.504 	Test Acc = 83.500%
# Epoch 73/250 	 Loss = 0.375 	 Train Acc = 86.686% 	 Sparsity = 47.095% 	 Test Loss = 0.504 	Test Acc = 83.460%
# Epoch 74/250 	 Loss = 0.375 	 Train Acc = 86.704% 	 Sparsity = 47.149% 	 Test Loss = 0.503 	Test Acc = 83.610%
# Epoch 75/250 	 Loss = 0.377 	 Train Acc = 86.622% 	 Sparsity = 47.206% 	 Test Loss = 0.504 	Test Acc = 83.490%
# Epoch 76/250 	 Loss = 0.370 	 Train Acc = 86.704% 	 Sparsity = 47.261% 	 Test Loss = 0.502 	Test Acc = 83.740%
# Epoch 77/250 	 Loss = 0.373 	 Train Acc = 86.784% 	 Sparsity = 47.313% 	 Test Loss = 0.495 	Test Acc = 83.900%
# New test accuracy is 83.900%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 78/250 	 Loss = 0.368 	 Train Acc = 86.936% 	 Sparsity = 47.365% 	 Test Loss = 0.514 	Test Acc = 83.270%
# Epoch 79/250 	 Loss = 0.373 	 Train Acc = 86.808% 	 Sparsity = 47.413% 	 Test Loss = 0.535 	Test Acc = 82.850%
# Epoch 80/250 	 Loss = 0.371 	 Train Acc = 86.920% 	 Sparsity = 47.461% 	 Test Loss = 0.494 	Test Acc = 83.720%
# Epoch 81/250 	 Loss = 0.369 	 Train Acc = 86.868% 	 Sparsity = 47.509% 	 Test Loss = 0.512 	Test Acc = 83.280%
# Epoch 82/250 	 Loss = 0.364 	 Train Acc = 87.004% 	 Sparsity = 47.558% 	 Test Loss = 0.532 	Test Acc = 82.950%
# Epoch 83/250 	 Loss = 0.367 	 Train Acc = 86.986% 	 Sparsity = 47.603% 	 Test Loss = 0.495 	Test Acc = 83.870%
# Epoch 84/250 	 Loss = 0.359 	 Train Acc = 87.112% 	 Sparsity = 47.647% 	 Test Loss = 0.517 	Test Acc = 83.290%
# Epoch 85/250 	 Loss = 0.365 	 Train Acc = 86.846% 	 Sparsity = 47.692% 	 Test Loss = 0.525 	Test Acc = 83.170%
# Epoch 86/250 	 Loss = 0.359 	 Train Acc = 87.128% 	 Sparsity = 47.737% 	 Test Loss = 0.492 	Test Acc = 83.840%
# Epoch 87/250 	 Loss = 0.359 	 Train Acc = 87.264% 	 Sparsity = 47.781% 	 Test Loss = 0.496 	Test Acc = 83.930%
# New test accuracy is 83.930%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 88/250 	 Loss = 0.363 	 Train Acc = 87.036% 	 Sparsity = 47.824% 	 Test Loss = 0.497 	Test Acc = 83.480%
# Epoch 89/250 	 Loss = 0.362 	 Train Acc = 87.106% 	 Sparsity = 47.867% 	 Test Loss = 0.500 	Test Acc = 83.880%
# Epoch 90/250 	 Loss = 0.365 	 Train Acc = 87.106% 	 Sparsity = 47.910% 	 Test Loss = 0.505 	Test Acc = 83.720%
# Epoch 91/250 	 Loss = 0.363 	 Train Acc = 87.056% 	 Sparsity = 47.949% 	 Test Loss = 0.505 	Test Acc = 83.520%
# Epoch 92/250 	 Loss = 0.359 	 Train Acc = 87.188% 	 Sparsity = 47.986% 	 Test Loss = 0.524 	Test Acc = 83.050%
# Epoch 93/250 	 Loss = 0.362 	 Train Acc = 87.136% 	 Sparsity = 48.024% 	 Test Loss = 0.498 	Test Acc = 83.850%
# Epoch 94/250 	 Loss = 0.358 	 Train Acc = 87.260% 	 Sparsity = 48.060% 	 Test Loss = 0.492 	Test Acc = 84.060%
# New test accuracy is 84.060%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 95/250 	 Loss = 0.357 	 Train Acc = 87.212% 	 Sparsity = 48.097% 	 Test Loss = 0.493 	Test Acc = 84.180%
# New test accuracy is 84.180%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 96/250 	 Loss = 0.362 	 Train Acc = 87.330% 	 Sparsity = 48.132% 	 Test Loss = 0.504 	Test Acc = 83.950%
# Epoch 97/250 	 Loss = 0.361 	 Train Acc = 87.144% 	 Sparsity = 48.167% 	 Test Loss = 0.512 	Test Acc = 83.270%
# Epoch 98/250 	 Loss = 0.358 	 Train Acc = 87.434% 	 Sparsity = 48.202% 	 Test Loss = 0.492 	Test Acc = 84.100%
# Epoch 99/250 	 Loss = 0.363 	 Train Acc = 87.178% 	 Sparsity = 48.235% 	 Test Loss = 0.526 	Test Acc = 83.060%
# Epoch 100/250 	 Loss = 0.354 	 Train Acc = 87.450% 	 Sparsity = 48.268% 	 Test Loss = 0.508 	Test Acc = 83.520%
# Epoch 101/250 	 Loss = 0.352 	 Train Acc = 87.438% 	 Sparsity = 48.301% 	 Test Loss = 0.498 	Test Acc = 83.650%
# Epoch 102/250 	 Loss = 0.356 	 Train Acc = 87.224% 	 Sparsity = 48.334% 	 Test Loss = 0.484 	Test Acc = 84.200%
# New test accuracy is 84.200%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 103/250 	 Loss = 0.351 	 Train Acc = 87.678% 	 Sparsity = 48.367% 	 Test Loss = 0.492 	Test Acc = 83.790%
# Epoch 104/250 	 Loss = 0.352 	 Train Acc = 87.412% 	 Sparsity = 48.397% 	 Test Loss = 0.489 	Test Acc = 83.990%
# Epoch 105/250 	 Loss = 0.354 	 Train Acc = 87.324% 	 Sparsity = 48.427% 	 Test Loss = 0.494 	Test Acc = 84.190%
# Epoch 106/250 	 Loss = 0.348 	 Train Acc = 87.530% 	 Sparsity = 48.456% 	 Test Loss = 0.495 	Test Acc = 83.920%
# Epoch 107/250 	 Loss = 0.354 	 Train Acc = 87.366% 	 Sparsity = 48.489% 	 Test Loss = 0.481 	Test Acc = 84.420%
# New test accuracy is 84.420%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 108/250 	 Loss = 0.357 	 Train Acc = 87.310% 	 Sparsity = 48.523% 	 Test Loss = 0.483 	Test Acc = 84.070%
# Epoch 109/250 	 Loss = 0.354 	 Train Acc = 87.328% 	 Sparsity = 48.554% 	 Test Loss = 0.539 	Test Acc = 82.600%
# Epoch 110/250 	 Loss = 0.351 	 Train Acc = 87.598% 	 Sparsity = 48.584% 	 Test Loss = 0.499 	Test Acc = 83.930%
# Epoch 111/250 	 Loss = 0.349 	 Train Acc = 87.744% 	 Sparsity = 48.613% 	 Test Loss = 0.501 	Test Acc = 84.200%
# Epoch 112/250 	 Loss = 0.351 	 Train Acc = 87.544% 	 Sparsity = 48.642% 	 Test Loss = 0.485 	Test Acc = 84.110%
# Epoch 113/250 	 Loss = 0.349 	 Train Acc = 87.654% 	 Sparsity = 48.668% 	 Test Loss = 0.483 	Test Acc = 84.380%
# Epoch 114/250 	 Loss = 0.350 	 Train Acc = 87.528% 	 Sparsity = 48.697% 	 Test Loss = 0.475 	Test Acc = 84.620%
# New test accuracy is 84.620%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 115/250 	 Loss = 0.346 	 Train Acc = 87.768% 	 Sparsity = 48.723% 	 Test Loss = 0.480 	Test Acc = 84.600%
# Epoch 116/250 	 Loss = 0.346 	 Train Acc = 87.612% 	 Sparsity = 48.748% 	 Test Loss = 0.502 	Test Acc = 84.020%
# Epoch 117/250 	 Loss = 0.351 	 Train Acc = 87.332% 	 Sparsity = 48.773% 	 Test Loss = 0.493 	Test Acc = 84.150%
# Epoch 118/250 	 Loss = 0.347 	 Train Acc = 87.500% 	 Sparsity = 48.799% 	 Test Loss = 0.481 	Test Acc = 84.330%
# Epoch 119/250 	 Loss = 0.350 	 Train Acc = 87.634% 	 Sparsity = 48.825% 	 Test Loss = 0.502 	Test Acc = 83.950%
# Epoch 120/250 	 Loss = 0.345 	 Train Acc = 87.664% 	 Sparsity = 48.851% 	 Test Loss = 0.501 	Test Acc = 83.750%
# Epoch 121/250 	 Loss = 0.342 	 Train Acc = 87.818% 	 Sparsity = 48.878% 	 Test Loss = 0.494 	Test Acc = 83.930%
# Epoch 122/250 	 Loss = 0.353 	 Train Acc = 87.366% 	 Sparsity = 48.907% 	 Test Loss = 0.484 	Test Acc = 84.300%
# Epoch 123/250 	 Loss = 0.344 	 Train Acc = 87.704% 	 Sparsity = 48.933% 	 Test Loss = 0.495 	Test Acc = 84.000%
# Epoch 124/250 	 Loss = 0.346 	 Train Acc = 87.562% 	 Sparsity = 48.958% 	 Test Loss = 0.501 	Test Acc = 83.760%
# Epoch 125/250 	 Loss = 0.342 	 Train Acc = 87.714% 	 Sparsity = 48.982% 	 Test Loss = 0.568 	Test Acc = 82.180%
# Epoch 126/250 	 Loss = 0.343 	 Train Acc = 87.662% 	 Sparsity = 49.006% 	 Test Loss = 0.557 	Test Acc = 82.620%
# Epoch 127/250 	 Loss = 0.344 	 Train Acc = 87.688% 	 Sparsity = 49.030% 	 Test Loss = 0.494 	Test Acc = 84.080%
# Epoch 128/250 	 Loss = 0.344 	 Train Acc = 87.696% 	 Sparsity = 49.052% 	 Test Loss = 0.506 	Test Acc = 83.740%
# Epoch 129/250 	 Loss = 0.346 	 Train Acc = 87.566% 	 Sparsity = 49.076% 	 Test Loss = 0.483 	Test Acc = 84.520%
# Epoch 130/250 	 Loss = 0.339 	 Train Acc = 87.882% 	 Sparsity = 49.099% 	 Test Loss = 0.498 	Test Acc = 83.950%
# Epoch 131/250 	 Loss = 0.338 	 Train Acc = 87.814% 	 Sparsity = 49.123% 	 Test Loss = 0.488 	Test Acc = 84.330%
# Epoch 132/250 	 Loss = 0.343 	 Train Acc = 87.744% 	 Sparsity = 49.146% 	 Test Loss = 0.495 	Test Acc = 84.010%
# Epoch 133/250 	 Loss = 0.339 	 Train Acc = 87.840% 	 Sparsity = 49.168% 	 Test Loss = 0.502 	Test Acc = 84.140%
# Epoch 134/250 	 Loss = 0.343 	 Train Acc = 87.782% 	 Sparsity = 49.191% 	 Test Loss = 0.501 	Test Acc = 83.920%
# Epoch 135/250 	 Loss = 0.343 	 Train Acc = 87.708% 	 Sparsity = 49.213% 	 Test Loss = 0.505 	Test Acc = 83.890%
# Epoch 136/250 	 Loss = 0.339 	 Train Acc = 87.790% 	 Sparsity = 49.234% 	 Test Loss = 0.502 	Test Acc = 83.800%
# Epoch 137/250 	 Loss = 0.341 	 Train Acc = 87.802% 	 Sparsity = 49.255% 	 Test Loss = 0.483 	Test Acc = 84.320%
# Epoch 138/250 	 Loss = 0.346 	 Train Acc = 87.600% 	 Sparsity = 49.274% 	 Test Loss = 0.483 	Test Acc = 84.650%
# New test accuracy is 84.650%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 139/250 	 Loss = 0.340 	 Train Acc = 87.904% 	 Sparsity = 49.296% 	 Test Loss = 0.515 	Test Acc = 83.700%
# Epoch 140/250 	 Loss = 0.341 	 Train Acc = 87.770% 	 Sparsity = 49.317% 	 Test Loss = 0.495 	Test Acc = 84.400%
# Epoch 141/250 	 Loss = 0.341 	 Train Acc = 87.748% 	 Sparsity = 49.336% 	 Test Loss = 0.497 	Test Acc = 84.160%
# Epoch 142/250 	 Loss = 0.339 	 Train Acc = 87.784% 	 Sparsity = 49.357% 	 Test Loss = 0.483 	Test Acc = 84.330%
# Epoch 143/250 	 Loss = 0.344 	 Train Acc = 87.778% 	 Sparsity = 49.376% 	 Test Loss = 0.481 	Test Acc = 84.650%
# Epoch 144/250 	 Loss = 0.340 	 Train Acc = 87.804% 	 Sparsity = 49.395% 	 Test Loss = 0.509 	Test Acc = 83.650%
# Epoch 145/250 	 Loss = 0.337 	 Train Acc = 87.868% 	 Sparsity = 49.412% 	 Test Loss = 0.497 	Test Acc = 84.210%
# Epoch 146/250 	 Loss = 0.333 	 Train Acc = 88.122% 	 Sparsity = 49.432% 	 Test Loss = 0.505 	Test Acc = 83.920%
# Epoch 147/250 	 Loss = 0.339 	 Train Acc = 87.668% 	 Sparsity = 49.451% 	 Test Loss = 0.488 	Test Acc = 84.550%
# Epoch 148/250 	 Loss = 0.336 	 Train Acc = 87.968% 	 Sparsity = 49.468% 	 Test Loss = 0.471 	Test Acc = 84.740%
# New test accuracy is 84.740%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 149/250 	 Loss = 0.338 	 Train Acc = 88.048% 	 Sparsity = 49.487% 	 Test Loss = 0.509 	Test Acc = 83.960%
# Epoch 150/250 	 Loss = 0.338 	 Train Acc = 87.908% 	 Sparsity = 49.505% 	 Test Loss = 0.491 	Test Acc = 84.560%
# Epoch 151/250 	 Loss = 0.335 	 Train Acc = 87.922% 	 Sparsity = 49.522% 	 Test Loss = 0.474 	Test Acc = 84.790%
# New test accuracy is 84.790%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 152/250 	 Loss = 0.338 	 Train Acc = 87.848% 	 Sparsity = 49.539% 	 Test Loss = 0.518 	Test Acc = 83.620%
# Epoch 153/250 	 Loss = 0.336 	 Train Acc = 87.962% 	 Sparsity = 49.557% 	 Test Loss = 0.485 	Test Acc = 84.410%
# Epoch 154/250 	 Loss = 0.332 	 Train Acc = 88.046% 	 Sparsity = 49.574% 	 Test Loss = 0.506 	Test Acc = 84.260%
# Epoch 155/250 	 Loss = 0.334 	 Train Acc = 88.038% 	 Sparsity = 49.591% 	 Test Loss = 0.497 	Test Acc = 84.260%
# Epoch 156/250 	 Loss = 0.332 	 Train Acc = 88.230% 	 Sparsity = 49.608% 	 Test Loss = 0.502 	Test Acc = 83.920%
# Epoch 157/250 	 Loss = 0.334 	 Train Acc = 88.064% 	 Sparsity = 49.623% 	 Test Loss = 0.498 	Test Acc = 84.440%
# Epoch 158/250 	 Loss = 0.336 	 Train Acc = 87.914% 	 Sparsity = 49.639% 	 Test Loss = 0.495 	Test Acc = 84.090%
# Epoch 159/250 	 Loss = 0.335 	 Train Acc = 88.068% 	 Sparsity = 49.656% 	 Test Loss = 0.513 	Test Acc = 83.800%
# Epoch 160/250 	 Loss = 0.331 	 Train Acc = 88.160% 	 Sparsity = 49.672% 	 Test Loss = 0.499 	Test Acc = 84.200%
# Epoch 161/250 	 Loss = 0.333 	 Train Acc = 87.964% 	 Sparsity = 49.688% 	 Test Loss = 0.491 	Test Acc = 84.550%
# Epoch 162/250 	 Loss = 0.335 	 Train Acc = 87.962% 	 Sparsity = 49.705% 	 Test Loss = 0.486 	Test Acc = 84.450%
# Epoch 163/250 	 Loss = 0.331 	 Train Acc = 88.220% 	 Sparsity = 49.722% 	 Test Loss = 0.487 	Test Acc = 84.520%
# Epoch 164/250 	 Loss = 0.333 	 Train Acc = 88.126% 	 Sparsity = 49.738% 	 Test Loss = 0.509 	Test Acc = 83.910%
# Epoch 165/250 	 Loss = 0.333 	 Train Acc = 88.070% 	 Sparsity = 49.754% 	 Test Loss = 0.491 	Test Acc = 84.600%
# Epoch 166/250 	 Loss = 0.334 	 Train Acc = 87.930% 	 Sparsity = 49.770% 	 Test Loss = 0.508 	Test Acc = 83.890%
# Epoch 167/250 	 Loss = 0.331 	 Train Acc = 88.128% 	 Sparsity = 49.784% 	 Test Loss = 0.507 	Test Acc = 84.000%
# Epoch 168/250 	 Loss = 0.333 	 Train Acc = 88.096% 	 Sparsity = 49.799% 	 Test Loss = 0.486 	Test Acc = 84.420%
# Epoch 169/250 	 Loss = 0.338 	 Train Acc = 87.906% 	 Sparsity = 49.813% 	 Test Loss = 0.496 	Test Acc = 84.370%
# Epoch 170/250 	 Loss = 0.336 	 Train Acc = 88.094% 	 Sparsity = 49.830% 	 Test Loss = 0.487 	Test Acc = 84.520%
# Epoch 171/250 	 Loss = 0.331 	 Train Acc = 88.026% 	 Sparsity = 49.846% 	 Test Loss = 0.497 	Test Acc = 84.430%
# Epoch 172/250 	 Loss = 0.329 	 Train Acc = 88.228% 	 Sparsity = 49.861% 	 Test Loss = 0.488 	Test Acc = 84.570%
# Epoch 173/250 	 Loss = 0.337 	 Train Acc = 87.812% 	 Sparsity = 49.876% 	 Test Loss = 0.488 	Test Acc = 84.480%
# Epoch 174/250 	 Loss = 0.334 	 Train Acc = 88.092% 	 Sparsity = 49.889% 	 Test Loss = 0.507 	Test Acc = 84.010%
# Epoch 175/250 	 Loss = 0.326 	 Train Acc = 88.414% 	 Sparsity = 49.903% 	 Test Loss = 0.480 	Test Acc = 84.750%
# Epoch 176/250 	 Loss = 0.333 	 Train Acc = 87.936% 	 Sparsity = 49.918% 	 Test Loss = 0.492 	Test Acc = 84.310%
# Epoch 177/250 	 Loss = 0.329 	 Train Acc = 88.232% 	 Sparsity = 49.933% 	 Test Loss = 0.493 	Test Acc = 84.570%
# Epoch 178/250 	 Loss = 0.330 	 Train Acc = 88.226% 	 Sparsity = 49.946% 	 Test Loss = 0.492 	Test Acc = 84.310%
# Epoch 179/250 	 Loss = 0.330 	 Train Acc = 88.014% 	 Sparsity = 49.961% 	 Test Loss = 0.481 	Test Acc = 84.490%
# Epoch 180/250 	 Loss = 0.329 	 Train Acc = 88.178% 	 Sparsity = 49.975% 	 Test Loss = 0.487 	Test Acc = 84.660%
# Epoch 181/250 	 Loss = 0.332 	 Train Acc = 88.146% 	 Sparsity = 49.989% 	 Test Loss = 0.500 	Test Acc = 84.370%
# Epoch 182/250 	 Loss = 0.332 	 Train Acc = 88.114% 	 Sparsity = 50.002% 	 Test Loss = 0.491 	Test Acc = 84.350%
# Epoch 183/250 	 Loss = 0.330 	 Train Acc = 88.256% 	 Sparsity = 50.016% 	 Test Loss = 0.488 	Test Acc = 84.690%
# Epoch 184/250 	 Loss = 0.334 	 Train Acc = 87.938% 	 Sparsity = 50.029% 	 Test Loss = 0.480 	Test Acc = 84.560%
# Epoch 185/250 	 Loss = 0.328 	 Train Acc = 88.340% 	 Sparsity = 50.041% 	 Test Loss = 0.495 	Test Acc = 84.140%
# Epoch 186/250 	 Loss = 0.327 	 Train Acc = 88.338% 	 Sparsity = 50.055% 	 Test Loss = 0.475 	Test Acc = 84.660%
# Epoch 187/250 	 Loss = 0.327 	 Train Acc = 88.286% 	 Sparsity = 50.067% 	 Test Loss = 0.482 	Test Acc = 84.620%
# Epoch 188/250 	 Loss = 0.331 	 Train Acc = 88.206% 	 Sparsity = 50.080% 	 Test Loss = 0.493 	Test Acc = 84.520%
# Epoch 189/250 	 Loss = 0.326 	 Train Acc = 88.298% 	 Sparsity = 50.093% 	 Test Loss = 0.477 	Test Acc = 84.640%
# Epoch 190/250 	 Loss = 0.320 	 Train Acc = 88.410% 	 Sparsity = 50.105% 	 Test Loss = 0.487 	Test Acc = 84.430%
# Epoch 191/250 	 Loss = 0.328 	 Train Acc = 88.252% 	 Sparsity = 50.119% 	 Test Loss = 0.486 	Test Acc = 84.400%
# Epoch 192/250 	 Loss = 0.329 	 Train Acc = 88.166% 	 Sparsity = 50.132% 	 Test Loss = 0.484 	Test Acc = 84.630%
# Epoch 193/250 	 Loss = 0.327 	 Train Acc = 88.316% 	 Sparsity = 50.144% 	 Test Loss = 0.497 	Test Acc = 84.300%
# Epoch 194/250 	 Loss = 0.330 	 Train Acc = 88.110% 	 Sparsity = 50.159% 	 Test Loss = 0.478 	Test Acc = 84.710%
# Epoch 195/250 	 Loss = 0.331 	 Train Acc = 88.288% 	 Sparsity = 50.172% 	 Test Loss = 0.515 	Test Acc = 83.620%
# Epoch 196/250 	 Loss = 0.328 	 Train Acc = 88.124% 	 Sparsity = 50.186% 	 Test Loss = 0.502 	Test Acc = 84.000%
# Epoch 197/250 	 Loss = 0.326 	 Train Acc = 88.196% 	 Sparsity = 50.198% 	 Test Loss = 0.491 	Test Acc = 84.180%
# Epoch 198/250 	 Loss = 0.327 	 Train Acc = 88.256% 	 Sparsity = 50.210% 	 Test Loss = 0.496 	Test Acc = 84.240%
# Epoch 199/250 	 Loss = 0.330 	 Train Acc = 88.192% 	 Sparsity = 50.224% 	 Test Loss = 0.486 	Test Acc = 84.390%
# Epoch 200/250 	 Loss = 0.326 	 Train Acc = 88.322% 	 Sparsity = 50.236% 	 Test Loss = 0.488 	Test Acc = 84.170%
# Epoch 201/250 	 Loss = 0.327 	 Train Acc = 88.400% 	 Sparsity = 50.247% 	 Test Loss = 0.486 	Test Acc = 84.400%
# Epoch 202/250 	 Loss = 0.333 	 Train Acc = 88.136% 	 Sparsity = 50.259% 	 Test Loss = 0.484 	Test Acc = 84.550%
# Epoch 203/250 	 Loss = 0.329 	 Train Acc = 88.324% 	 Sparsity = 50.271% 	 Test Loss = 0.486 	Test Acc = 84.480%
# Epoch 204/250 	 Loss = 0.327 	 Train Acc = 88.420% 	 Sparsity = 50.281% 	 Test Loss = 0.477 	Test Acc = 84.780%
# Epoch 205/250 	 Loss = 0.329 	 Train Acc = 88.240% 	 Sparsity = 50.291% 	 Test Loss = 0.492 	Test Acc = 84.380%
# Epoch 206/250 	 Loss = 0.322 	 Train Acc = 88.358% 	 Sparsity = 50.302% 	 Test Loss = 0.484 	Test Acc = 84.590%
# Epoch 207/250 	 Loss = 0.329 	 Train Acc = 88.126% 	 Sparsity = 50.314% 	 Test Loss = 0.489 	Test Acc = 84.150%
# Epoch 208/250 	 Loss = 0.329 	 Train Acc = 88.230% 	 Sparsity = 50.325% 	 Test Loss = 0.485 	Test Acc = 84.710%
# Epoch 209/250 	 Loss = 0.332 	 Train Acc = 88.148% 	 Sparsity = 50.335% 	 Test Loss = 0.480 	Test Acc = 84.620%
# Epoch 210/250 	 Loss = 0.326 	 Train Acc = 88.288% 	 Sparsity = 50.345% 	 Test Loss = 0.520 	Test Acc = 83.670%
# Epoch 211/250 	 Loss = 0.323 	 Train Acc = 88.414% 	 Sparsity = 50.355% 	 Test Loss = 0.484 	Test Acc = 84.570%
# Epoch 212/250 	 Loss = 0.329 	 Train Acc = 88.260% 	 Sparsity = 50.366% 	 Test Loss = 0.511 	Test Acc = 83.940%
# Epoch 213/250 	 Loss = 0.326 	 Train Acc = 88.306% 	 Sparsity = 50.376% 	 Test Loss = 0.502 	Test Acc = 84.300%
# Epoch 214/250 	 Loss = 0.323 	 Train Acc = 88.556% 	 Sparsity = 50.385% 	 Test Loss = 0.482 	Test Acc = 84.670%
# Epoch 215/250 	 Loss = 0.322 	 Train Acc = 88.618% 	 Sparsity = 50.396% 	 Test Loss = 0.502 	Test Acc = 84.320%
# Epoch 216/250 	 Loss = 0.326 	 Train Acc = 88.204% 	 Sparsity = 50.407% 	 Test Loss = 0.476 	Test Acc = 84.610%
# Epoch 217/250 	 Loss = 0.325 	 Train Acc = 88.380% 	 Sparsity = 50.415% 	 Test Loss = 0.485 	Test Acc = 84.820%
# New test accuracy is 84.820%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 218/250 	 Loss = 0.321 	 Train Acc = 88.512% 	 Sparsity = 50.425% 	 Test Loss = 0.486 	Test Acc = 84.620%
# Epoch 219/250 	 Loss = 0.328 	 Train Acc = 88.258% 	 Sparsity = 50.435% 	 Test Loss = 0.530 	Test Acc = 83.650%
# Epoch 220/250 	 Loss = 0.322 	 Train Acc = 88.284% 	 Sparsity = 50.444% 	 Test Loss = 0.490 	Test Acc = 84.770%
# Epoch 221/250 	 Loss = 0.322 	 Train Acc = 88.436% 	 Sparsity = 50.452% 	 Test Loss = 0.478 	Test Acc = 84.580%
# Epoch 222/250 	 Loss = 0.322 	 Train Acc = 88.466% 	 Sparsity = 50.462% 	 Test Loss = 0.509 	Test Acc = 83.970%
# Epoch 223/250 	 Loss = 0.327 	 Train Acc = 88.488% 	 Sparsity = 50.472% 	 Test Loss = 0.514 	Test Acc = 83.720%
# Epoch 224/250 	 Loss = 0.324 	 Train Acc = 88.452% 	 Sparsity = 50.481% 	 Test Loss = 0.489 	Test Acc = 84.520%
# Epoch 225/250 	 Loss = 0.325 	 Train Acc = 88.434% 	 Sparsity = 50.490% 	 Test Loss = 0.528 	Test Acc = 83.460%
# Epoch 226/250 	 Loss = 0.320 	 Train Acc = 88.430% 	 Sparsity = 50.499% 	 Test Loss = 0.503 	Test Acc = 84.130%
# Epoch 227/250 	 Loss = 0.324 	 Train Acc = 88.368% 	 Sparsity = 50.509% 	 Test Loss = 0.493 	Test Acc = 84.440%
# Epoch 228/250 	 Loss = 0.330 	 Train Acc = 88.146% 	 Sparsity = 50.518% 	 Test Loss = 0.509 	Test Acc = 83.730%
# Epoch 229/250 	 Loss = 0.328 	 Train Acc = 88.212% 	 Sparsity = 50.527% 	 Test Loss = 0.484 	Test Acc = 84.550%
# Epoch 230/250 	 Loss = 0.323 	 Train Acc = 88.322% 	 Sparsity = 50.536% 	 Test Loss = 0.493 	Test Acc = 84.210%
# Epoch 231/250 	 Loss = 0.324 	 Train Acc = 88.298% 	 Sparsity = 50.545% 	 Test Loss = 0.476 	Test Acc = 84.660%
# Epoch 232/250 	 Loss = 0.329 	 Train Acc = 88.178% 	 Sparsity = 50.553% 	 Test Loss = 0.476 	Test Acc = 84.820%
# Epoch 233/250 	 Loss = 0.320 	 Train Acc = 88.550% 	 Sparsity = 50.564% 	 Test Loss = 0.490 	Test Acc = 84.560%
# Epoch 234/250 	 Loss = 0.327 	 Train Acc = 88.202% 	 Sparsity = 50.572% 	 Test Loss = 0.479 	Test Acc = 84.520%
# Epoch 235/250 	 Loss = 0.322 	 Train Acc = 88.432% 	 Sparsity = 50.580% 	 Test Loss = 0.497 	Test Acc = 84.170%
# Epoch 236/250 	 Loss = 0.322 	 Train Acc = 88.508% 	 Sparsity = 50.588% 	 Test Loss = 0.494 	Test Acc = 84.290%
# Epoch 237/250 	 Loss = 0.319 	 Train Acc = 88.396% 	 Sparsity = 50.596% 	 Test Loss = 0.497 	Test Acc = 84.300%
# Epoch 238/250 	 Loss = 0.324 	 Train Acc = 88.252% 	 Sparsity = 50.604% 	 Test Loss = 0.497 	Test Acc = 84.290%
# Epoch 239/250 	 Loss = 0.326 	 Train Acc = 88.376% 	 Sparsity = 50.612% 	 Test Loss = 0.476 	Test Acc = 84.650%
# Epoch 240/250 	 Loss = 0.319 	 Train Acc = 88.544% 	 Sparsity = 50.621% 	 Test Loss = 0.485 	Test Acc = 84.550%
# Epoch 241/250 	 Loss = 0.328 	 Train Acc = 88.298% 	 Sparsity = 50.628% 	 Test Loss = 0.474 	Test Acc = 84.850%
# New test accuracy is 84.850%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 242/250 	 Loss = 0.321 	 Train Acc = 88.664% 	 Sparsity = 50.636% 	 Test Loss = 0.484 	Test Acc = 84.740%
# Epoch 243/250 	 Loss = 0.322 	 Train Acc = 88.420% 	 Sparsity = 50.644% 	 Test Loss = 0.471 	Test Acc = 84.950%
# New test accuracy is 84.950%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 244/250 	 Loss = 0.320 	 Train Acc = 88.642% 	 Sparsity = 50.653% 	 Test Loss = 0.482 	Test Acc = 84.860%
# Epoch 245/250 	 Loss = 0.323 	 Train Acc = 88.292% 	 Sparsity = 50.662% 	 Test Loss = 0.504 	Test Acc = 84.020%
# Epoch 246/250 	 Loss = 0.320 	 Train Acc = 88.526% 	 Sparsity = 50.670% 	 Test Loss = 0.491 	Test Acc = 84.630%
# Epoch 247/250 	 Loss = 0.319 	 Train Acc = 88.470% 	 Sparsity = 50.679% 	 Test Loss = 0.487 	Test Acc = 84.520%
# Epoch 248/250 	 Loss = 0.320 	 Train Acc = 88.516% 	 Sparsity = 50.688% 	 Test Loss = 0.496 	Test Acc = 84.380%
# Epoch 249/250 	 Loss = 0.325 	 Train Acc = 88.340% 	 Sparsity = 50.695% 	 Test Loss = 0.486 	Test Acc = 84.690%
# Epoch 250/250 	 Loss = 0.322 	 Train Acc = 88.310% 	 Sparsity = 50.703% 	 Test Loss = 0.473 	Test Acc = 84.800%

# %%
l = len(model.trainable_weights)
for i in range(l):
  a = tf.reshape(model.trainable_weights[i],[-1])
  b = a.numpy()
  #print(a)
  #plt.ylim(0,300)
  plt.title(str(i))
  plt.hist(b,200)
  plt.show()

# %%
import pandas as pd

data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_2.csv')

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
model = keras.models.load_model('test_2.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
for layer in model.layers:
    if layer.name == 'conv1':
        a = tf.reshape(layer.weights[0],[-1])
        b = a.numpy()
        plt.hist(b,200)
        plt.show()

        plt.hist(b,200)
        plt.ylim((0,30))
        plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
with tf.device('/device:CPU:0'):
    test_accuracy = tf.keras.metrics.Accuracy()
    logits = model(x_test, training=False)
    prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
    test_accuracy(prediction, y_test)
    print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 84.950%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.7.0
# 1

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255

#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout (Dropout)           (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_1 (Dropout)         (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_2 (Dropout)         (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_3 (Dropout)         (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 250
alpha = 0.25
n_bits = 3

learning_rate = 0.015
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_3.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0 and alpha > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0 and alpha > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_3.csv')
# Out:
# Created Tensor of velocity
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Epoch 1/250 	 Loss = 1.912 	 Train Acc = 38.068% 	 Sparsity = 32.623% 	 Test Loss = 1.518 	Test Acc = 47.300%
# New test accuracy is 47.300%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/250 	 Loss = 1.403 	 Train Acc = 49.932% 	 Sparsity = 63.828% 	 Test Loss = 1.268 	Test Acc = 54.450%
# New test accuracy is 54.450%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/250 	 Loss = 1.302 	 Train Acc = 53.328% 	 Sparsity = 64.224% 	 Test Loss = 1.110 	Test Acc = 60.630%
# New test accuracy is 60.630%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/250 	 Loss = 1.243 	 Train Acc = 55.420% 	 Sparsity = 64.383% 	 Test Loss = 1.384 	Test Acc = 54.040%
# Epoch 5/250 	 Loss = 1.207 	 Train Acc = 56.708% 	 Sparsity = 64.481% 	 Test Loss = 1.085 	Test Acc = 61.140%
# New test accuracy is 61.140%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/250 	 Loss = 1.184 	 Train Acc = 57.836% 	 Sparsity = 64.522% 	 Test Loss = 1.171 	Test Acc = 58.010%
# Epoch 7/250 	 Loss = 1.178 	 Train Acc = 58.270% 	 Sparsity = 64.530% 	 Test Loss = 1.037 	Test Acc = 63.710%
# New test accuracy is 63.710%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/250 	 Loss = 1.169 	 Train Acc = 58.648% 	 Sparsity = 64.535% 	 Test Loss = 1.037 	Test Acc = 63.550%
# Epoch 9/250 	 Loss = 1.168 	 Train Acc = 58.534% 	 Sparsity = 64.537% 	 Test Loss = 1.127 	Test Acc = 59.870%
# Epoch 10/250 	 Loss = 1.159 	 Train Acc = 58.948% 	 Sparsity = 64.540% 	 Test Loss = 1.002 	Test Acc = 64.440%
# New test accuracy is 64.440%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 11/250 	 Loss = 1.154 	 Train Acc = 59.180% 	 Sparsity = 64.542% 	 Test Loss = 1.072 	Test Acc = 62.080%
# Epoch 12/250 	 Loss = 1.159 	 Train Acc = 58.918% 	 Sparsity = 64.543% 	 Test Loss = 1.043 	Test Acc = 62.780%
# Epoch 13/250 	 Loss = 1.156 	 Train Acc = 59.066% 	 Sparsity = 64.543% 	 Test Loss = 1.022 	Test Acc = 63.290%
# Epoch 14/250 	 Loss = 1.152 	 Train Acc = 59.218% 	 Sparsity = 64.544% 	 Test Loss = 1.617 	Test Acc = 45.240%
# Epoch 15/250 	 Loss = 1.169 	 Train Acc = 58.656% 	 Sparsity = 64.545% 	 Test Loss = 1.003 	Test Acc = 64.570%
# New test accuracy is 64.570%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 16/250 	 Loss = 1.159 	 Train Acc = 59.096% 	 Sparsity = 64.545% 	 Test Loss = 1.047 	Test Acc = 62.200%
# Epoch 17/250 	 Loss = 1.160 	 Train Acc = 58.828% 	 Sparsity = 64.546% 	 Test Loss = 1.022 	Test Acc = 64.100%
# Epoch 18/250 	 Loss = 1.155 	 Train Acc = 58.976% 	 Sparsity = 64.546% 	 Test Loss = 0.996 	Test Acc = 64.940%
# New test accuracy is 64.940%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 19/250 	 Loss = 1.153 	 Train Acc = 59.042% 	 Sparsity = 64.546% 	 Test Loss = 1.129 	Test Acc = 59.510%
# Epoch 20/250 	 Loss = 1.152 	 Train Acc = 59.196% 	 Sparsity = 64.546% 	 Test Loss = 1.006 	Test Acc = 64.470%
# Epoch 21/250 	 Loss = 1.151 	 Train Acc = 59.278% 	 Sparsity = 64.546% 	 Test Loss = 0.991 	Test Acc = 65.000%
# New test accuracy is 65.000%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 22/250 	 Loss = 1.153 	 Train Acc = 59.240% 	 Sparsity = 64.546% 	 Test Loss = 1.021 	Test Acc = 63.510%
# Epoch 23/250 	 Loss = 1.145 	 Train Acc = 59.428% 	 Sparsity = 64.547% 	 Test Loss = 0.987 	Test Acc = 64.920%
# Epoch 24/250 	 Loss = 1.154 	 Train Acc = 58.858% 	 Sparsity = 64.547% 	 Test Loss = 0.986 	Test Acc = 65.050%
# New test accuracy is 65.050%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 25/250 	 Loss = 1.151 	 Train Acc = 59.174% 	 Sparsity = 64.547% 	 Test Loss = 0.991 	Test Acc = 64.760%
# Epoch 26/250 	 Loss = 1.150 	 Train Acc = 59.164% 	 Sparsity = 64.548% 	 Test Loss = 1.055 	Test Acc = 62.130%
# Epoch 27/250 	 Loss = 1.154 	 Train Acc = 59.238% 	 Sparsity = 64.548% 	 Test Loss = 1.054 	Test Acc = 62.410%
# Epoch 28/250 	 Loss = 1.153 	 Train Acc = 59.228% 	 Sparsity = 64.548% 	 Test Loss = 1.027 	Test Acc = 63.750%
# Epoch 29/250 	 Loss = 1.152 	 Train Acc = 59.150% 	 Sparsity = 64.548% 	 Test Loss = 1.000 	Test Acc = 64.500%
# Epoch 30/250 	 Loss = 1.151 	 Train Acc = 59.298% 	 Sparsity = 64.548% 	 Test Loss = 1.008 	Test Acc = 64.270%
# Epoch 31/250 	 Loss = 1.151 	 Train Acc = 59.412% 	 Sparsity = 64.548% 	 Test Loss = 1.006 	Test Acc = 64.210%
# Epoch 32/250 	 Loss = 1.157 	 Train Acc = 59.104% 	 Sparsity = 64.549% 	 Test Loss = 1.270 	Test Acc = 55.010%
# Epoch 33/250 	 Loss = 1.158 	 Train Acc = 59.366% 	 Sparsity = 64.549% 	 Test Loss = 1.149 	Test Acc = 58.610%
# Epoch 34/250 	 Loss = 1.158 	 Train Acc = 58.974% 	 Sparsity = 64.549% 	 Test Loss = 1.027 	Test Acc = 64.020%
# Epoch 35/250 	 Loss = 1.159 	 Train Acc = 59.070% 	 Sparsity = 64.549% 	 Test Loss = 1.070 	Test Acc = 62.560%
# Epoch 36/250 	 Loss = 1.157 	 Train Acc = 58.890% 	 Sparsity = 64.549% 	 Test Loss = 1.047 	Test Acc = 62.690%
# Epoch 37/250 	 Loss = 1.152 	 Train Acc = 59.548% 	 Sparsity = 64.549% 	 Test Loss = 1.245 	Test Acc = 56.310%
# Epoch 38/250 	 Loss = 1.164 	 Train Acc = 58.604% 	 Sparsity = 64.549% 	 Test Loss = 1.004 	Test Acc = 64.370%
# Epoch 39/250 	 Loss = 1.161 	 Train Acc = 58.964% 	 Sparsity = 64.549% 	 Test Loss = 1.000 	Test Acc = 64.320%
# Epoch 40/250 	 Loss = 1.151 	 Train Acc = 59.492% 	 Sparsity = 64.549% 	 Test Loss = 0.991 	Test Acc = 64.790%
# Epoch 41/250 	 Loss = 1.156 	 Train Acc = 59.230% 	 Sparsity = 64.549% 	 Test Loss = 0.994 	Test Acc = 64.460%
# Epoch 42/250 	 Loss = 1.155 	 Train Acc = 59.126% 	 Sparsity = 64.549% 	 Test Loss = 0.980 	Test Acc = 64.950%
# Epoch 43/250 	 Loss = 1.149 	 Train Acc = 59.216% 	 Sparsity = 64.549% 	 Test Loss = 1.187 	Test Acc = 57.000%
# Epoch 44/250 	 Loss = 1.159 	 Train Acc = 58.838% 	 Sparsity = 64.549% 	 Test Loss = 1.137 	Test Acc = 59.830%
# Epoch 45/250 	 Loss = 1.152 	 Train Acc = 59.152% 	 Sparsity = 64.549% 	 Test Loss = 1.066 	Test Acc = 61.950%
# Epoch 46/250 	 Loss = 1.152 	 Train Acc = 59.000% 	 Sparsity = 64.549% 	 Test Loss = 1.074 	Test Acc = 62.300%
# Epoch 47/250 	 Loss = 1.153 	 Train Acc = 59.180% 	 Sparsity = 64.549% 	 Test Loss = 1.015 	Test Acc = 63.920%
# Epoch 48/250 	 Loss = 1.155 	 Train Acc = 59.234% 	 Sparsity = 64.549% 	 Test Loss = 1.059 	Test Acc = 62.140%
# Epoch 49/250 	 Loss = 1.150 	 Train Acc = 59.162% 	 Sparsity = 64.549% 	 Test Loss = 1.005 	Test Acc = 64.460%
# Epoch 50/250 	 Loss = 1.154 	 Train Acc = 59.106% 	 Sparsity = 64.549% 	 Test Loss = 1.000 	Test Acc = 64.770%
# Epoch 51/250 	 Loss = 1.150 	 Train Acc = 59.256% 	 Sparsity = 64.549% 	 Test Loss = 0.980 	Test Acc = 65.220%
# New test accuracy is 65.220%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 52/250 	 Loss = 1.152 	 Train Acc = 59.262% 	 Sparsity = 64.549% 	 Test Loss = 0.982 	Test Acc = 64.920%
# Epoch 53/250 	 Loss = 1.153 	 Train Acc = 59.148% 	 Sparsity = 64.549% 	 Test Loss = 0.984 	Test Acc = 65.360%
# New test accuracy is 65.360%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 54/250 	 Loss = 1.153 	 Train Acc = 59.144% 	 Sparsity = 64.549% 	 Test Loss = 0.994 	Test Acc = 65.170%
# Epoch 55/250 	 Loss = 1.151 	 Train Acc = 59.300% 	 Sparsity = 64.549% 	 Test Loss = 0.992 	Test Acc = 64.870%
# Epoch 56/250 	 Loss = 1.151 	 Train Acc = 59.490% 	 Sparsity = 64.549% 	 Test Loss = 0.999 	Test Acc = 64.550%
# Epoch 57/250 	 Loss = 1.154 	 Train Acc = 58.768% 	 Sparsity = 64.549% 	 Test Loss = 1.000 	Test Acc = 64.480%
# Epoch 58/250 	 Loss = 1.151 	 Train Acc = 59.350% 	 Sparsity = 64.549% 	 Test Loss = 0.989 	Test Acc = 64.640%
# Epoch 59/250 	 Loss = 1.151 	 Train Acc = 59.308% 	 Sparsity = 64.549% 	 Test Loss = 1.011 	Test Acc = 64.030%
# Epoch 60/250 	 Loss = 1.155 	 Train Acc = 59.148% 	 Sparsity = 64.549% 	 Test Loss = 0.998 	Test Acc = 64.260%
# Epoch 61/250 	 Loss = 1.149 	 Train Acc = 59.104% 	 Sparsity = 64.549% 	 Test Loss = 1.026 	Test Acc = 63.360%
# Epoch 62/250 	 Loss = 1.150 	 Train Acc = 59.488% 	 Sparsity = 64.550% 	 Test Loss = 0.994 	Test Acc = 65.120%
# Epoch 63/250 	 Loss = 1.146 	 Train Acc = 59.440% 	 Sparsity = 64.550% 	 Test Loss = 0.984 	Test Acc = 64.950%
# Epoch 64/250 	 Loss = 1.153 	 Train Acc = 59.108% 	 Sparsity = 64.550% 	 Test Loss = 0.985 	Test Acc = 64.640%
# Epoch 65/250 	 Loss = 1.149 	 Train Acc = 59.306% 	 Sparsity = 64.550% 	 Test Loss = 0.983 	Test Acc = 65.150%
# Epoch 66/250 	 Loss = 1.148 	 Train Acc = 59.438% 	 Sparsity = 64.550% 	 Test Loss = 1.001 	Test Acc = 64.790%
# Epoch 67/250 	 Loss = 1.149 	 Train Acc = 59.304% 	 Sparsity = 64.550% 	 Test Loss = 0.994 	Test Acc = 64.420%
# Epoch 68/250 	 Loss = 1.155 	 Train Acc = 59.232% 	 Sparsity = 64.550% 	 Test Loss = 1.001 	Test Acc = 64.520%
# Epoch 69/250 	 Loss = 1.152 	 Train Acc = 59.232% 	 Sparsity = 64.550% 	 Test Loss = 1.026 	Test Acc = 63.750%
# Epoch 70/250 	 Loss = 1.157 	 Train Acc = 59.160% 	 Sparsity = 64.550% 	 Test Loss = 1.014 	Test Acc = 63.880%
# Epoch 71/250 	 Loss = 1.147 	 Train Acc = 59.230% 	 Sparsity = 64.550% 	 Test Loss = 0.996 	Test Acc = 64.590%
# Epoch 72/250 	 Loss = 1.154 	 Train Acc = 59.096% 	 Sparsity = 64.550% 	 Test Loss = 0.995 	Test Acc = 64.750%
# Epoch 73/250 	 Loss = 1.150 	 Train Acc = 59.314% 	 Sparsity = 64.550% 	 Test Loss = 0.977 	Test Acc = 65.330%
# Epoch 74/250 	 Loss = 1.148 	 Train Acc = 59.380% 	 Sparsity = 64.550% 	 Test Loss = 0.991 	Test Acc = 64.960%
# Epoch 75/250 	 Loss = 1.154 	 Train Acc = 59.214% 	 Sparsity = 64.550% 	 Test Loss = 0.991 	Test Acc = 64.960%
# Epoch 76/250 	 Loss = 1.150 	 Train Acc = 59.274% 	 Sparsity = 64.550% 	 Test Loss = 1.021 	Test Acc = 63.880%
# Epoch 77/250 	 Loss = 1.151 	 Train Acc = 59.158% 	 Sparsity = 64.550% 	 Test Loss = 0.980 	Test Acc = 65.100%
# Epoch 78/250 	 Loss = 1.154 	 Train Acc = 59.162% 	 Sparsity = 64.550% 	 Test Loss = 0.978 	Test Acc = 65.210%
# Epoch 79/250 	 Loss = 1.150 	 Train Acc = 59.218% 	 Sparsity = 64.550% 	 Test Loss = 1.055 	Test Acc = 62.110%
# Epoch 80/250 	 Loss = 1.154 	 Train Acc = 59.178% 	 Sparsity = 64.550% 	 Test Loss = 0.974 	Test Acc = 65.430%
# New test accuracy is 65.430%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-761d6876b6e6> in <module>()
#      38                         f_weights = tf.reshape(layer_weights,[-1])
#      39                         #get standard deviation of each layer
# ---> 40                         lim = alpha*tf.math.reduce_std(f_weights)
#      41                         bk.append(lim)
#      42                         #create a mask
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in reduce_std(input_tensor, axis, keepdims, name)
#    2734   with ops.name_scope(name):
#    2735     input_tensor = ops.convert_to_tensor(input_tensor)
# -> 2736     variance = reduce_variance(input_tensor, axis=axis, keepdims=keepdims)
#    2737     return gen_math_ops.sqrt(variance)
#    2738
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in reduce_variance(input_tensor, axis, keepdims, name)
#    2675       raise TypeError(f"Input must be either real or complex. "
#    2676                       f"Received integer type {means.dtype}.")
# -> 2677     diff = input_tensor - means
#    2678     if diff.dtype.is_complex:
#    2679       # For complex values we need to take the absolute value before squaring.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#    1381         #   r_binary_op_wrapper use different force_same_dtype values.
#    1382         x, y = maybe_promote_tensors(x, y, force_same_dtype=False)
# -> 1383         return func(x, y, name=name)
#    1384       except (TypeError, ValueError) as e:
#    1385         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in subtract(x, y, name)
#     551 @dispatch.add_dispatch_support
#     552 def subtract(x, y, name=None):
# --> 553   return gen_math_ops.sub(x, y, name)
#     554
#     555
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_math_ops.py in sub(x, y, name)
#   11125     try:
#   11126       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# > 11127         _ctx, "Sub", name, x, y)
#   11128       return _result
#   11129     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
l = len(model.trainable_weights)
for i in range(l):
  a = tf.reshape(model.trainable_weights[i],[-1])
  b = a.numpy()
  #print(a)
  #plt.ylim(0,300)
  plt.title(str(i))
  plt.hist(b,200)
  plt.show()

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
import pandas as pd

data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_4.csv')

# %%
model = keras.models.load_model('test_3.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
test_accuracy = tf.keras.metrics.Accuracy()
logits = model(x_test, training=False)
prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
test_accuracy(prediction, y_test)
print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 65.430%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

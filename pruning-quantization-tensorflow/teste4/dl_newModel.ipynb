# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.7.0
# 1

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255

#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        #keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        #keras.layers.Dropout(0.2),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        #keras.layers.Dropout(0.2),
     
        keras.layers.Flatten(name = "flatten"),
        keras.layers.Dropout(0.2, name="dp1"),
        keras.layers.Dense(1024, name="dense1", activation='relu'),
        keras.layers.BatchNormalization(name="bn7"),
        keras.layers.Dropout(0.2),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(128, name="dense3", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.4),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dp1 (Dropout)               (64, 2048)                0
#
#  dense1 (Dense)              (64, 1024)                2098176
#
#  bn7 (BatchNormalization)    (64, 1024)                4096
#
#  dropout (Dropout)           (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
import pandas as pd

# %%
epochs = 100
alpha = 0.25
n_bits = 3

learning_rate = 0.01
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_4.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            
            #Cópia do modelo
            if n_bits > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
            
            #Quantização
            if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights))) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)

            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)

            if n_bits > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))

            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)
        

        #Quantização
        if n_bits > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights))) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        #bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_4.csv')
# Out:
# Created Tensor of velocity
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Epoch 1/100 	 Loss = 1.506 	 Train Acc = 48.566% 	 Sparsity = 25.345% 	 Test Loss = 1.119 	Test Acc = 60.020%
# New test accuracy is 60.020%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/100 	 Loss = 0.967 	 Train Acc = 65.612% 	 Sparsity = 36.769% 	 Test Loss = 1.295 	Test Acc = 56.520%
# Epoch 3/100 	 Loss = 0.839 	 Train Acc = 70.428% 	 Sparsity = 37.785% 	 Test Loss = 0.851 	Test Acc = 70.220%
# New test accuracy is 70.220%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/100 	 Loss = 0.769 	 Train Acc = 72.948% 	 Sparsity = 38.099% 	 Test Loss = 0.880 	Test Acc = 69.080%
# Epoch 5/100 	 Loss = 0.745 	 Train Acc = 73.640% 	 Sparsity = 38.186% 	 Test Loss = 0.793 	Test Acc = 72.550%
# New test accuracy is 72.550%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 6/100 	 Loss = 0.734 	 Train Acc = 74.030% 	 Sparsity = 38.216% 	 Test Loss = 0.771 	Test Acc = 72.970%
# New test accuracy is 72.970%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/100 	 Loss = 0.722 	 Train Acc = 74.454% 	 Sparsity = 38.230% 	 Test Loss = 0.775 	Test Acc = 73.170%
# New test accuracy is 73.170%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 8/100 	 Loss = 0.721 	 Train Acc = 74.362% 	 Sparsity = 38.237% 	 Test Loss = 0.771 	Test Acc = 72.950%
# Epoch 9/100 	 Loss = 0.724 	 Train Acc = 74.520% 	 Sparsity = 38.240% 	 Test Loss = 0.761 	Test Acc = 73.380%
# New test accuracy is 73.380%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 10/100 	 Loss = 0.720 	 Train Acc = 74.432% 	 Sparsity = 38.242% 	 Test Loss = 0.761 	Test Acc = 73.400%
# New test accuracy is 73.400%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 11/100 	 Loss = 0.721 	 Train Acc = 74.646% 	 Sparsity = 38.243% 	 Test Loss = 0.757 	Test Acc = 73.610%
# New test accuracy is 73.610%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 12/100 	 Loss = 0.720 	 Train Acc = 74.498% 	 Sparsity = 38.244% 	 Test Loss = 0.755 	Test Acc = 74.040%
# New test accuracy is 74.040%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 13/100 	 Loss = 0.724 	 Train Acc = 74.440% 	 Sparsity = 38.244% 	 Test Loss = 0.746 	Test Acc = 74.070%
# New test accuracy is 74.070%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 14/100 	 Loss = 0.719 	 Train Acc = 74.454% 	 Sparsity = 38.245% 	 Test Loss = 0.747 	Test Acc = 74.050%
# Epoch 15/100 	 Loss = 0.726 	 Train Acc = 74.282% 	 Sparsity = 38.246% 	 Test Loss = 0.749 	Test Acc = 73.900%
# Epoch 16/100 	 Loss = 0.723 	 Train Acc = 74.384% 	 Sparsity = 38.247% 	 Test Loss = 0.743 	Test Acc = 73.970%
# Epoch 17/100 	 Loss = 0.721 	 Train Acc = 74.542% 	 Sparsity = 38.247% 	 Test Loss = 0.748 	Test Acc = 73.660%
# Epoch 18/100 	 Loss = 0.720 	 Train Acc = 74.656% 	 Sparsity = 38.248% 	 Test Loss = 0.748 	Test Acc = 74.040%
# Epoch 19/100 	 Loss = 0.722 	 Train Acc = 74.592% 	 Sparsity = 38.248% 	 Test Loss = 0.742 	Test Acc = 74.110%
# New test accuracy is 74.110%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 20/100 	 Loss = 0.716 	 Train Acc = 74.626% 	 Sparsity = 38.248% 	 Test Loss = 0.743 	Test Acc = 74.000%
# Epoch 21/100 	 Loss = 0.722 	 Train Acc = 74.414% 	 Sparsity = 38.249% 	 Test Loss = 0.748 	Test Acc = 73.810%
# Epoch 22/100 	 Loss = 0.723 	 Train Acc = 74.432% 	 Sparsity = 38.249% 	 Test Loss = 0.748 	Test Acc = 73.830%
# Epoch 23/100 	 Loss = 0.724 	 Train Acc = 74.276% 	 Sparsity = 38.250% 	 Test Loss = 0.749 	Test Acc = 73.910%
# Epoch 24/100 	 Loss = 0.726 	 Train Acc = 74.172% 	 Sparsity = 38.250% 	 Test Loss = 0.747 	Test Acc = 73.660%
# Epoch 25/100 	 Loss = 0.726 	 Train Acc = 74.512% 	 Sparsity = 38.250% 	 Test Loss = 0.742 	Test Acc = 74.210%
# New test accuracy is 74.210%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 26/100 	 Loss = 0.723 	 Train Acc = 74.334% 	 Sparsity = 38.251% 	 Test Loss = 0.748 	Test Acc = 73.870%
# Epoch 27/100 	 Loss = 0.728 	 Train Acc = 74.264% 	 Sparsity = 38.251% 	 Test Loss = 0.747 	Test Acc = 74.070%
# Epoch 28/100 	 Loss = 0.730 	 Train Acc = 74.148% 	 Sparsity = 38.251% 	 Test Loss = 0.744 	Test Acc = 73.910%
# Epoch 29/100 	 Loss = 0.728 	 Train Acc = 74.120% 	 Sparsity = 38.251% 	 Test Loss = 0.748 	Test Acc = 73.870%
# Epoch 30/100 	 Loss = 0.725 	 Train Acc = 74.068% 	 Sparsity = 38.251% 	 Test Loss = 0.748 	Test Acc = 73.470%
# Epoch 31/100 	 Loss = 0.725 	 Train Acc = 74.356% 	 Sparsity = 38.252% 	 Test Loss = 0.746 	Test Acc = 74.130%
# Epoch 32/100 	 Loss = 0.729 	 Train Acc = 74.192% 	 Sparsity = 38.252% 	 Test Loss = 0.750 	Test Acc = 73.760%
# Epoch 33/100 	 Loss = 0.732 	 Train Acc = 74.240% 	 Sparsity = 38.252% 	 Test Loss = 0.754 	Test Acc = 73.700%
# Epoch 34/100 	 Loss = 0.733 	 Train Acc = 74.324% 	 Sparsity = 38.253% 	 Test Loss = 0.749 	Test Acc = 73.810%
# Epoch 35/100 	 Loss = 0.731 	 Train Acc = 74.178% 	 Sparsity = 38.253% 	 Test Loss = 0.750 	Test Acc = 73.640%
# Epoch 36/100 	 Loss = 0.732 	 Train Acc = 74.126% 	 Sparsity = 38.253% 	 Test Loss = 0.752 	Test Acc = 73.800%
# Epoch 37/100 	 Loss = 0.736 	 Train Acc = 73.976% 	 Sparsity = 38.253% 	 Test Loss = 0.750 	Test Acc = 73.610%
# Epoch 38/100 	 Loss = 0.734 	 Train Acc = 74.102% 	 Sparsity = 38.253% 	 Test Loss = 0.750 	Test Acc = 73.790%
# Epoch 39/100 	 Loss = 0.735 	 Train Acc = 73.968% 	 Sparsity = 38.254% 	 Test Loss = 0.754 	Test Acc = 73.750%
# Epoch 40/100 	 Loss = 0.732 	 Train Acc = 74.212% 	 Sparsity = 38.254% 	 Test Loss = 0.750 	Test Acc = 74.060%
# Epoch 41/100 	 Loss = 0.730 	 Train Acc = 74.048% 	 Sparsity = 38.254% 	 Test Loss = 0.750 	Test Acc = 73.680%
# Epoch 42/100 	 Loss = 0.731 	 Train Acc = 74.090% 	 Sparsity = 38.254% 	 Test Loss = 0.750 	Test Acc = 73.710%
# Epoch 43/100 	 Loss = 0.733 	 Train Acc = 74.172% 	 Sparsity = 38.254% 	 Test Loss = 0.749 	Test Acc = 73.690%
# Epoch 44/100 	 Loss = 0.729 	 Train Acc = 74.372% 	 Sparsity = 38.254% 	 Test Loss = 0.748 	Test Acc = 73.950%
# Epoch 45/100 	 Loss = 0.732 	 Train Acc = 74.220% 	 Sparsity = 38.254% 	 Test Loss = 0.758 	Test Acc = 73.460%
# Epoch 46/100 	 Loss = 0.733 	 Train Acc = 74.168% 	 Sparsity = 38.254% 	 Test Loss = 0.752 	Test Acc = 73.730%
# Epoch 47/100 	 Loss = 0.733 	 Train Acc = 74.286% 	 Sparsity = 38.254% 	 Test Loss = 0.751 	Test Acc = 73.540%
# Epoch 48/100 	 Loss = 0.735 	 Train Acc = 74.176% 	 Sparsity = 38.254% 	 Test Loss = 0.756 	Test Acc = 73.410%
# Epoch 49/100 	 Loss = 0.735 	 Train Acc = 74.094% 	 Sparsity = 38.254% 	 Test Loss = 0.746 	Test Acc = 73.750%
# Epoch 50/100 	 Loss = 0.733 	 Train Acc = 74.188% 	 Sparsity = 38.254% 	 Test Loss = 0.751 	Test Acc = 73.570%
# Epoch 51/100 	 Loss = 0.731 	 Train Acc = 74.304% 	 Sparsity = 38.254% 	 Test Loss = 0.749 	Test Acc = 73.920%
# Epoch 52/100 	 Loss = 0.729 	 Train Acc = 74.316% 	 Sparsity = 38.254% 	 Test Loss = 0.750 	Test Acc = 73.800%
# Epoch 53/100 	 Loss = 0.733 	 Train Acc = 74.150% 	 Sparsity = 38.254% 	 Test Loss = 0.750 	Test Acc = 73.870%
# Epoch 54/100 	 Loss = 0.731 	 Train Acc = 74.208% 	 Sparsity = 38.254% 	 Test Loss = 0.748 	Test Acc = 73.700%
# Epoch 55/100 	 Loss = 0.731 	 Train Acc = 74.256% 	 Sparsity = 38.254% 	 Test Loss = 0.747 	Test Acc = 73.710%
# Epoch 56/100 	 Loss = 0.737 	 Train Acc = 74.036% 	 Sparsity = 38.254% 	 Test Loss = 0.750 	Test Acc = 73.720%
# Epoch 57/100 	 Loss = 0.733 	 Train Acc = 74.148% 	 Sparsity = 38.254% 	 Test Loss = 0.751 	Test Acc = 73.500%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-cee34bd9c781> in <module>()
#      56             #Cópia do modelo
#      57             if n_bits > 0:
# ---> 58                 model_copy = keras.models.clone_model(model)
#      59                 model_copy.set_weights(model.get_weights())
#      60
#
# /usr/local/lib/python3.7/dist-packages/keras/models.py in clone_model(model, input_tensors, clone_function)
#     452     if isinstance(model, Sequential):
#     453       return _clone_sequential_model(
# --> 454           model, input_tensors=input_tensors, layer_fn=clone_function)
#     455     else:
#     456       return _clone_functional_model(
#
# /usr/local/lib/python3.7/dist-packages/keras/models.py in _clone_sequential_model(model, input_tensors, layer_fn)
#     334
#     335   if input_tensors is None:
# --> 336     cloned_model = Sequential(layers=layers, name=model.name)
#     337   elif len(generic_utils.to_list(input_tensors)) != 1:
#     338     raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py in __init__(self, layers, name)
#     134         layers = [layers]
#     135       for layer in layers:
# --> 136         self.add(layer)
#     137
#     138   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py in add(self, layer)
#     218       # If the model is being built continuously on top of an input layer:
#     219       # refresh its output.
# --> 220       output_tensor = layer(self.outputs[0])
#     221       if len(tf.nest.flatten(output_tensor)) != 1:
#     222         raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1018     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#    1019       return self._functional_construction_call(inputs, args, kwargs,
# -> 1020                                                 input_list)
#    1021
#    1022     # Maintains info about the `Layer.call` stack.
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1159       # Check input assumptions set after layer building, e.g. input shape.
#    1160       outputs = self._keras_tensor_symbolic_call(
# -> 1161           inputs, input_masks, args, kwargs)
#    1162
#    1163       if outputs is None:
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     883       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     884     else:
# --> 885       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     886
#     887   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     926           # overridden).
#     927           # TODO(kaftan): do we maybe_build here, or have we already done it?
# --> 928           self._maybe_build(inputs)
#     929           inputs = self._maybe_cast_inputs(inputs)
#     930           outputs = call_fn(inputs, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2722         # operations.
#    2723         with tf_utils.maybe_init_scope(self):
# -> 2724           self.build(input_shapes)  # pylint:disable=not-callable
#    2725       # We must set also ensure that the layer is marked as built, and the build
#    2726       # shape is stored since user defined build functions may not be calling
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/normalization/batch_normalization.py in build(self, input_shape)
#     442           name='moving_mean',
#     443           shape=param_shape,
# --> 444           dtype=self._param_dtype,
#     445           initializer=self.moving_mean_initializer,
#     446           synchronization=tf.VariableSynchronization.ON_READ,
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/normalization/batch_normalization.py in _param_dtype(self)
#     276   def _param_dtype(self):
#     277     # Raise parameters of fp16 batch norm to fp32
# --> 278     if self.dtype == tf.float16 or self.dtype == tf.bfloat16:
#     279       return tf.float32
#     280     else:
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in dtype(self)
#    1232       return self.call
#    1233
# -> 1234   @property
#    1235   def dtype(self):
#    1236     """The dtype of the layer weights.
#
# KeyboardInterrupt:

# %%
data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_4.csv')

# %%
bk
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=0.35180673>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.2396565>,
#  -1,
#  -1,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.111343>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.027994027>,
#  -1,
#  -1,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.09837446>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.03144899>,
#  -1,
#  -1,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.07186437>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.02575152>,
#  -1,
#  -1,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.06926642>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.021599825>,
#  -1,
#  -1,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.053536177>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.020942055>,
#  -1,
#  -1,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.052750133>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.0034731736>,
#  -1,
#  -1,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.027873868>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.119544216>]

# %%
model = keras.models.load_model('test_4.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
for (i,layer) in enumerate(model.trainable_weights):
        if 'bn' in layer.name or 'bias' in layer.name:
            pass
        else:
            print(layer.name)
            a = tf.reshape(layer,[-1])
            b = a.numpy()
            
            plt.axvline(x=-bk[i],color='r')
            plt.hist(b,100)
            
            plt.axvline(x=bk[i],color='r')
            #plt.text(bk[i], 600, 'bk')
            #plt.text(-bk[i], 600, '-bk')
            plt.ylim([0,10000])
            plt.show()
# Out:
# conv1/kernel:0
# conv2/kernel:0
# conv3/kernel:0
# conv4/kernel:0
# conv5/kernel:0
# conv6/kernel:0
# dense1/kernel:0
# dense4/kernel:0

# %%
for layer in model.layers:
    if layer.name == 'conv1':
        a = tf.reshape(layer.weights[0],[-1])
        b = a.numpy()
        plt.hist(b,200)
        plt.show()

        plt.hist(b,200)
        plt.ylim((0,100))
        plt.show()

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
test_accuracy = tf.keras.metrics.Accuracy()
logits = model(x_test, training=False)
prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
test_accuracy(prediction, y_test)
print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 74.210%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

print(tf.__version__)
print(len(tf.config.experimental.list_physical_devices('GPU')))
device_name = tf.test.gpu_device_name()
print(device_name)
# Out:
# 2.7.0
# 1
# /device:GPU:0

# %%
#IMPORTAÇÃO E NORRMALIZAÇÃO
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()
#x_train = x_train.reshape(-1, 28, 28, 1)
#x_test = x_test.reshape(-1, 28, 28, 1)

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255
#CRIAR DATASET
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# %%
x_train.shape
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
acc_metric = keras.metrics.SparseCategoricalAccuracy()
test_accuracy = tf.keras.metrics.Accuracy()
test_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
train_accuracy = tf.keras.metrics.Accuracy()

# %%
model = keras.Sequential(
    [
        keras.layers.InputLayer(input_shape=(32, 32,3),batch_size=64),
     
        keras.layers.Conv2D(32, (3, 3), name="conv1", activation='relu',padding='same'),
        keras.layers.BatchNormalization(name="bn1"),  
        keras.layers.Conv2D(32, (3, 3),name="conv2", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn2"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp1"),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(64, (3, 3),name="conv3", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn3"),
        keras.layers.Conv2D(64, (3, 3),name="conv4", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn4"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp2"),
        keras.layers.Dropout(0.3),
        keras.layers.Conv2D(128, (3, 3),name="conv5", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn5"),
        keras.layers.Conv2D(128, (3, 3),name="conv6", activation='relu', padding='same'),
        keras.layers.BatchNormalization(name="bn6"),
        keras.layers.MaxPooling2D(pool_size=(2, 2),name="mp3"),
        keras.layers.Dropout(0.4),
     
        keras.layers.Flatten(name = "flatten"),
        #keras.layers.Dropout(0.2, name="dp1"),
        #keras.layers.Dense(512, name="dense1", activation='relu'),
        #keras.layers.BatchNormalization(name="bn7"),
        #keras.layers.Dropout(0.4),
        #keras.layers.Dense(256, name="dense2", activation='relu'),
        #keras.layers.BatchNormalization(name="bn8"),
        #keras.layers.Dropout(0.2),
        keras.layers.Dense(1024, name="dense3", activation='relu'),
        keras.layers.BatchNormalization(name="bn9"),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, name="dense4", activation='softmax')
    ],
    name="modelo-0.0",
)

for layer in model.trainable_variables:
    #print(layer.name)
    if 'bias' in layer.name:
        new_bias = tf.cast(tf.where(tf.abs(layer) >= 0, 0.1, 0.1), tf.float32)
        layer.assign(new_bias)

model.summary()
# Out:
# Model: "modelo-0.0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (64, 32, 32, 32)          896
#
#  bn1 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  conv2 (Conv2D)              (64, 32, 32, 32)          9248
#
#  bn2 (BatchNormalization)    (64, 32, 32, 32)          128
#
#  mp1 (MaxPooling2D)          (64, 16, 16, 32)          0
#
#  dropout_56 (Dropout)        (64, 16, 16, 32)          0
#
#  conv3 (Conv2D)              (64, 16, 16, 64)          18496
#
#  bn3 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  conv4 (Conv2D)              (64, 16, 16, 64)          36928
#
#  bn4 (BatchNormalization)    (64, 16, 16, 64)          256
#
#  mp2 (MaxPooling2D)          (64, 8, 8, 64)            0
#
#  dropout_57 (Dropout)        (64, 8, 8, 64)            0
#
#  conv5 (Conv2D)              (64, 8, 8, 128)           73856
#
#  bn5 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  conv6 (Conv2D)              (64, 8, 8, 128)           147584
#
#  bn6 (BatchNormalization)    (64, 8, 8, 128)           512
#
#  mp3 (MaxPooling2D)          (64, 4, 4, 128)           0
#
#  dropout_58 (Dropout)        (64, 4, 4, 128)           0
#
#  flatten (Flatten)           (64, 2048)                0
#
#  dense3 (Dense)              (64, 1024)                2098176
#
#  bn9 (BatchNormalization)    (64, 1024)                4096
#
#  dropout_59 (Dropout)        (64, 1024)                0
#
#  dense4 (Dense)              (64, 10)                  10250
#
# =================================================================
# Total params: 2,401,322
# Trainable params: 2,398,378
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
epochs = 250
alpha = 0.5
n_bits = 16

learning_rate = 0.015
momentum = 0.9

np.set_printoptions(threshold=np.inf)

model_sparsity = np.array([])
model_train_loss = np.array([])
model_train_acc = np.array([])
model_test_loss = np.array([])
model_test_acc = np.array([])
sparsity = 0

last_test_acc = 0
model_name = "test_5.h5"


with tf.device('/device:GPU:0'):
    #TODO: Quantizition of gammas and betas of batch_normalization layer
    for epoch in range(epochs):
        # Iterate over the batches of the dataset.
        loss_batch = np.array([])
        loss_test_batch = np.array([])
        for step, (x_batch_train, y_batch_train) in enumerate(train_ds):
            n_zeros = 0
            size = 0
            #pruning
            if alpha > 0:
                bk = []
                for layer_weights in model.trainable_variables:
                    if 'bn' in layer_weights.name:
                        bk.append(-1)
                    else:
                        #flatten weights
                        f_weights = tf.reshape(layer_weights,[-1])
                        #get standard deviation of each layer
                        lim = alpha*tf.math.reduce_std(f_weights)
                        bk.append(lim)
                        #create a mask
                        mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                        #assign pruned weights to the layer
                        layer_weights.assign(tf.math.multiply(layer_weights,mask))
                        #check sparsity
                        flat_array = np.array((tf.reshape(mask,[-1])))
                        n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                        size += flat_array.shape[0]
                        sparsity = n_zeros*100/size
            else:
                bk = [0] * len(model.trainable_weights)

            #Cópia do modelo
            if n_bits > 0 and alpha > 0:
                model_copy = keras.models.clone_model(model)
                model_copy.set_weights(model.get_weights())
        
            #Quantização
            if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)

            with tf.GradientTape() as tape:
                pred = model(x_batch_train, training=True)
                loss = loss_fn(y_batch_train, pred)
          
            grads = tape.gradient(loss, model.trainable_weights)
            if step==0 and epoch==0:
                print("Created Tensor of velocity")
                v = np.zeros_like(grads)
            if n_bits > 0 and alpha > 0:
                for i, (layer_weights, copied_weights) in enumerate(zip(model.trainable_variables, model_copy.trainable_variables)):
                    #TODO: Add momentum and velocity
                    grads[i] = grads[i] * learning_rate
                    #Get value of velocity
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    # WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(copied_weights, v[i]))
            else:
                for i, layer_weights in enumerate(model.trainable_variables):
                    
                    grads[i] = grads[i] * learning_rate
                    v[i] = tf.math.subtract(momentum*v[i], grads[i])
                    #WEIGHT UPDATE
                    layer_weights.assign(tf.math.add(layer_weights, v[i]))
            predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            train_accuracy.update_state(y_batch_train,predictions)

            #predictions = tf.argmax(pred, axis=1, output_type=tf.int32)
            #acc = train_accuracy(y_batch_train, predictions)

        #keep track of loss by batch
            loss_batch = np.append(loss_batch, loss)
        acc = train_accuracy.result()

        #reset states
        train_accuracy.reset_states()
        #mean of loss by epoch
        model_train_loss = np.append(model_train_loss, np.mean(loss_batch))
        #train accuracy by epoch
        model_train_acc = np.append(model_train_acc, acc*100)
        #sparsity by epoch
        model_sparsity = np.append(model_sparsity, sparsity)

        if alpha > 0:
            bk = []
            for layer_weights in model.trainable_variables:
                if 'bn' in layer_weights.name:
                    bk.append(-1)
                else:
                    #flatten weights
                    f_weights = tf.reshape(layer_weights,[-1])
                    #get standard deviation of each layer
                    lim = alpha*tf.math.reduce_std(f_weights)
                    bk.append(lim)
                    #create a mask
                    mask = tf.cast(tf.where(tf.abs(layer_weights)>lim,1,0), tf.float32)
                    #assign pruned weights to the layer
                    layer_weights.assign(tf.math.multiply(layer_weights,mask))
                    #check sparsity
                    flat_array = np.array((tf.reshape(mask,[-1])))
                    n_zeros += np.count_nonzero(np.array(flat_array) == 0)
                    size += flat_array.shape[0]
                    sparsity = n_zeros*100/size
        else:
            bk = [0] * len(model.trainable_weights)

        #Quantização
        if n_bits > 0 and alpha > 0:
                for i, layer_weights in enumerate(model.trainable_variables):
                    if 'bn' in layer_weights.name:
                        pass
                    else:
                        qk_line = (tf.reduce_max(tf.math.abs(layer_weights)) - bk[i]) / (2 ** (n_bits - 1) - 1)
                        ck = tf.math.round(layer_weights / qk_line) * qk_line
                        layer_weights.assign(ck)
      
        bk.clear()
        
        #Test
        acc_val = np.array([])
        for step, (x_batch_test, y_batch_test) in enumerate(test_ds):
            test_pred = model(x_batch_test, training=False)
            test_loss = loss_fn(y_batch_test,test_pred)
            test_prediction = tf.argmax(test_pred, axis=1, output_type=tf.int32)
            #test_acc = test_accuracy(y_batch_test, test_prediction)
                
            #acc_val = np.append(acc_val,float(test_acc))

            loss_test_batch = np.append(loss_test_batch,test_loss)
            test_accuracy.update_state(y_batch_test,test_prediction)

        test_acc = test_accuracy.result()
        test_accuracy.reset_states()

        model_test_acc = np.append(model_test_acc, test_acc*100)
        model_test_loss = np.append(model_test_loss,np.mean(loss_test_batch))
        
        print("Epoch {}/{} \t Loss = {:.3f} \t Train Acc = {:.3f}% \t Sparsity = {:.3f}% \t Test Loss = {:.3f} \tTest Acc = {:.3f}%".format(epoch+1,epochs,float(np.mean(loss_batch)),float(acc*100),sparsity, float(np.mean(loss_test_batch)),float(test_acc*100)))

        if last_test_acc < test_acc:
            print('New test accuracy is {:.3f}%, Model saved'.format(test_acc*100))
            last_test_acc = test_acc
            model.save(model_name)



data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_5.csv')
# Out:
# Created Tensor of velocity
# Epoch 1/250 	 Loss = 1.691 	 Train Acc = 56.235% 	 Sparsity = 44.273% 	 Test Loss = 1.255 	Test Acc = 54.790%
# New test accuracy is 54.790%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2/250 	 Loss = 1.279 	 Train Acc = 53.698% 	 Sparsity = 46.222% 	 Test Loss = 1.082 	Test Acc = 61.280%
# New test accuracy is 61.280%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 3/250 	 Loss = 1.112 	 Train Acc = 60.326% 	 Sparsity = 47.589% 	 Test Loss = 0.936 	Test Acc = 66.500%
# New test accuracy is 66.500%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 4/250 	 Loss = 1.001 	 Train Acc = 64.784% 	 Sparsity = 48.609% 	 Test Loss = 0.873 	Test Acc = 69.550%
# New test accuracy is 69.550%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 5/250 	 Loss = 0.924 	 Train Acc = 67.606% 	 Sparsity = 49.435% 	 Test Loss = 1.000 	Test Acc = 65.150%
# Epoch 6/250 	 Loss = 0.866 	 Train Acc = 69.598% 	 Sparsity = 50.107% 	 Test Loss = 0.758 	Test Acc = 73.160%
# New test accuracy is 73.160%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 7/250 	 Loss = 0.832 	 Train Acc = 71.078% 	 Sparsity = 50.678% 	 Test Loss = 0.777 	Test Acc = 72.340%
# Epoch 8/250 	 Loss = 0.796 	 Train Acc = 72.346% 	 Sparsity = 51.167% 	 Test Loss = 0.687 	Test Acc = 76.240%
# New test accuracy is 76.240%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 9/250 	 Loss = 0.764 	 Train Acc = 73.362% 	 Sparsity = 51.606% 	 Test Loss = 0.683 	Test Acc = 76.220%
# Epoch 10/250 	 Loss = 0.745 	 Train Acc = 74.150% 	 Sparsity = 51.986% 	 Test Loss = 0.694 	Test Acc = 75.940%
# Epoch 11/250 	 Loss = 0.717 	 Train Acc = 75.080% 	 Sparsity = 52.328% 	 Test Loss = 0.682 	Test Acc = 76.060%
# Epoch 12/250 	 Loss = 0.707 	 Train Acc = 75.380% 	 Sparsity = 52.637% 	 Test Loss = 0.641 	Test Acc = 77.560%
# New test accuracy is 77.560%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 13/250 	 Loss = 0.688 	 Train Acc = 76.080% 	 Sparsity = 52.912% 	 Test Loss = 0.621 	Test Acc = 78.390%
# New test accuracy is 78.390%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 14/250 	 Loss = 0.678 	 Train Acc = 76.624% 	 Sparsity = 53.168% 	 Test Loss = 0.636 	Test Acc = 77.760%
# Epoch 15/250 	 Loss = 0.669 	 Train Acc = 76.814% 	 Sparsity = 53.401% 	 Test Loss = 0.668 	Test Acc = 76.950%
# Epoch 16/250 	 Loss = 0.661 	 Train Acc = 77.142% 	 Sparsity = 53.615% 	 Test Loss = 0.634 	Test Acc = 78.220%
# Epoch 17/250 	 Loss = 0.654 	 Train Acc = 77.410% 	 Sparsity = 53.809% 	 Test Loss = 0.625 	Test Acc = 78.090%
# Epoch 18/250 	 Loss = 0.641 	 Train Acc = 77.738% 	 Sparsity = 53.977% 	 Test Loss = 0.602 	Test Acc = 79.230%
# New test accuracy is 79.230%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 19/250 	 Loss = 0.635 	 Train Acc = 78.008% 	 Sparsity = 54.148% 	 Test Loss = 0.587 	Test Acc = 79.880%
# New test accuracy is 79.880%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 20/250 	 Loss = 0.630 	 Train Acc = 78.222% 	 Sparsity = 54.302% 	 Test Loss = 0.588 	Test Acc = 79.610%
# Epoch 21/250 	 Loss = 0.625 	 Train Acc = 78.458% 	 Sparsity = 54.435% 	 Test Loss = 0.656 	Test Acc = 77.270%
# Epoch 22/250 	 Loss = 0.619 	 Train Acc = 78.602% 	 Sparsity = 54.577% 	 Test Loss = 0.667 	Test Acc = 77.580%
# Epoch 23/250 	 Loss = 0.612 	 Train Acc = 78.768% 	 Sparsity = 54.702% 	 Test Loss = 0.581 	Test Acc = 79.900%
# New test accuracy is 79.900%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 24/250 	 Loss = 0.610 	 Train Acc = 78.796% 	 Sparsity = 54.825% 	 Test Loss = 0.583 	Test Acc = 79.950%
# New test accuracy is 79.950%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 25/250 	 Loss = 0.602 	 Train Acc = 79.182% 	 Sparsity = 54.930% 	 Test Loss = 0.603 	Test Acc = 79.210%
# Epoch 26/250 	 Loss = 0.600 	 Train Acc = 79.224% 	 Sparsity = 55.037% 	 Test Loss = 0.627 	Test Acc = 78.310%
# Epoch 27/250 	 Loss = 0.597 	 Train Acc = 79.196% 	 Sparsity = 55.134% 	 Test Loss = 0.600 	Test Acc = 79.620%
# Epoch 28/250 	 Loss = 0.595 	 Train Acc = 79.346% 	 Sparsity = 55.229% 	 Test Loss = 0.581 	Test Acc = 79.750%
# Epoch 29/250 	 Loss = 0.592 	 Train Acc = 79.532% 	 Sparsity = 55.327% 	 Test Loss = 0.593 	Test Acc = 79.830%
# Epoch 30/250 	 Loss = 0.586 	 Train Acc = 79.748% 	 Sparsity = 55.425% 	 Test Loss = 0.581 	Test Acc = 80.080%
# New test accuracy is 80.080%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 31/250 	 Loss = 0.587 	 Train Acc = 79.704% 	 Sparsity = 55.499% 	 Test Loss = 0.588 	Test Acc = 79.610%
# Epoch 32/250 	 Loss = 0.583 	 Train Acc = 79.754% 	 Sparsity = 55.566% 	 Test Loss = 0.565 	Test Acc = 80.400%
# New test accuracy is 80.400%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 33/250 	 Loss = 0.583 	 Train Acc = 79.816% 	 Sparsity = 55.644% 	 Test Loss = 0.596 	Test Acc = 79.230%
# Epoch 34/250 	 Loss = 0.578 	 Train Acc = 80.016% 	 Sparsity = 55.719% 	 Test Loss = 0.583 	Test Acc = 79.830%
# Epoch 35/250 	 Loss = 0.583 	 Train Acc = 79.780% 	 Sparsity = 55.780% 	 Test Loss = 0.575 	Test Acc = 80.020%
# Epoch 36/250 	 Loss = 0.572 	 Train Acc = 80.252% 	 Sparsity = 55.846% 	 Test Loss = 0.568 	Test Acc = 80.600%
# New test accuracy is 80.600%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 37/250 	 Loss = 0.577 	 Train Acc = 80.078% 	 Sparsity = 55.908% 	 Test Loss = 0.559 	Test Acc = 80.840%
# New test accuracy is 80.840%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 38/250 	 Loss = 0.574 	 Train Acc = 80.156% 	 Sparsity = 55.972% 	 Test Loss = 0.562 	Test Acc = 80.720%
# Epoch 39/250 	 Loss = 0.570 	 Train Acc = 80.268% 	 Sparsity = 56.039% 	 Test Loss = 0.557 	Test Acc = 80.890%
# New test accuracy is 80.890%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 40/250 	 Loss = 0.566 	 Train Acc = 80.552% 	 Sparsity = 56.105% 	 Test Loss = 0.615 	Test Acc = 79.140%
# Epoch 41/250 	 Loss = 0.567 	 Train Acc = 80.250% 	 Sparsity = 56.150% 	 Test Loss = 0.543 	Test Acc = 81.630%
# New test accuracy is 81.630%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 42/250 	 Loss = 0.561 	 Train Acc = 80.568% 	 Sparsity = 56.196% 	 Test Loss = 0.577 	Test Acc = 80.260%
# Epoch 43/250 	 Loss = 0.561 	 Train Acc = 80.546% 	 Sparsity = 56.265% 	 Test Loss = 0.576 	Test Acc = 80.270%
# Epoch 44/250 	 Loss = 0.555 	 Train Acc = 80.686% 	 Sparsity = 56.305% 	 Test Loss = 0.565 	Test Acc = 80.790%
# Epoch 45/250 	 Loss = 0.564 	 Train Acc = 80.424% 	 Sparsity = 56.374% 	 Test Loss = 0.555 	Test Acc = 80.970%
# Epoch 46/250 	 Loss = 0.559 	 Train Acc = 80.724% 	 Sparsity = 56.423% 	 Test Loss = 0.562 	Test Acc = 80.330%
# Epoch 47/250 	 Loss = 0.558 	 Train Acc = 80.576% 	 Sparsity = 56.465% 	 Test Loss = 0.534 	Test Acc = 81.700%
# New test accuracy is 81.700%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 48/250 	 Loss = 0.552 	 Train Acc = 80.780% 	 Sparsity = 56.500% 	 Test Loss = 0.548 	Test Acc = 81.010%
# Epoch 49/250 	 Loss = 0.553 	 Train Acc = 80.780% 	 Sparsity = 56.552% 	 Test Loss = 0.570 	Test Acc = 80.590%
# Epoch 50/250 	 Loss = 0.556 	 Train Acc = 80.596% 	 Sparsity = 56.588% 	 Test Loss = 0.569 	Test Acc = 80.640%
# Epoch 51/250 	 Loss = 0.552 	 Train Acc = 80.992% 	 Sparsity = 56.625% 	 Test Loss = 0.551 	Test Acc = 81.210%
# Epoch 52/250 	 Loss = 0.553 	 Train Acc = 80.874% 	 Sparsity = 56.655% 	 Test Loss = 0.549 	Test Acc = 81.190%
# Epoch 53/250 	 Loss = 0.548 	 Train Acc = 81.026% 	 Sparsity = 56.701% 	 Test Loss = 0.556 	Test Acc = 81.010%
# Epoch 54/250 	 Loss = 0.552 	 Train Acc = 80.982% 	 Sparsity = 56.743% 	 Test Loss = 0.560 	Test Acc = 81.100%
# Epoch 55/250 	 Loss = 0.547 	 Train Acc = 80.854% 	 Sparsity = 56.777% 	 Test Loss = 0.557 	Test Acc = 81.010%
# Epoch 56/250 	 Loss = 0.549 	 Train Acc = 80.900% 	 Sparsity = 56.815% 	 Test Loss = 0.567 	Test Acc = 80.830%
# Epoch 57/250 	 Loss = 0.548 	 Train Acc = 80.874% 	 Sparsity = 56.875% 	 Test Loss = 0.569 	Test Acc = 80.870%
# Epoch 58/250 	 Loss = 0.543 	 Train Acc = 81.138% 	 Sparsity = 56.908% 	 Test Loss = 0.582 	Test Acc = 79.880%
# Epoch 59/250 	 Loss = 0.540 	 Train Acc = 81.400% 	 Sparsity = 56.935% 	 Test Loss = 0.560 	Test Acc = 81.210%
# Epoch 60/250 	 Loss = 0.545 	 Train Acc = 81.028% 	 Sparsity = 56.965% 	 Test Loss = 0.560 	Test Acc = 81.090%
# Epoch 61/250 	 Loss = 0.545 	 Train Acc = 80.934% 	 Sparsity = 57.010% 	 Test Loss = 0.546 	Test Acc = 81.240%
# Epoch 62/250 	 Loss = 0.544 	 Train Acc = 81.124% 	 Sparsity = 57.033% 	 Test Loss = 0.556 	Test Acc = 81.150%
# Epoch 63/250 	 Loss = 0.544 	 Train Acc = 81.126% 	 Sparsity = 57.059% 	 Test Loss = 0.544 	Test Acc = 81.500%
# Epoch 64/250 	 Loss = 0.544 	 Train Acc = 81.250% 	 Sparsity = 57.083% 	 Test Loss = 0.558 	Test Acc = 81.070%
# Epoch 65/250 	 Loss = 0.545 	 Train Acc = 80.938% 	 Sparsity = 57.135% 	 Test Loss = 0.534 	Test Acc = 81.770%
# New test accuracy is 81.770%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 66/250 	 Loss = 0.538 	 Train Acc = 81.416% 	 Sparsity = 57.156% 	 Test Loss = 0.556 	Test Acc = 80.930%
# Epoch 67/250 	 Loss = 0.539 	 Train Acc = 81.308% 	 Sparsity = 57.181% 	 Test Loss = 0.539 	Test Acc = 81.680%
# Epoch 68/250 	 Loss = 0.538 	 Train Acc = 81.234% 	 Sparsity = 57.201% 	 Test Loss = 0.547 	Test Acc = 81.390%
# Epoch 69/250 	 Loss = 0.540 	 Train Acc = 81.282% 	 Sparsity = 57.218% 	 Test Loss = 0.548 	Test Acc = 81.290%
# Epoch 70/250 	 Loss = 0.540 	 Train Acc = 81.236% 	 Sparsity = 57.254% 	 Test Loss = 0.534 	Test Acc = 81.680%
# Epoch 71/250 	 Loss = 0.544 	 Train Acc = 81.054% 	 Sparsity = 57.269% 	 Test Loss = 0.534 	Test Acc = 81.900%
# New test accuracy is 81.900%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 72/250 	 Loss = 0.537 	 Train Acc = 81.304% 	 Sparsity = 57.299% 	 Test Loss = 0.543 	Test Acc = 81.630%
# Epoch 73/250 	 Loss = 0.532 	 Train Acc = 81.368% 	 Sparsity = 57.327% 	 Test Loss = 0.567 	Test Acc = 80.810%
# Epoch 74/250 	 Loss = 0.536 	 Train Acc = 81.370% 	 Sparsity = 57.362% 	 Test Loss = 0.530 	Test Acc = 81.940%
# New test accuracy is 81.940%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 75/250 	 Loss = 0.533 	 Train Acc = 81.362% 	 Sparsity = 57.396% 	 Test Loss = 0.552 	Test Acc = 81.140%
# Epoch 76/250 	 Loss = 0.537 	 Train Acc = 81.234% 	 Sparsity = 57.430% 	 Test Loss = 0.529 	Test Acc = 81.720%
# Epoch 77/250 	 Loss = 0.535 	 Train Acc = 81.320% 	 Sparsity = 57.450% 	 Test Loss = 0.542 	Test Acc = 82.050%
# New test accuracy is 82.050%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 78/250 	 Loss = 0.527 	 Train Acc = 81.672% 	 Sparsity = 57.473% 	 Test Loss = 0.544 	Test Acc = 81.650%
# Epoch 79/250 	 Loss = 0.530 	 Train Acc = 81.496% 	 Sparsity = 57.490% 	 Test Loss = 0.531 	Test Acc = 81.810%
# Epoch 80/250 	 Loss = 0.530 	 Train Acc = 81.456% 	 Sparsity = 57.533% 	 Test Loss = 0.525 	Test Acc = 82.170%
# New test accuracy is 82.170%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 81/250 	 Loss = 0.532 	 Train Acc = 81.548% 	 Sparsity = 57.561% 	 Test Loss = 0.569 	Test Acc = 80.640%
# Epoch 82/250 	 Loss = 0.533 	 Train Acc = 81.404% 	 Sparsity = 57.576% 	 Test Loss = 0.536 	Test Acc = 81.650%
# Epoch 83/250 	 Loss = 0.530 	 Train Acc = 81.400% 	 Sparsity = 57.590% 	 Test Loss = 0.577 	Test Acc = 80.430%
# Epoch 84/250 	 Loss = 0.531 	 Train Acc = 81.546% 	 Sparsity = 57.626% 	 Test Loss = 0.548 	Test Acc = 81.500%
# Epoch 85/250 	 Loss = 0.532 	 Train Acc = 81.500% 	 Sparsity = 57.639% 	 Test Loss = 0.552 	Test Acc = 81.310%
# Epoch 86/250 	 Loss = 0.530 	 Train Acc = 81.410% 	 Sparsity = 57.667% 	 Test Loss = 0.535 	Test Acc = 81.850%
# Epoch 87/250 	 Loss = 0.532 	 Train Acc = 81.440% 	 Sparsity = 57.680% 	 Test Loss = 0.556 	Test Acc = 80.770%
# Epoch 88/250 	 Loss = 0.533 	 Train Acc = 81.454% 	 Sparsity = 57.697% 	 Test Loss = 0.547 	Test Acc = 81.460%
# Epoch 89/250 	 Loss = 0.529 	 Train Acc = 81.678% 	 Sparsity = 57.713% 	 Test Loss = 0.549 	Test Acc = 81.510%
# Epoch 90/250 	 Loss = 0.528 	 Train Acc = 81.618% 	 Sparsity = 57.767% 	 Test Loss = 0.518 	Test Acc = 82.300%
# New test accuracy is 82.300%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 91/250 	 Loss = 0.531 	 Train Acc = 81.546% 	 Sparsity = 57.779% 	 Test Loss = 0.533 	Test Acc = 82.010%
# Epoch 92/250 	 Loss = 0.535 	 Train Acc = 81.360% 	 Sparsity = 57.790% 	 Test Loss = 0.536 	Test Acc = 81.650%
# Epoch 93/250 	 Loss = 0.526 	 Train Acc = 81.510% 	 Sparsity = 57.803% 	 Test Loss = 0.533 	Test Acc = 82.230%
# Epoch 94/250 	 Loss = 0.531 	 Train Acc = 81.612% 	 Sparsity = 57.814% 	 Test Loss = 0.538 	Test Acc = 81.620%
# Epoch 95/250 	 Loss = 0.527 	 Train Acc = 81.642% 	 Sparsity = 57.828% 	 Test Loss = 0.547 	Test Acc = 81.570%
# Epoch 96/250 	 Loss = 0.525 	 Train Acc = 81.702% 	 Sparsity = 57.845% 	 Test Loss = 0.526 	Test Acc = 82.070%
# Epoch 97/250 	 Loss = 0.527 	 Train Acc = 81.780% 	 Sparsity = 57.854% 	 Test Loss = 0.532 	Test Acc = 82.050%
# Epoch 98/250 	 Loss = 0.530 	 Train Acc = 81.654% 	 Sparsity = 57.871% 	 Test Loss = 0.532 	Test Acc = 81.740%
# Epoch 99/250 	 Loss = 0.529 	 Train Acc = 81.674% 	 Sparsity = 57.884% 	 Test Loss = 0.571 	Test Acc = 80.710%
# Epoch 100/250 	 Loss = 0.524 	 Train Acc = 81.690% 	 Sparsity = 57.894% 	 Test Loss = 0.564 	Test Acc = 81.020%
# Epoch 101/250 	 Loss = 0.524 	 Train Acc = 81.782% 	 Sparsity = 57.907% 	 Test Loss = 0.540 	Test Acc = 81.880%
# Epoch 102/250 	 Loss = 0.527 	 Train Acc = 81.884% 	 Sparsity = 57.916% 	 Test Loss = 0.544 	Test Acc = 81.520%
# Epoch 103/250 	 Loss = 0.527 	 Train Acc = 81.752% 	 Sparsity = 57.959% 	 Test Loss = 0.556 	Test Acc = 80.950%
# Epoch 104/250 	 Loss = 0.519 	 Train Acc = 81.794% 	 Sparsity = 57.970% 	 Test Loss = 0.540 	Test Acc = 81.840%
# Epoch 105/250 	 Loss = 0.526 	 Train Acc = 81.678% 	 Sparsity = 57.986% 	 Test Loss = 0.546 	Test Acc = 81.510%
# Epoch 106/250 	 Loss = 0.519 	 Train Acc = 81.926% 	 Sparsity = 57.994% 	 Test Loss = 0.538 	Test Acc = 81.740%
# Epoch 107/250 	 Loss = 0.521 	 Train Acc = 82.076% 	 Sparsity = 58.003% 	 Test Loss = 0.532 	Test Acc = 82.040%
# Epoch 108/250 	 Loss = 0.525 	 Train Acc = 81.572% 	 Sparsity = 58.012% 	 Test Loss = 0.527 	Test Acc = 82.140%
# Epoch 109/250 	 Loss = 0.530 	 Train Acc = 81.666% 	 Sparsity = 58.040% 	 Test Loss = 0.518 	Test Acc = 82.410%
# New test accuracy is 82.410%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 110/250 	 Loss = 0.520 	 Train Acc = 81.818% 	 Sparsity = 58.072% 	 Test Loss = 0.528 	Test Acc = 82.250%
# Epoch 111/250 	 Loss = 0.518 	 Train Acc = 81.902% 	 Sparsity = 58.090% 	 Test Loss = 0.532 	Test Acc = 81.930%
# Epoch 112/250 	 Loss = 0.523 	 Train Acc = 81.758% 	 Sparsity = 58.130% 	 Test Loss = 0.544 	Test Acc = 81.510%
# Epoch 113/250 	 Loss = 0.521 	 Train Acc = 81.752% 	 Sparsity = 58.152% 	 Test Loss = 0.520 	Test Acc = 82.790%
# New test accuracy is 82.790%, Model saved
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 114/250 	 Loss = 0.523 	 Train Acc = 81.594% 	 Sparsity = 58.186% 	 Test Loss = 0.539 	Test Acc = 82.020%
# Epoch 115/250 	 Loss = 0.521 	 Train Acc = 81.878% 	 Sparsity = 58.193% 	 Test Loss = 0.537 	Test Acc = 82.170%
# Epoch 116/250 	 Loss = 0.520 	 Train Acc = 81.682% 	 Sparsity = 58.221% 	 Test Loss = 0.535 	Test Acc = 82.010%
# Epoch 117/250 	 Loss = 0.521 	 Train Acc = 81.850% 	 Sparsity = 58.264% 	 Test Loss = 0.544 	Test Acc = 81.990%
# Epoch 118/250 	 Loss = 0.523 	 Train Acc = 81.962% 	 Sparsity = 58.270% 	 Test Loss = 0.547 	Test Acc = 81.610%
# Epoch 119/250 	 Loss = 0.525 	 Train Acc = 81.722% 	 Sparsity = 58.292% 	 Test Loss = 0.524 	Test Acc = 82.240%
# Epoch 120/250 	 Loss = 0.521 	 Train Acc = 81.886% 	 Sparsity = 58.298% 	 Test Loss = 0.532 	Test Acc = 82.190%
# Epoch 121/250 	 Loss = 0.522 	 Train Acc = 81.780% 	 Sparsity = 58.317% 	 Test Loss = 0.543 	Test Acc = 82.190%
# Epoch 122/250 	 Loss = 0.520 	 Train Acc = 81.874% 	 Sparsity = 58.322% 	 Test Loss = 0.523 	Test Acc = 82.470%
# Epoch 123/250 	 Loss = 0.523 	 Train Acc = 81.774% 	 Sparsity = 58.328% 	 Test Loss = 0.534 	Test Acc = 82.120%
# Epoch 124/250 	 Loss = 0.517 	 Train Acc = 82.022% 	 Sparsity = 58.346% 	 Test Loss = 0.522 	Test Acc = 82.670%
# Epoch 125/250 	 Loss = 0.521 	 Train Acc = 81.886% 	 Sparsity = 58.355% 	 Test Loss = 0.553 	Test Acc = 81.380%
# Epoch 126/250 	 Loss = 0.523 	 Train Acc = 81.660% 	 Sparsity = 58.361% 	 Test Loss = 0.516 	Test Acc = 82.510%
# Epoch 127/250 	 Loss = 0.524 	 Train Acc = 81.816% 	 Sparsity = 58.383% 	 Test Loss = 0.534 	Test Acc = 81.920%
# Epoch 128/250 	 Loss = 0.521 	 Train Acc = 81.746% 	 Sparsity = 58.402% 	 Test Loss = 0.536 	Test Acc = 82.030%
# Epoch 129/250 	 Loss = 0.521 	 Train Acc = 81.922% 	 Sparsity = 58.409% 	 Test Loss = 0.541 	Test Acc = 81.470%
# Epoch 130/250 	 Loss = 0.519 	 Train Acc = 82.044% 	 Sparsity = 58.415% 	 Test Loss = 0.518 	Test Acc = 82.280%
# Epoch 131/250 	 Loss = 0.518 	 Train Acc = 81.958% 	 Sparsity = 58.460% 	 Test Loss = 0.534 	Test Acc = 82.120%
# Epoch 132/250 	 Loss = 0.525 	 Train Acc = 81.560% 	 Sparsity = 58.467% 	 Test Loss = 0.538 	Test Acc = 81.930%
# Epoch 133/250 	 Loss = 0.517 	 Train Acc = 81.962% 	 Sparsity = 58.474% 	 Test Loss = 0.548 	Test Acc = 81.260%
# Epoch 134/250 	 Loss = 0.516 	 Train Acc = 82.030% 	 Sparsity = 58.481% 	 Test Loss = 0.531 	Test Acc = 81.970%
# Epoch 135/250 	 Loss = 0.520 	 Train Acc = 82.024% 	 Sparsity = 58.486% 	 Test Loss = 0.529 	Test Acc = 82.290%
# Epoch 136/250 	 Loss = 0.517 	 Train Acc = 81.942% 	 Sparsity = 58.492% 	 Test Loss = 0.523 	Test Acc = 82.080%
# Epoch 137/250 	 Loss = 0.519 	 Train Acc = 82.022% 	 Sparsity = 58.498% 	 Test Loss = 0.520 	Test Acc = 82.320%
# Epoch 138/250 	 Loss = 0.515 	 Train Acc = 82.076% 	 Sparsity = 58.514% 	 Test Loss = 0.549 	Test Acc = 81.110%
# Epoch 139/250 	 Loss = 0.519 	 Train Acc = 81.954% 	 Sparsity = 58.540% 	 Test Loss = 0.535 	Test Acc = 81.960%
# Epoch 140/250 	 Loss = 0.518 	 Train Acc = 81.922% 	 Sparsity = 58.546% 	 Test Loss = 0.545 	Test Acc = 81.530%
# Epoch 141/250 	 Loss = 0.515 	 Train Acc = 81.970% 	 Sparsity = 58.561% 	 Test Loss = 0.529 	Test Acc = 82.190%
# Epoch 142/250 	 Loss = 0.519 	 Train Acc = 81.884% 	 Sparsity = 58.566% 	 Test Loss = 0.532 	Test Acc = 81.870%
# Epoch 143/250 	 Loss = 0.516 	 Train Acc = 82.002% 	 Sparsity = 58.571% 	 Test Loss = 0.523 	Test Acc = 82.520%
# Epoch 144/250 	 Loss = 0.517 	 Train Acc = 81.946% 	 Sparsity = 58.592% 	 Test Loss = 0.547 	Test Acc = 81.540%
# Epoch 145/250 	 Loss = 0.520 	 Train Acc = 81.946% 	 Sparsity = 58.596% 	 Test Loss = 0.533 	Test Acc = 81.730%
# Epoch 146/250 	 Loss = 0.519 	 Train Acc = 81.766% 	 Sparsity = 58.601% 	 Test Loss = 0.519 	Test Acc = 82.460%
# Epoch 147/250 	 Loss = 0.521 	 Train Acc = 81.848% 	 Sparsity = 58.617% 	 Test Loss = 0.522 	Test Acc = 81.990%
# Epoch 148/250 	 Loss = 0.517 	 Train Acc = 82.070% 	 Sparsity = 58.625% 	 Test Loss = 0.529 	Test Acc = 81.940%
# Epoch 149/250 	 Loss = 0.518 	 Train Acc = 81.930% 	 Sparsity = 58.629% 	 Test Loss = 0.518 	Test Acc = 82.040%
# Epoch 150/250 	 Loss = 0.515 	 Train Acc = 82.092% 	 Sparsity = 58.659% 	 Test Loss = 0.521 	Test Acc = 82.120%
# Epoch 151/250 	 Loss = 0.514 	 Train Acc = 82.098% 	 Sparsity = 58.665% 	 Test Loss = 0.532 	Test Acc = 81.960%
# Epoch 152/250 	 Loss = 0.517 	 Train Acc = 81.974% 	 Sparsity = 58.741% 	 Test Loss = 0.544 	Test Acc = 81.630%
# Epoch 153/250 	 Loss = 0.512 	 Train Acc = 82.068% 	 Sparsity = 58.745% 	 Test Loss = 0.537 	Test Acc = 81.830%
# Epoch 154/250 	 Loss = 0.518 	 Train Acc = 81.842% 	 Sparsity = 58.751% 	 Test Loss = 0.535 	Test Acc = 81.740%
# Epoch 155/250 	 Loss = 0.516 	 Train Acc = 81.884% 	 Sparsity = 58.755% 	 Test Loss = 0.527 	Test Acc = 82.220%
# Epoch 156/250 	 Loss = 0.516 	 Train Acc = 81.992% 	 Sparsity = 58.777% 	 Test Loss = 0.533 	Test Acc = 81.690%
# Epoch 157/250 	 Loss = 0.513 	 Train Acc = 82.048% 	 Sparsity = 58.781% 	 Test Loss = 0.535 	Test Acc = 81.800%
# Epoch 158/250 	 Loss = 0.517 	 Train Acc = 81.980% 	 Sparsity = 58.800% 	 Test Loss = 0.534 	Test Acc = 82.430%
# Epoch 159/250 	 Loss = 0.521 	 Train Acc = 81.748% 	 Sparsity = 58.805% 	 Test Loss = 0.525 	Test Acc = 82.450%
# Epoch 160/250 	 Loss = 0.514 	 Train Acc = 82.000% 	 Sparsity = 58.808% 	 Test Loss = 0.533 	Test Acc = 82.100%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2964/3983694037.py in <module>
#      71                 loss = loss_fn(y_batch_train, pred)
#      72
# ---> 73             grads = tape.gradient(loss, model.trainable_weights)
#      74             if step==0 and epoch==0:
#      75                 print("Created Tensor of velocity")
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1088         output_gradients=output_gradients,
#    1089         sources_raw=flat_sources_raw,
# -> 1090         unconnected_gradients=unconnected_gradients)
#    1091
#    1092     if not self._persistent:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     157       gradient_name_scope += forward_pass_name_scope + "/"
#     158     with ops.name_scope(gradient_name_scope):
# --> 159       return grad_fn(mock_op, *out_grads)
#     160   else:
#     161     return grad_fn(mock_op, *out_grads)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\ops\math_grad.py in _SumGrad(op, grad)
#     153   input_0_shape = op.inputs[0]._shape_tuple()  # pylint: disable=protected-access
#     154   if input_0_shape is not None:
# --> 155     axes = tensor_util.constant_value(op.inputs[1])
#     156     if axes is not None:
#     157       rank = len(input_0_shape)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\framework\tensor_util.py in constant_value(tensor, partial)
#     871   if isinstance(tensor, ops.EagerTensor):
#     872     try:
# --> 873       return tensor.numpy()
#     874     except errors_impl.UnimplementedError:
#     875       # Some EagerTensors may not implement .numpy/resolve, e.g. parallel
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
l = len(model.trainable_weights)
for i in range(l):
  a = tf.reshape(model.trainable_weights[i],[-1])
  b = a.numpy()
  #print(a)
  #plt.ylim(0,300)
  plt.title(str(i))
  plt.hist(b,200)
  plt.show()

# %%
import pandas as pd

data = {'train accuracy': model_train_acc, 'test accuracy': model_test_acc, 'sparsity': model_sparsity, 'train loss': model_train_loss, 'test loss': model_test_loss}

df = pd.DataFrame(data)

df.to_csv('test_5.csv')

# %%
plt.title("test acc x train acc")
plt.plot(model_train_acc)
plt.plot(model_test_acc)
plt.show()

# %%
plt.title("train loss x test loss")
plt.plot(model_train_loss)
plt.plot(model_test_loss)
plt.show()

# %%
plt.title("Sparsity")
plt.plot(model_sparsity)
plt.show()

# %%
model = keras.models.load_model('test_5.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
for layer in model.layers:
    if layer.name == 'conv2':
        a = tf.reshape(layer.weights[0],[-1])
        b = a.numpy()
        plt.hist(b,200)
        plt.show()

        plt.hist(b,200)
        plt.ylim((0,150))
        plt.show()

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    figure(figsize=(10, 7), dpi=80)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(10)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm[:,0])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, str(cm[i, j]*100/1000) + "%",
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
with tf.device('/device:CPU:0'):
    test_accuracy = tf.keras.metrics.Accuracy()
    logits = model(x_test, training=False)
    prediction = tf.argmax(logits, axis=1, output_type=tf.int32)
    test_accuracy(prediction, y_test)
    print("Test set accuracy: {:.3%}".format(test_accuracy.result()))
# Out:
# Test set accuracy: 82.790%

# %%
classes = ["avião","carro","pássaro","gato","veado","cachorro","sapo","cavalo","navio","caminhão"]
cm = confusion_matrix(y_true=y_test, y_pred=prediction)
plot_confusion_matrix(cm=cm, classes=classes, title='Matriz de confusão')
# Out:
# Confusion matrix, without normalization
